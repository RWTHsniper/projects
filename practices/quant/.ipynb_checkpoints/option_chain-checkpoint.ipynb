# %%
import yfinance as yf

# %%
aapl = yf.Ticker("AAPL")

# %% [markdown]
# # Option data

# %%
aapl.options
# Out:
# ('2020-12-24',
#  '2020-12-31',
#  '2021-01-08',
#  '2021-01-15',
#  '2021-01-22',
#  '2021-01-29',
#  '2021-02-19',
#  '2021-03-19',
#  '2021-04-16',
#  '2021-06-18',
#  '2021-07-16',
#  '2021-09-17',
#  '2022-01-21',
#  '2022-06-17',
#  '2022-09-16',
#  '2023-01-20')

# %%
date = aapl.options[0]; print(date)
opt = aapl.option_chain(date)
opt.calls.head(10)
# Out:
# 2020-12-24
#         contractSymbol       lastTradeDate  strike  lastPrice    bid    ask  \
# 0  AAPL201224C00065000 2020-12-21 14:58:59    65.0      60.40  62.90  63.55
# 1  AAPL201224C00070000 2020-11-27 15:28:43    70.0      47.22  57.90  58.55
# 2  AAPL201224C00075000 2020-12-21 16:56:54    75.0      49.95  52.90  53.55
# 3  AAPL201224C00080000 2020-12-21 17:48:01    80.0      45.64  48.05  48.40
# 4  AAPL201224C00085000 2020-12-21 20:12:56    85.0      41.32  43.05  43.40
# 5  AAPL201224C00090000 2020-12-21 20:35:22    90.0      36.35  38.05  38.40
# 6  AAPL201224C00095000 2020-12-17 19:35:44    95.0      33.25  33.05  33.40
# 7  AAPL201224C00097000 2020-12-21 14:30:00    97.0      29.30  31.05  31.40
# 8  AAPL201224C00098000 2020-12-18 20:52:02    98.0      28.40  30.05  30.40
# 9  AAPL201224C00099000 2020-12-21 18:38:35    99.0      27.95  29.05  29.40
#
#      change  percentChange  volume  openInterest  impliedVolatility  \
# ...

# %%
date = aapl.options[1]; print(date)
opt = aapl.option_chain(date)
opt.calls.head(10)
# Out:
# 2020-12-31
#         contractSymbol       lastTradeDate  strike  lastPrice    bid    ask  \
# 0  AAPL201231C00085000 2020-12-21 20:12:56    85.0      41.35  43.05  43.45
# 1  AAPL201231C00090000 2020-12-21 17:53:47    90.0      35.93  38.10  38.50
# 2  AAPL201231C00095000 2020-12-21 20:41:49    95.0      32.40  33.10  33.50
# 3  AAPL201231C00100000 2020-12-21 20:58:33   100.0      28.15  28.15  28.55
# 4  AAPL201231C00105000 2020-12-21 20:47:49   105.0      22.90  23.15  23.60
# 5  AAPL201231C00106000 2020-12-21 18:54:21   106.0      21.40  22.15  22.60
# 6  AAPL201231C00107000 2020-12-21 15:22:11   107.0      17.31  21.15  21.60
# 7  AAPL201231C00108000 2020-12-21 17:22:53   108.0      17.72  20.15  20.60
# 8  AAPL201231C00109000 2020-12-21 19:13:16   109.0      17.80  19.20  19.60
# 9  AAPL201231C00110000 2020-12-21 20:58:16   110.0      18.19  18.20  18.65
#
#      change  percentChange  volume  openInterest  impliedVolatility  \
# ...
