# %%
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np

class DeepQNetwork(nn.Module):
    """
    For a given observation, compute Q values for each action
        Attributes
    ----------
    lr: float
        learning rate
    input_dims : list
        [8]
    fc1_dims : int
        fully-connected layer 1
    fc2_dims : int
        fully-connected layer 2
    n_actions : int
        the number of actions
    """
    def __init__(self, lr, input_dims, fc1_dims, fc2_dims, n_actions, weight_decay=1e-5,p=0.5):
        super(DeepQNetwork, self).__init__()
        self.input_dims = input_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
        self.fc1 = nn.Linear(*self.input_dims, self.fc1_dims)
        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
        self.fc3 = nn.Linear(self.fc2_dims, self.n_actions)
#        self.dropout = nn.Dropout(p) 
        self.optimizer = optim.Adam(self.parameters(), lr=lr, weight_decay=weight_decay)
#        self.loss = nn.MSELoss()
        self.loss = nn.SmoothL1Loss() # Huber loss
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)
    
    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
#        x = self.dropout(x) # dropout for regularization
        actions = self.fc3(x)
        
        return actions

class Agent():
    def __init__(self, gamma, epsilon, lr, input_dims, batch_size, n_actions,
                max_mem_size=100000, eps_end=0.01, eps_dec=1e-5, weight_decay=1e-5):
        self.gamma = gamma
        self.epsilon = epsilon
        self.eps_min = eps_end
        self.eps_dec = eps_dec
        self.lr = lr
        self.action_space = [i for i in range(n_actions)] # list of actions
        self.mem_size = max_mem_size
        self.batch_size = batch_size
        self.mem_cntr = 0
        
        self.Q_eval = DeepQNetwork(self.lr, n_actions=n_actions, input_dims=input_dims, 
                                  fc1_dims=32, fc2_dims=32, weight_decay=weight_decay)
        
        self.state_memory = np.zeros((self.mem_size, *input_dims), dtype= np.float32)
        self.new_state_memory = np.zeros((self.mem_size, *input_dims), dtype=np.float32)
        self.action_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.reward_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)
        
    def store_transition(self, state, action, reward, state_, done):
        if index >= self.mem_size:
            index -= self.mem_size
        index = self.mem_cntr % self.mem_size # residual. The memory is finite, so we are reusing
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.reward_memory[index] = reward
        self.action_memory[index] =  action
        self.terminal_memory[index] = done
        
        self.mem_cntr += 1
        
    def choose_action(self, observation):
        if np.random.random() > self.epsilon:
            state = T.tensor([observation]).to(self.Q_eval.device) # [] is used because of the nn library. torch.Size([1, 6])
            actions = self.Q_eval.forward(state)
            action = T.argmax(actions).item() # .item() to get integer
        else:
            action = np.random.choice(self.action_space)
            
        return action
    
    def learn(self):
        if self.mem_cntr < self.batch_size:
            return
        
        self.Q_eval.optimizer.zero_grad()
        
        max_mem = min(self.mem_cntr, self.mem_size) 
        # select samples the number of self.batch_size out of max_mem 
        batch = np.random.choice(max_mem, self.batch_size, replace=False) # Don't select the same thing again
        # array slicing [0,1,2,...,self.batch_size-1]
        batch_index = np.arange(self.batch_size, dtype=np.int32) 
        
        state_batch = T.tensor(self.state_memory[batch]).to(self.Q_eval.device)
        new_state_batch = T.tensor(self.new_state_memory[batch]).to(self.Q_eval.device)
        reward_batch = T.tensor(self.reward_memory[batch]).to(self.Q_eval.device)
        terminal_batch = T.tensor(self.terminal_memory[batch]).to(self.Q_eval.device)
        
        action_batch = self.action_memory[batch]
        
        q_eval = self.Q_eval.forward(state_batch)[batch_index, action_batch]
        q_next = self.Q_eval.forward(new_state_batch)
        q_next[terminal_batch] = 0.0
                                                 
        q_target = reward_batch + self.gamma * T.max(q_next, dim=1)[0]
        
        loss = self.Q_eval.loss(q_target, q_eval).to(self.Q_eval.device)
        loss.backward()
        self.Q_eval.optimizer.step()
        
        self.epsilon = self.epsilon - self.eps_dec if self.epsilon > self.eps_min else self.eps_min

# %%
#from env import TradingSPYEnv
from env4 import TradingSPYEnv
import numpy as np
env = TradingSPYEnv(init_invest=100.0, sma_len=[5,25,50,100])
num_states = len(env._get_observation().flatten())
print("Size of State Space ->  {}".format(num_states))
num_actions = env.action_space.n
print("Size of Action Space ->  {}".format(num_actions))

agent = Agent(gamma=0.99, epsilon=1.0, batch_size=64, n_actions=num_actions, eps_end=0.01, input_dims = [num_states], lr=0.003,
              weight_decay=1e-5)
scores, eps_history = [], []
n_games = 1000


for i in range(n_games):
    score = 0
    done = False
    observation = env.reset()
    if observation.dtype == np.float64:
        observation = observation.astype(np.float32)
    while not done:
        action = agent.choose_action(observation)
        observation_, reward, done, info = env.step(action)
        if (observation_ is not None): 
            if (observation_.dtype == np.float64):
                observation_ = observation_.astype(np.float32)
            score += reward
            agent.store_transition(observation, action, reward, observation_, done)
        agent.learn()
        observation = observation_
    scores.append(score)
    eps_history.append(agent.epsilon)
    
    avg_score = np.mean(scores[-100:])
    
    print('episode ', i, 'score %.2f' % score,
         'average score %.2f' % avg_score,
         'epsilon %.2f ' % agent.epsilon,
         'profit_iteration %.2f ' % info['profit_iteration'],
         'iterations %.2f ' % info['iterations'],
         'long_return %.2f ' % info['long_return']
         )
# Out:
# C:\Users\golde\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# Size of State Space ->  404
# Size of Action Space ->  3
# episode  0 score -58.62 average score -58.62 epsilon 0.97  profit_iteration -0.02  iterations 2920.00  long_return 2.51
# episode  1 score 9.48 average score -24.57 epsilon 0.96  profit_iteration 0.01  iterations 946.00  long_return 1.54
# episode  2 score 79.29 average score 10.05 epsilon 0.93  profit_iteration 0.03  iterations 2813.00  long_return 2.31
# episode  3 score 10.31 average score 10.12 epsilon 0.92  profit_iteration 0.01  iterations 1273.00  long_return 1.93
# episode  4 score -4.50 average score 7.19 epsilon 0.91  profit_iteration -0.01  iterations 1027.00  long_return 1.56
# episode  5 score -4.19 average score 5.30 epsilon 0.91  profit_iteration -0.05  iterations 81.00  long_return 1.02
# episode  6 score -6.65 average score 3.59 epsilon 0.91  profit_iteration -0.02  iterations 252.00  long_return 1.16
# episode  7 score -43.26 average score -2.27 epsilon 0.88  profit_iteration -0.02  iterations 2600.00  long_return 2.61
# episode  8 score -19.40 average score -4.17 epsilon 0.87  profit_iteration -0.01  iterations 1609.00  long_return 2.32
# episode  9 score 28.88 average score -0.87 epsilon 0.85  profit_iteration 0.02  iterations 1552.00  long_return 2.31
# episode  10 score 16.22 average score 0.69 epsilon 0.84  profit_iteration 0.02  iterations 955.00  long_return 1.50
# episode  11 score -23.14 average score -1.30 epsilon 0.83  profit_iteration -0.02  iterations 1492.00  long_return 2.24
# episode  12 score -41.51 average score -4.39 epsilon 0.79  profit_iteration -0.01  iterations 3966.00  long_return 4.70
# episode  13 score 80.80 average score 1.69 epsilon 0.75  profit_iteration 0.02  iterations 3703.00  long_return 3.60
# episode  14 score 8.47 average score 2.15 epsilon 0.72  profit_iteration 0.00  iterations 2581.00  long_return 2.52
# episode  15 score -43.34 average score -0.70 epsilon 0.69  profit_iteration -0.02  iterations 2874.00  long_return 2.43
# episode  16 score 8.28 average score -0.17 epsilon 0.67  profit_iteration 0.00  iterations 2536.00  long_return 2.52
# episode  17 score -25.06 average score -1.55 epsilon 0.65  profit_iteration -0.01  iterations 1913.00  long_return 2.64
# episode  18 score -60.08 average score -4.63 epsilon 0.61  profit_iteration -0.02  iterations 3656.00  long_return 3.33
# episode  19 score 201.89 average score 5.69 epsilon 0.59  profit_iteration 0.07  iterations 2763.00  long_return 2.26
# episode  20 score -11.52 average score 4.87 epsilon 0.57  profit_iteration -0.01  iterations 1947.00  long_return 2.76
# episode  21 score -3.05 average score 4.51 epsilon 0.57  profit_iteration -0.08  iterations 39.00  long_return 1.03
# episode  22 score -9.03 average score 3.93 epsilon 0.55  profit_iteration -0.01  iterations 1480.00  long_return 2.20
# episode  23 score -46.14 average score 1.84 epsilon 0.53  profit_iteration -0.02  iterations 2531.00  long_return 2.59
# episode  24 score 12.14 average score 2.25 epsilon 0.50  profit_iteration 0.01  iterations 2199.00  long_return 3.02
# episode  25 score -21.04 average score 1.36 epsilon 0.46  profit_iteration -0.01  iterations 4010.00  long_return 4.39
# episode  26 score -39.52 average score -0.16 epsilon 0.44  profit_iteration -0.02  iterations 2212.00  long_return 3.16
# episode  27 score -18.84 average score -0.83 epsilon 0.43  profit_iteration -0.02  iterations 1247.00  long_return 1.81
# episode  28 score 40.65 average score 0.60 epsilon 0.40  profit_iteration 0.02  iterations 2365.00  long_return 4.25
# episode  29 score 43.20 average score 2.02 epsilon 0.38  profit_iteration 0.02  iterations 2857.00  long_return 2.51
# episode  30 score 3.85 average score 2.08 epsilon 0.38  profit_iteration 0.04  iterations 82.00  long_return 1.01
# episode  31 score -22.56 average score 1.31 epsilon 0.35  profit_iteration -0.01  iterations 2788.00  long_return 2.28
# episode  32 score 8.49 average score 1.53 epsilon 0.34  profit_iteration 0.01  iterations 899.00  long_return 1.49
# episode  33 score 32.18 average score 2.43 epsilon 0.30  profit_iteration 0.01  iterations 3559.00  long_return 3.37
# episode  34 score -3.37 average score 2.27 epsilon 0.29  profit_iteration -0.00  iterations 828.00  long_return 1.44
# episode  35 score 47.30 average score 3.52 epsilon 0.29  profit_iteration 0.06  iterations 770.00  long_return 1.39
# episode  36 score -2.70 average score 3.35 epsilon 0.25  profit_iteration -0.00  iterations 3833.00  long_return 4.18
# episode  37 score 92.86 average score 5.71 epsilon 0.22  profit_iteration 0.03  iterations 2969.00  long_return 2.68
# episode  38 score 84.36 average score 7.72 epsilon 0.21  profit_iteration 0.06  iterations 1325.00  long_return 1.97
# episode  39 score 49.24 average score 8.76 epsilon 0.19  profit_iteration 0.04  iterations 1250.00  long_return 1.81
# episode  40 score 43.46 average score 9.61 epsilon 0.17  profit_iteration 0.02  iterations 2229.00  long_return 3.31
# episode  41 score 252.39 average score 15.39 epsilon 0.15  profit_iteration 0.11  iterations 2360.00  long_return 4.37
# episode  42 score 50.68 average score 16.21 epsilon 0.11  profit_iteration 0.01  iterations 3317.00  long_return 3.09
# episode  43 score 201.85 average score 20.43 epsilon 0.09  profit_iteration 0.07  iterations 2733.00  long_return 2.36
# episode  44 score 48.18 average score 21.04 epsilon 0.08  profit_iteration 0.05  iterations 1038.00  long_return 1.57
# episode  45 score 7.37 average score 20.75 epsilon 0.07  profit_iteration 0.01  iterations 749.00  long_return 1.39
# episode  46 score 89.79 average score 22.22 epsilon 0.03  profit_iteration 0.02  iterations 3828.00  long_return 4.08
# episode  47 score 291.43 average score 27.82 epsilon 0.01  profit_iteration 0.07  iterations 4020.00  long_return 4.75
# episode  48 score 102.39 average score 29.35 epsilon 0.01  profit_iteration 0.04  iterations 2637.00  long_return 2.61
# episode  49 score 149.23 average score 31.74 epsilon 0.01  profit_iteration 0.07  iterations 1974.00  long_return 2.97
# episode  50 score 168.13 average score 34.42 epsilon 0.01  profit_iteration 0.10  iterations 1664.00  long_return 2.65
# episode  51 score 154.99 average score 36.74 epsilon 0.01  profit_iteration 0.08  iterations 1981.00  long_return 3.09
# episode  52 score 20.13 average score 36.42 epsilon 0.01  profit_iteration 0.02  iterations 938.00  long_return 1.58
# episode  53 score 101.55 average score 37.63 epsilon 0.01  profit_iteration 0.06  iterations 1676.00  long_return 2.58
# episode  54 score 46.90 average score 37.80 epsilon 0.01  profit_iteration 0.04  iterations 1083.00  long_return 1.62
# episode  55 score 38.89 average score 37.82 epsilon 0.01  profit_iteration 0.02  iterations 1758.00  long_return 2.42
# episode  56 score 229.85 average score 41.19 epsilon 0.01  profit_iteration 0.09  iterations 2489.00  long_return 2.67
# episode  57 score 183.21 average score 43.63 epsilon 0.01  profit_iteration 0.05  iterations 3369.00  long_return 3.06
# episode  58 score 39.78 average score 43.57 epsilon 0.01  profit_iteration 0.05  iterations 706.00  long_return 1.49
# episode  59 score 62.24 average score 43.88 epsilon 0.01  profit_iteration 0.05  iterations 1300.00  long_return 1.88
# episode  60 score 58.27 average score 44.12 epsilon 0.01  profit_iteration 0.05  iterations 1055.00  long_return 1.60
# episode  61 score 151.52 average score 45.85 epsilon 0.01  profit_iteration 0.08  iterations 1873.00  long_return 2.50
# episode  62 score 164.56 average score 47.73 epsilon 0.01  profit_iteration 0.05  iterations 3310.00  long_return 3.08
# episode  63 score 85.81 average score 48.33 epsilon 0.01  profit_iteration 0.03  iterations 2837.00  long_return 2.43
# episode  64 score 258.18 average score 51.56 epsilon 0.01  profit_iteration 0.11  iterations 2277.00  long_return 3.68
# episode  65 score 72.93 average score 51.88 epsilon 0.01  profit_iteration 0.06  iterations 1223.00  long_return 1.87
# episode  66 score 3.53 average score 51.16 epsilon 0.01  profit_iteration 0.02  iterations 150.00  long_return 1.06
# episode  67 score 161.27 average score 52.78 epsilon 0.01  profit_iteration 0.04  iterations 3604.00  long_return 3.28
# episode  68 score 18.38 average score 52.28 epsilon 0.01  profit_iteration 0.06  iterations 273.00  long_return 1.16
# episode  69 score 101.72 average score 52.99 epsilon 0.01  profit_iteration 0.05  iterations 2065.00  long_return 2.74
# episode  70 score 179.15 average score 54.76 epsilon 0.01  profit_iteration 0.09  iterations 1938.00  long_return 2.74
# episode  71 score 134.73 average score 55.87 epsilon 0.01  profit_iteration 0.04  iterations 2967.00  long_return 2.64
# episode  72 score 193.87 average score 57.76 epsilon 0.01  profit_iteration 0.06  iterations 3358.00  long_return 3.00
# episode  73 score 169.36 average score 59.27 epsilon 0.01  profit_iteration 0.05  iterations 3250.00  long_return 2.91
# episode  74 score 273.43 average score 62.13 epsilon 0.01  profit_iteration 0.08  iterations 3455.00  long_return 3.31
# episode  75 score 113.71 average score 62.81 epsilon 0.01  profit_iteration 0.07  iterations 1557.00  long_return 2.24
# episode  76 score 325.96 average score 66.22 epsilon 0.01  profit_iteration 0.08  iterations 3994.00  long_return 4.12
# episode  77 score 137.46 average score 67.14 epsilon 0.01  profit_iteration 0.07  iterations 1811.00  long_return 2.35
# episode  78 score 86.15 average score 67.38 epsilon 0.01  profit_iteration 0.06  iterations 1389.00  long_return 2.12
# episode  79 score 121.16 average score 68.05 epsilon 0.01  profit_iteration 0.05  iterations 2654.00  long_return 2.31
# episode  80 score 238.77 average score 70.16 epsilon 0.01  profit_iteration 0.11  iterations 2187.00  long_return 3.19
# episode  81 score 162.65 average score 71.29 epsilon 0.01  profit_iteration 0.08  iterations 1894.00  long_return 2.56
# episode  82 score 254.68 average score 73.50 epsilon 0.01  profit_iteration 0.06  iterations 4015.00  long_return 4.18
# episode  83 score 11.33 average score 72.76 epsilon 0.01  profit_iteration 0.05  iterations 207.00  long_return 1.13
# episode  84 score 225.87 average score 74.56 epsilon 0.01  profit_iteration 0.06  iterations 3928.00  long_return 4.02
# episode  85 score 41.37 average score 74.17 epsilon 0.01  profit_iteration 0.05  iterations 805.00  long_return 1.42
# episode  86 score 269.16 average score 76.41 epsilon 0.01  profit_iteration 0.07  iterations 3817.00  long_return 3.96
# episode  87 score 116.71 average score 76.87 epsilon 0.01  profit_iteration 0.04  iterations 3172.00  long_return 2.83
# episode  88 score 300.73 average score 79.39 epsilon 0.01  profit_iteration 0.08  iterations 3763.00  long_return 3.77
# episode  89 score 143.38 average score 80.10 epsilon 0.01  profit_iteration 0.04  iterations 3225.00  long_return 2.91
# episode  90 score 16.56 average score 79.40 epsilon 0.01  profit_iteration 0.07  iterations 230.00  long_return 1.16
# episode  91 score 56.32 average score 79.15 epsilon 0.01  profit_iteration 0.09  iterations 593.00  long_return 1.46
# episode  92 score 136.73 average score 79.77 epsilon 0.01  profit_iteration 0.07  iterations 1899.00  long_return 2.56
# episode  93 score 131.57 average score 80.32 epsilon 0.01  profit_iteration 0.04  iterations 3284.00  long_return 3.01
# episode  94 score 101.33 average score 80.54 epsilon 0.01  profit_iteration 0.03  iterations 2907.00  long_return 2.47
# episode  95 score 76.20 average score 80.49 epsilon 0.01  profit_iteration 0.06  iterations 1248.00  long_return 1.81
# episode  96 score 40.75 average score 80.08 epsilon 0.01  profit_iteration 0.05  iterations 787.00  long_return 1.39
# episode  97 score 149.38 average score 80.79 epsilon 0.01  profit_iteration 0.05  iterations 3126.00  long_return 2.82
# episode  98 score 314.06 average score 83.15 epsilon 0.01  profit_iteration 0.08  iterations 3758.00  long_return 3.85
# episode  99 score 76.50 average score 83.08 epsilon 0.01  profit_iteration 0.06  iterations 1198.00  long_return 1.82
# episode  100 score 113.15 average score 84.80 epsilon 0.01  profit_iteration 0.04  iterations 3066.00  long_return 2.68
# episode  101 score 227.66 average score 86.98 epsilon 0.01  profit_iteration 0.09  iterations 2456.00  long_return 3.39
# episode  102 score 48.11 average score 86.67 epsilon 0.01  profit_iteration 0.08  iterations 617.00  long_return 1.54
# episode  103 score 187.35 average score 88.44 epsilon 0.01  profit_iteration 0.05  iterations 3626.00  long_return 3.22
# episode  104 score 269.16 average score 91.18 epsilon 0.01  profit_iteration 0.07  iterations 3563.00  long_return 3.35
# episode  105 score 187.36 average score 93.09 epsilon 0.01  profit_iteration 0.09  iterations 1980.00  long_return 3.05
# episode  106 score 33.07 average score 93.49 epsilon 0.01  profit_iteration 0.07  iterations 457.00  long_return 1.34
# episode  107 score 110.10 average score 95.02 epsilon 0.01  profit_iteration 0.03  iterations 3236.00  long_return 2.94
# episode  108 score 183.78 average score 97.05 epsilon 0.01  profit_iteration 0.07  iterations 2518.00  long_return 2.72
# episode  109 score 11.76 average score 96.88 epsilon 0.01  profit_iteration 0.06  iterations 189.00  long_return 1.11
# episode  110 score 187.39 average score 98.59 epsilon 0.01  profit_iteration 0.05  iterations 3701.00  long_return 3.59
# episode  111 score 277.09 average score 101.60 epsilon 0.01  profit_iteration 0.08  iterations 3291.00  long_return 2.99
# episode  112 score 158.45 average score 103.60 epsilon 0.01  profit_iteration 0.09  iterations 1734.00  long_return 2.79
# episode  113 score 181.80 average score 104.61 epsilon 0.01  profit_iteration 0.08  iterations 2123.00  long_return 2.99
# episode  114 score 41.13 average score 104.93 epsilon 0.01  profit_iteration 0.07  iterations 585.00  long_return 1.44
# episode  115 score 246.59 average score 107.83 epsilon 0.01  profit_iteration 0.10  iterations 2450.00  long_return 3.76
# episode  116 score 231.02 average score 110.06 epsilon 0.01  profit_iteration 0.08  iterations 3008.00  long_return 2.77
# episode  117 score 366.25 average score 113.97 epsilon 0.01  profit_iteration 0.09  iterations 3964.00  long_return 4.69
# episode  118 score 231.84 average score 116.89 epsilon 0.01  profit_iteration 0.10  iterations 2338.00  long_return 4.09
# episode  119 score 408.53 average score 118.96 epsilon 0.01  profit_iteration 0.10  iterations 3988.00  long_return 4.22
# episode  120 score 13.68 average score 119.21 epsilon 0.01  profit_iteration 0.07  iterations 190.00  long_return 1.10
# episode  121 score 166.82 average score 120.91 epsilon 0.01  profit_iteration 0.09  iterations 1927.00  long_return 2.66
# episode  122 score 214.22 average score 123.14 epsilon 0.01  profit_iteration 0.06  iterations 3393.00  long_return 3.04
# episode  123 score 374.63 average score 127.35 epsilon 0.01  profit_iteration 0.10  iterations 3889.00  long_return 4.35
# episode  124 score 98.33 average score 128.21 epsilon 0.01  profit_iteration 0.06  iterations 1514.00  long_return 2.27
# episode  125 score 85.20 average score 129.27 epsilon 0.01  profit_iteration 0.06  iterations 1316.00  long_return 1.98
# episode  126 score 112.44 average score 130.79 epsilon 0.01  profit_iteration 0.03  iterations 3404.00  long_return 3.01
# episode  127 score 298.29 average score 133.96 epsilon 0.01  profit_iteration 0.13  iterations 2297.00  long_return 3.72
# episode  128 score 207.59 average score 135.63 epsilon 0.01  profit_iteration 0.10  iterations 2025.00  long_return 3.03
# episode  129 score 169.33 average score 136.89 epsilon 0.01  profit_iteration 0.08  iterations 2068.00  long_return 2.69
# episode  130 score 43.33 average score 137.29 epsilon 0.01  profit_iteration 0.08  iterations 513.00  long_return 1.44
# episode  131 score 256.91 average score 140.08 epsilon 0.01  profit_iteration 0.06  iterations 3932.00  long_return 4.05
# episode  132 score 172.19 average score 141.72 epsilon 0.01  profit_iteration 0.10  iterations 1637.00  long_return 2.47
# episode  133 score 156.56 average score 142.96 epsilon 0.01  profit_iteration 0.06  iterations 2465.00  long_return 2.85
# episode  134 score 16.34 average score 143.16 epsilon 0.01  profit_iteration 0.05  iterations 305.00  long_return 1.19
# episode  135 score 206.96 average score 144.76 epsilon 0.01  profit_iteration 0.05  iterations 3766.00  long_return 3.73
# episode  136 score 25.22 average score 145.04 epsilon 0.01  profit_iteration 0.03  iterations 851.00  long_return 1.40
# episode  137 score 13.79 average score 144.25 epsilon 0.01  profit_iteration 0.05  iterations 250.00  long_return 1.15
# episode  138 score 85.55 average score 144.26 epsilon 0.01  profit_iteration 0.07  iterations 1211.00  long_return 1.77
# episode  139 score 281.42 average score 146.58 epsilon 0.01  profit_iteration 0.08  iterations 3668.00  long_return 3.44
# episode  140 score 11.18 average score 146.26 epsilon 0.01  profit_iteration 0.05  iterations 199.00  long_return 1.13
# episode  141 score 158.44 average score 145.32 epsilon 0.01  profit_iteration 0.05  iterations 2881.00  long_return 2.44
# episode  142 score 73.21 average score 145.54 epsilon 0.01  profit_iteration 0.06  iterations 1114.00  long_return 1.70
# episode  143 score 36.36 average score 143.89 epsilon 0.01  profit_iteration 0.05  iterations 747.00  long_return 1.40
# episode  144 score 127.67 average score 144.68 epsilon 0.01  profit_iteration 0.04  iterations 2888.00  long_return 2.46
# episode  145 score 470.62 average score 149.32 epsilon 0.01  profit_iteration 0.12  iterations 3954.00  long_return 4.28
# episode  146 score 211.61 average score 150.53 epsilon 0.01  profit_iteration 0.06  iterations 3277.00  long_return 2.99
# episode  147 score 107.90 average score 148.70 epsilon 0.01  profit_iteration 0.08  iterations 1326.00  long_return 1.98
# episode  148 score 154.60 average score 149.22 epsilon 0.01  profit_iteration 0.08  iterations 1967.00  long_return 2.88
# episode  149 score 169.21 average score 149.42 epsilon 0.01  profit_iteration 0.04  iterations 3738.00  long_return 3.61
# episode  150 score 9.02 average score 147.83 epsilon 0.01  profit_iteration 0.10  iterations 86.00  long_return 1.02
# episode  151 score 35.96 average score 146.64 epsilon 0.01  profit_iteration 0.04  iterations 817.00  long_return 1.41
# episode  152 score 175.11 average score 148.19 epsilon 0.01  profit_iteration 0.05  iterations 3234.00  long_return 2.95
# episode  153 score 36.58 average score 147.54 epsilon 0.01  profit_iteration 0.05  iterations 749.00  long_return 1.39
# episode  154 score 42.89 average score 147.50 epsilon 0.01  profit_iteration 0.05  iterations 779.00  long_return 1.42
# episode  155 score 21.51 average score 147.33 epsilon 0.01  profit_iteration 0.06  iterations 332.00  long_return 1.19
# episode  156 score 239.98 average score 147.43 epsilon 0.01  profit_iteration 0.07  iterations 3491.00  long_return 3.30
# episode  157 score 78.02 average score 146.37 epsilon 0.01  profit_iteration 0.06  iterations 1214.00  long_return 1.81
# episode  158 score 35.92 average score 146.34 epsilon 0.01  profit_iteration 0.08  iterations 462.00  long_return 1.32
# episode  159 score 2.17 average score 145.74 epsilon 0.01  profit_iteration 0.02  iterations 82.00  long_return 1.01
# episode  160 score 187.99 average score 147.03 epsilon 0.01  profit_iteration 0.09  iterations 1997.00  long_return 2.88
# episode  161 score 37.68 average score 145.89 epsilon 0.01  profit_iteration 0.07  iterations 545.00  long_return 1.40
# episode  162 score 171.99 average score 145.97 epsilon 0.01  profit_iteration 0.07  iterations 2503.00  long_return 2.69
# episode  163 score 111.51 average score 146.23 epsilon 0.01  profit_iteration 0.08  iterations 1367.00  long_return 2.04
# episode  164 score 243.47 average score 146.08 epsilon 0.01  profit_iteration 0.07  iterations 3222.00  long_return 2.97
# episode  165 score 90.14 average score 146.25 epsilon 0.01  profit_iteration 0.07  iterations 1342.00  long_return 1.98
# episode  166 score 148.93 average score 147.70 epsilon 0.01  profit_iteration 0.05  iterations 3068.00  long_return 2.72
# episode  167 score 157.56 average score 147.67 epsilon 0.01  profit_iteration 0.09  iterations 1812.00  long_return 2.36
# episode  168 score 265.37 average score 150.14 epsilon 0.01  profit_iteration 0.07  iterations 3909.00  long_return 4.27
# episode  169 score 246.29 average score 151.58 epsilon 0.01  profit_iteration 0.07  iterations 3724.00  long_return 3.68
# episode  170 score 144.12 average score 151.23 epsilon 0.01  profit_iteration 0.08  iterations 1845.00  long_return 2.46
# episode  171 score 45.79 average score 150.34 epsilon 0.01  profit_iteration 0.05  iterations 967.00  long_return 1.49
# episode  172 score 183.53 average score 150.24 epsilon 0.01  profit_iteration 0.07  iterations 2525.00  long_return 2.66
# episode  173 score 209.96 average score 150.65 epsilon 0.01  profit_iteration 0.09  iterations 2256.00  long_return 3.38
# episode  174 score 93.28 average score 148.84 epsilon 0.01  profit_iteration 0.03  iterations 2807.00  long_return 2.31
# episode  175 score 37.02 average score 148.08 epsilon 0.01  profit_iteration 0.07  iterations 505.00  long_return 1.35
# episode  176 score 152.85 average score 146.35 epsilon 0.01  profit_iteration 0.09  iterations 1657.00  long_return 2.51
# episode  177 score 143.45 average score 146.41 epsilon 0.01  profit_iteration 0.05  iterations 2710.00  long_return 2.25
# episode  178 score 138.35 average score 146.93 epsilon 0.01  profit_iteration 0.09  iterations 1564.00  long_return 2.30
# episode  179 score 294.68 average score 148.66 epsilon 0.01  profit_iteration 0.08  iterations 3763.00  long_return 3.77
# episode  180 score 250.86 average score 148.78 epsilon 0.01  profit_iteration 0.07  iterations 3480.00  long_return 3.23
# episode  181 score 194.70 average score 149.10 epsilon 0.01  profit_iteration 0.06  iterations 3251.00  long_return 2.92
# episode  182 score 93.04 average score 147.49 epsilon 0.01  profit_iteration 0.06  iterations 1558.00  long_return 2.23
# episode  183 score 294.53 average score 150.32 epsilon 0.01  profit_iteration 0.08  iterations 3599.00  long_return 3.37
# episode  184 score 155.59 average score 149.62 epsilon 0.01  profit_iteration 0.05  iterations 3257.00  long_return 2.90
# episode  185 score 192.08 average score 151.12 epsilon 0.01  profit_iteration 0.05  iterations 3504.00  long_return 3.39
# episode  186 score 88.78 average score 149.32 epsilon 0.01  profit_iteration 0.07  iterations 1325.00  long_return 1.97
# episode  187 score 280.53 average score 150.96 epsilon 0.01  profit_iteration 0.08  iterations 3317.00  long_return 3.09
# episode  188 score 10.61 average score 148.06 epsilon 0.01  profit_iteration 0.05  iterations 191.00  long_return 1.10
# episode  189 score 168.07 average score 148.30 epsilon 0.01  profit_iteration 0.07  iterations 2506.00  long_return 2.76
# episode  190 score 173.14 average score 149.87 epsilon 0.01  profit_iteration 0.08  iterations 2131.00  long_return 3.01
# episode  191 score 30.28 average score 149.61 epsilon 0.01  profit_iteration 0.03  iterations 844.00  long_return 1.41
# episode  192 score 42.19 average score 148.66 epsilon 0.01  profit_iteration 0.05  iterations 833.00  long_return 1.40
# episode  193 score 202.21 average score 149.37 epsilon 0.01  profit_iteration 0.08  iterations 2510.00  long_return 2.67
# episode  194 score 15.30 average score 148.51 epsilon 0.01  profit_iteration 0.06  iterations 235.00  long_return 1.14
# episode  195 score 224.33 average score 149.99 epsilon 0.01  profit_iteration 0.06  iterations 3470.00  long_return 3.29
# episode  196 score 287.18 average score 152.46 epsilon 0.01  profit_iteration 0.09  iterations 3045.00  long_return 2.80
# episode  197 score 12.80 average score 151.09 epsilon 0.01  profit_iteration 0.06  iterations 207.00  long_return 1.13
# episode  198 score 36.15 average score 148.31 epsilon 0.01  profit_iteration 0.07  iterations 525.00  long_return 1.36
# episode  199 score 300.33 average score 150.55 epsilon 0.01  profit_iteration 0.07  iterations 4033.00  long_return 3.98
# episode  200 score 197.99 average score 151.40 epsilon 0.01  profit_iteration 0.10  iterations 2037.00  long_return 3.07
# episode  201 score 230.95 average score 151.43 epsilon 0.01  profit_iteration 0.06  iterations 3540.00  long_return 3.24
# episode  202 score 148.01 average score 152.43 epsilon 0.01  profit_iteration 0.05  iterations 3067.00  long_return 2.71
# episode  203 score 227.45 average score 152.83 epsilon 0.01  profit_iteration 0.10  iterations 2229.00  long_return 3.31
# episode  204 score 357.20 average score 153.71 epsilon 0.01  profit_iteration 0.09  iterations 3867.00  long_return 4.47
# episode  205 score 3.10 average score 151.87 epsilon 0.01  profit_iteration 0.02  iterations 131.00  long_return 1.04
# episode  206 score 148.12 average score 153.02 epsilon 0.01  profit_iteration 0.05  iterations 2904.00  long_return 2.48
# episode  207 score 27.31 average score 152.19 epsilon 0.01  profit_iteration 0.07  iterations 388.00  long_return 1.26
# episode  208 score 123.11 average score 151.58 epsilon 0.01  profit_iteration 0.08  iterations 1530.00  long_return 2.39
# episode  209 score 78.17 average score 152.25 epsilon 0.01  profit_iteration 0.07  iterations 1086.00  long_return 1.62
# episode  210 score 38.22 average score 150.76 epsilon 0.01  profit_iteration 0.07  iterations 564.00  long_return 1.39
# episode  211 score 66.75 average score 148.65 epsilon 0.01  profit_iteration 0.06  iterations 1132.00  long_return 1.64
# episode  212 score 121.76 average score 148.29 epsilon 0.01  profit_iteration 0.04  iterations 2761.00  long_return 2.30
# episode  213 score 18.11 average score 146.65 epsilon 0.01  profit_iteration 0.08  iterations 228.00  long_return 1.14
# episode  214 score 181.13 average score 148.05 epsilon 0.01  profit_iteration 0.05  iterations 3285.00  long_return 2.96
# episode  215 score 236.59 average score 147.95 epsilon 0.01  profit_iteration 0.11  iterations 2229.00  long_return 3.31
# episode  216 score 15.16 average score 145.79 epsilon 0.01  profit_iteration 0.07  iterations 215.00  long_return 1.14
# episode  217 score 343.83 average score 145.57 epsilon 0.01  profit_iteration 0.10  iterations 3435.00  long_return 3.10
# episode  218 score 184.32 average score 145.09 epsilon 0.01  profit_iteration 0.08  iterations 2197.00  long_return 3.03
# episode  219 score 123.78 average score 142.24 epsilon 0.01  profit_iteration 0.08  iterations 1542.00  long_return 2.37
# episode  220 score 41.64 average score 142.52 epsilon 0.01  profit_iteration 0.06  iterations 668.00  long_return 1.43
# episode  221 score 196.41 average score 142.82 epsilon 0.01  profit_iteration 0.09  iterations 2122.00  long_return 3.09
# episode  222 score 204.45 average score 142.72 epsilon 0.01  profit_iteration 0.08  iterations 2659.00  long_return 2.38
# episode  223 score 56.30 average score 139.54 epsilon 0.01  profit_iteration 0.09  iterations 625.00  long_return 1.55
# episode  224 score 50.46 average score 139.06 epsilon 0.01  profit_iteration 0.06  iterations 853.00  long_return 1.40
# episode  225 score 126.49 average score 139.47 epsilon 0.01  profit_iteration 0.07  iterations 1692.00  long_return 2.59
# episode  226 score 21.02 average score 138.56 epsilon 0.01  profit_iteration 0.06  iterations 327.00  long_return 1.21
# episode  227 score 46.09 average score 136.04 epsilon 0.01  profit_iteration 0.08  iterations 585.00  long_return 1.44
# episode  228 score 109.35 average score 135.05 epsilon 0.01  profit_iteration 0.08  iterations 1375.00  long_return 2.07
# episode  229 score 167.79 average score 135.04 epsilon 0.01  profit_iteration 0.06  iterations 2575.00  long_return 2.47
# episode  230 score 161.19 average score 136.22 epsilon 0.01  profit_iteration 0.05  iterations 3402.00  long_return 3.06
# episode  231 score 141.93 average score 135.07 epsilon 0.01  profit_iteration 0.10  iterations 1393.00  long_return 2.18
# episode  232 score 25.31 average score 133.60 epsilon 0.01  profit_iteration 0.06  iterations 406.00  long_return 1.30
# episode  233 score 144.94 average score 133.48 epsilon 0.01  profit_iteration 0.04  iterations 3337.00  long_return 3.07
# episode  234 score 219.26 average score 135.51 epsilon 0.01  profit_iteration 0.11  iterations 2017.00  long_return 3.07
# episode  235 score 163.28 average score 135.08 epsilon 0.01  profit_iteration 0.05  iterations 2972.00  long_return 2.67
# episode  236 score 276.17 average score 137.59 epsilon 0.01  profit_iteration 0.12  iterations 2340.00  long_return 4.10
# episode  237 score 147.77 average score 138.92 epsilon 0.01  profit_iteration 0.06  iterations 2591.00  long_return 2.58
# episode  238 score 237.56 average score 140.45 epsilon 0.01  profit_iteration 0.07  iterations 3179.00  long_return 2.85
# episode  239 score 198.30 average score 139.61 epsilon 0.01  profit_iteration 0.06  iterations 3175.00  long_return 2.84
# episode  240 score 40.12 average score 139.90 epsilon 0.01  profit_iteration 0.06  iterations 678.00  long_return 1.40
# episode  241 score 184.32 average score 140.16 epsilon 0.01  profit_iteration 0.09  iterations 2063.00  long_return 2.75
# episode  242 score 19.57 average score 139.63 epsilon 0.01  profit_iteration 0.06  iterations 298.00  long_return 1.19
# episode  243 score 123.62 average score 140.50 epsilon 0.01  profit_iteration 0.04  iterations 2923.00  long_return 2.54
# episode  244 score 89.32 average score 140.11 epsilon 0.01  profit_iteration 0.07  iterations 1311.00  long_return 1.94
# episode  245 score 221.14 average score 137.62 epsilon 0.01  profit_iteration 0.07  iterations 3344.00  long_return 3.06
# episode  246 score 176.38 average score 137.27 epsilon 0.01  profit_iteration 0.06  iterations 2777.00  long_return 2.31
# episode  247 score 98.32 average score 137.17 epsilon 0.01  profit_iteration 0.06  iterations 1571.00  long_return 2.26
# episode  248 score 45.24 average score 136.08 epsilon 0.01  profit_iteration 0.07  iterations 644.00  long_return 1.43
# episode  249 score 38.53 average score 134.77 epsilon 0.01  profit_iteration 0.07  iterations 529.00  long_return 1.38
# episode  250 score 144.33 average score 136.12 epsilon 0.01  profit_iteration 0.04  iterations 3213.00  long_return 2.96
# episode  251 score 175.55 average score 137.52 epsilon 0.01  profit_iteration 0.09  iterations 1895.00  long_return 2.56
# episode  252 score 24.39 average score 136.01 epsilon 0.01  profit_iteration 0.02  iterations 1083.00  long_return 1.62
# episode  253 score 7.92 average score 135.73 epsilon 0.01  profit_iteration 0.04  iterations 165.00  long_return 1.09
# episode  254 score 129.43 average score 136.59 epsilon 0.01  profit_iteration 0.05  iterations 2577.00  long_return 2.50
# episode  255 score 46.40 average score 136.84 epsilon 0.01  profit_iteration 0.06  iterations 813.00  long_return 1.41
# episode  256 score 15.34 average score 134.59 epsilon 0.01  profit_iteration 0.07  iterations 222.00  long_return 1.15
# episode  257 score 264.26 average score 136.46 epsilon 0.01  profit_iteration 0.07  iterations 3495.00  long_return 3.34
# episode  258 score 49.73 average score 136.60 epsilon 0.01  profit_iteration 0.05  iterations 975.00  long_return 1.50
# episode  259 score 156.18 average score 138.14 epsilon 0.01  profit_iteration 0.05  iterations 2934.00  long_return 2.55

# %%
observation_

# %%
len(env._get_observation().flatten())

# %%
env._get_observation().shape

# %%
from utils import plot_learning_curve
import os
x = [i+1 for i in range(n_games)]
filename = 'Phil-deepQ-huber.png'
plot_learning_curve(x, scores, eps_history, filename)
state_dict_path = os.path.join(os.getcwd(),'test-huber.pth')
T.save(agent.Q_eval.state_dict(), state_dict_path)

# %%
import matplotlib.pyplot as plt
plt.scatter(np.arange(len(agent.action_memory)),agent.action_memory)

# %%
agent.Q_eval.load_state_dict(T.load(state_dict_path)) # load saved model

# %%
print(agent.state_memory[-4:],
        agent.new_state_memory[-4:], 
        agent.action_memory[-4:], 
        agent.reward_memory[-4:], 
        agent.terminal_memory[-4:])

# %%
tmp = agent.action_memory
print('mean', np.mean(tmp))
print('max', np.max(tmp))
print('min', np.min(tmp))

# %%
info
