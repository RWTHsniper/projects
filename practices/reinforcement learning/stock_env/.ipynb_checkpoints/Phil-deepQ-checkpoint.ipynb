# %%
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np

class DeepQNetwork(nn.Module):
    """
    For a given observation, compute Q values for each action
        Attributes
    ----------
    lr: float
        learning rate
    input_dims : list
        [8]
    fc1_dims : int
        fully-connected layer 1
    fc2_dims : int
        fully-connected layer 2
    n_actions : int
        the number of actions
    """
    def __init__(self, lr, input_dims, fc1_dims, fc2_dims, n_actions):
        super(DeepQNetwork, self).__init__()
        self.input_dims = input_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
        self.fc1 = nn.Linear(*self.input_dims, self.fc1_dims)
        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
        self.fc3 = nn.Linear(self.fc2_dims, self.n_actions)
        self.optimizer = optim.Adam(self.parameters(), lr=lr)
        self.loss = nn.MSELoss()
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)
    
    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        actions = self.fc3(x)
        
        return actions

class Agent():
    def __init__(self, gamma, epsilon, lr, input_dims, batch_size, n_actions,
                max_mem_size=100000, eps_end=0.01, eps_dec=1e-5):
        self.gamma = gamma
        self.epsilon = epsilon
        self.eps_min = eps_end
        self.eps_dec = eps_dec
        self.lr = lr
        self.action_space = [i for i in range(n_actions)] # list of actions
        self.mem_size = max_mem_size
        self.batch_size = batch_size
        self.mem_cntr = 0
        
        self.Q_eval = DeepQNetwork(self.lr, n_actions=n_actions, input_dims=input_dims, 
                                  fc1_dims=256, fc2_dims=256)
        
        self.state_memory = np.zeros((self.mem_size, *input_dims), dtype= np.float32)
        self.new_state_memory = np.zeros((self.mem_size, *input_dims), dtype=np.float32)
        self.action_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.reward_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)
        
    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size # residual. The memory is finite, so we are reusing
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.reward_memory[index] = reward
        self.action_memory[index] =  action
        self.terminal_memory[index] = done
        
        self.mem_cntr += 1
        
    def choose_action(self, observation):
        if np.random.random() > self.epsilon:
            state = T.tensor([observation]).to(self.Q_eval.device) # [] is used because of the nn library
            actions = self.Q_eval.forward(state)
            action = T.argmax(actions).item() # .item() to get integer
        else:
            action = np.random.choice(self.action_space)
            
        return action
    
    def learn(self):
        if self.mem_cntr < self.batch_size:
            return
        
        self.Q_eval.optimizer.zero_grad()
        
        max_mem = min(self.mem_cntr, self.mem_size) 
        # select samples the number of self.batch_size out of max_mem 
        batch = np.random.choice(max_mem, self.batch_size, replace=False) # Don't select the same thing again
        # array slicing [0,1,2,...,self.batch_size-1]
        batch_index = np.arange(self.batch_size, dtype=np.int32) 
        
        state_batch = T.tensor(self.state_memory[batch]).to(self.Q_eval.device)
        new_state_batch = T.tensor(self.new_state_memory[batch]).to(self.Q_eval.device)
        reward_batch = T.tensor(self.reward_memory[batch]).to(self.Q_eval.device)
        terminal_batch = T.tensor(self.terminal_memory[batch]).to(self.Q_eval.device)
        
        action_batch = self.action_memory[batch]
        
        q_eval = self.Q_eval.forward(state_batch)[batch_index, action_batch]
        q_next = self.Q_eval.forward(new_state_batch)
        q_next[terminal_batch] = 0.0
                                                 
        q_target = reward_batch + self.gamma * T.max(q_next, dim=1)[0]
        
        loss = self.Q_eval.loss(q_target, q_eval).to(self.Q_eval.device)
        loss.backward()
        self.Q_eval.optimizer.step()
        
        self.epsilon = self.epsilon - self.eps_dec if self.epsilon > self.eps_min else self.eps_min

# %%
from env import TradingSPYEnv
import numpy as np
env = TradingSPYEnv(sma_len=[5,25])
num_states = env.observation_space.shape[0]
print("Size of State Space ->  {}".format(num_states))
num_actions = env.action_space.n
print("Size of Action Space ->  {}".format(num_actions))

agent = Agent(gamma=0.99, epsilon=1.0, batch_size=64, n_actions=num_actions, eps_end=0.01, input_dims = [num_states], lr=0.003)
scores, eps_history = [], []
n_games = 1000


for i in range(n_games):
    score = 0
    done = False
    observation = env.reset()
    if observation.dtype == np.float64:
        observation = observation.astype(np.float32)
    while not done:
        action = agent.choose_action(observation)
        observation_, reward, done, info = env.step(action)
        if (observation_ is not None): 
            if (observation_.dtype == np.float64):
                observation_ = observation_.astype(np.float32)
            score += reward
            agent.store_transition(observation, action, reward, observation_, done)
        agent.learn()
        observation = observation_
    scores.append(score)
    eps_history.append(agent.epsilon)
    
    avg_score = np.mean(scores[-100:])
    
    print('episode ', i, 'score %.2f' % score,
         'average score %.2f' % avg_score,
         'epsilon %.2f ' % agent.epsilon)
# Out:
# Size of State Space ->  6
# Size of Action Space ->  3
# C:\Users\golde\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# episode  0 score -2440.21 average score -2440.21 epsilon 0.98
# episode  1 score -571.77 average score -1505.99 epsilon 0.95
# episode  2 score -2454.85 average score -1822.28 epsilon 0.94
# episode  3 score 519.65 average score -1236.80 epsilon 0.92
# episode  4 score -2399.75 average score -1469.39 epsilon 0.90
# episode  5 score -685.56 average score -1338.75 epsilon 0.88
# episode  6 score 12851.51 average score 688.43 epsilon 0.86
# episode  7 score -151.77 average score 583.41 epsilon 0.85
# episode  8 score -328.95 average score 482.03 epsilon 0.83
# episode  9 score -2730.08 average score 160.82 epsilon 0.79
# episode  10 score -2456.97 average score -77.16 epsilon 0.77
# episode  11 score 5855.01 average score 417.19 epsilon 0.76
# episode  12 score 13035.15 average score 1387.80 epsilon 0.75
# episode  13 score 2770.98 average score 1486.60 epsilon 0.74
# episode  14 score -1987.69 average score 1254.98 epsilon 0.73
# episode  15 score 2776.82 average score 1350.10 epsilon 0.72
# episode  16 score -3407.05 average score 1070.26 epsilon 0.67
# episode  17 score 2309.45 average score 1139.11 epsilon 0.64
# episode  18 score 458.93 average score 1103.31 epsilon 0.63
# episode  19 score 1833.92 average score 1139.84 epsilon 0.60
# episode  20 score -2071.99 average score 986.89 epsilon 0.58
# episode  21 score 1725.25 average score 1020.46 epsilon 0.56
# episode  22 score 1231.24 average score 1029.62 epsilon 0.55
# episode  23 score 3239.24 average score 1121.69 epsilon 0.52
# episode  24 score 10312.40 average score 1489.32 epsilon 0.49
# episode  25 score 1840.25 average score 1502.81 epsilon 0.48
# episode  26 score -1314.43 average score 1398.47 epsilon 0.43
# episode  27 score 8348.22 average score 1646.68 epsilon 0.42
# episode  28 score 1453.93 average score 1640.03 epsilon 0.41
# episode  29 score 12940.36 average score 2016.71 epsilon 0.37
# episode  30 score -149.03 average score 1946.85 epsilon 0.36
# episode  31 score 5185.92 average score 2048.07 epsilon 0.34
# episode  32 score -303.77 average score 1976.80 epsilon 0.33
# episode  33 score 5056.45 average score 2067.38 epsilon 0.31
# episode  34 score 14433.05 average score 2420.68 epsilon 0.29
# episode  35 score 9154.33 average score 2607.73 epsilon 0.26
# episode  36 score 17709.94 average score 3015.90 epsilon 0.22
# episode  37 score 39063.97 average score 3964.53 epsilon 0.17
# episode  38 score 5340.98 average score 3999.82 epsilon 0.14
# episode  39 score 9739.88 average score 4143.32 epsilon 0.11
# episode  40 score 3799.99 average score 4134.95 epsilon 0.10
# episode  41 score 3657.20 average score 4123.57 epsilon 0.09
# episode  42 score 593.31 average score 4041.48 epsilon 0.06
# episode  43 score 16890.34 average score 4333.50 epsilon 0.02
# episode  44 score 10240.50 average score 4464.76 epsilon 0.01
# episode  45 score 1708.02 average score 4404.83 epsilon 0.01
# episode  46 score 33601.13 average score 5026.03 epsilon 0.01
# episode  47 score 36460.13 average score 5680.91 epsilon 0.01
# episode  48 score 9309.90 average score 5754.97 epsilon 0.01
# episode  49 score 21455.38 average score 6068.98 epsilon 0.01
# episode  50 score 13771.08 average score 6220.00 epsilon 0.01
# episode  51 score 3536.34 average score 6168.39 epsilon 0.01
# episode  52 score 297.74 average score 6057.62 epsilon 0.01
# episode  53 score 3921.83 average score 6018.07 epsilon 0.01
# episode  54 score 4261.84 average score 5986.14 epsilon 0.01
# episode  55 score 11258.02 average score 6080.28 epsilon 0.01
# episode  56 score 26394.15 average score 6436.66 epsilon 0.01
# episode  57 score 8161.36 average score 6466.40 epsilon 0.01
# episode  58 score 5175.13 average score 6444.51 epsilon 0.01
# episode  59 score 7978.44 average score 6470.08 epsilon 0.01
# episode  60 score 6811.26 average score 6475.67 epsilon 0.01
# episode  61 score 11474.24 average score 6556.30 epsilon 0.01
# episode  62 score 13563.98 average score 6667.53 epsilon 0.01
# episode  63 score 16915.11 average score 6827.65 epsilon 0.01
# episode  64 score 25683.05 average score 7117.73 epsilon 0.01
# episode  65 score 24359.09 average score 7378.96 epsilon 0.01
# episode  66 score 22539.52 average score 7605.24 epsilon 0.01
# episode  67 score 8511.99 average score 7618.57 epsilon 0.01
# episode  68 score 39551.83 average score 8081.37 epsilon 0.01
# episode  69 score 20964.44 average score 8265.42 epsilon 0.01
# episode  70 score 46802.74 average score 8808.20 epsilon 0.01
# episode  71 score 33525.47 average score 9151.49 epsilon 0.01
# episode  72 score 17593.72 average score 9267.14 epsilon 0.01
# episode  73 score 24537.89 average score 9473.50 epsilon 0.01
# episode  74 score 49605.32 average score 10008.59 epsilon 0.01
# episode  75 score 31756.22 average score 10294.75 epsilon 0.01
# episode  76 score 7792.59 average score 10262.25 epsilon 0.01
# episode  77 score 7176.90 average score 10222.69 epsilon 0.01
# episode  78 score 39293.04 average score 10590.67 epsilon 0.01
# episode  79 score 4887.76 average score 10519.39 epsilon 0.01
# episode  80 score 27726.35 average score 10731.82 epsilon 0.01
# episode  81 score 43453.94 average score 11130.87 epsilon 0.01
# episode  82 score 8995.28 average score 11105.14 epsilon 0.01
# episode  83 score 20273.10 average score 11214.28 epsilon 0.01
# episode  84 score 5158.63 average score 11143.04 epsilon 0.01
# episode  85 score 23780.54 average score 11289.99 epsilon 0.01
# episode  86 score 18122.57 average score 11368.52 epsilon 0.01
# episode  87 score 31120.17 average score 11592.97 epsilon 0.01
# episode  88 score 28236.93 average score 11779.98 epsilon 0.01
# episode  89 score 43250.00 average score 12129.65 epsilon 0.01
# episode  90 score 26007.44 average score 12282.15 epsilon 0.01
# episode  91 score 11024.87 average score 12268.49 epsilon 0.01
# episode  92 score 33747.09 average score 12499.44 epsilon 0.01
# episode  93 score 38614.44 average score 12777.26 epsilon 0.01
# episode  94 score 12828.60 average score 12777.80 epsilon 0.01
# episode  95 score 29047.05 average score 12947.27 epsilon 0.01
# episode  96 score 14415.46 average score 12962.41 epsilon 0.01
# episode  97 score 7131.61 average score 12902.91 epsilon 0.01
# episode  98 score 34002.86 average score 13116.04 epsilon 0.01
# episode  99 score 27918.25 average score 13264.06 epsilon 0.01
# episode  100 score 19493.26 average score 13483.40 epsilon 0.01
# episode  101 score 13227.64 average score 13621.39 epsilon 0.01
# episode  102 score 42112.94 average score 14067.07 epsilon 0.01
# episode  103 score 9083.46 average score 14152.71 epsilon 0.01
# episode  104 score 6474.68 average score 14241.45 epsilon 0.01
# episode  105 score 29110.68 average score 14539.41 epsilon 0.01
# episode  106 score 5791.30 average score 14468.81 epsilon 0.01
# episode  107 score 3469.17 average score 14505.02 epsilon 0.01
# episode  108 score 2331.80 average score 14531.63 epsilon 0.01
# episode  109 score 18316.93 average score 14742.10 epsilon 0.01
# episode  110 score 27816.26 average score 15044.83 epsilon 0.01
# episode  111 score 13969.63 average score 15125.98 epsilon 0.01
# episode  112 score 23832.75 average score 15233.95 epsilon 0.01
# episode  113 score 8416.54 average score 15290.41 epsilon 0.01
# episode  114 score 28492.44 average score 15595.21 epsilon 0.01
# episode  115 score 28209.68 average score 15849.54 epsilon 0.01
# episode  116 score 29227.69 average score 16175.89 epsilon 0.01
# episode  117 score 45892.00 average score 16611.71 epsilon 0.01
# episode  118 score 8575.87 average score 16692.88 epsilon 0.01
# episode  119 score 12420.56 average score 16798.75 epsilon 0.01
# episode  120 score 18276.86 average score 17002.24 epsilon 0.01
# episode  121 score 30430.30 average score 17289.29 epsilon 0.01
# episode  122 score 6850.71 average score 17345.48 epsilon 0.01
# episode  123 score 20354.84 average score 17516.64 epsilon 0.01
# episode  124 score 45357.07 average score 17867.08 epsilon 0.01
# episode  125 score 28796.21 average score 18136.64 epsilon 0.01
# episode  126 score 30325.53 average score 18453.04 epsilon 0.01
# episode  127 score 22416.82 average score 18593.73 epsilon 0.01
# episode  128 score 48908.74 average score 19068.28 epsilon 0.01
# episode  129 score 41473.30 average score 19353.61 epsilon 0.01
# episode  130 score 12818.88 average score 19483.28 epsilon 0.01
# episode  131 score 24296.10 average score 19674.39 epsilon 0.01
# episode  132 score 38238.52 average score 20059.81 epsilon 0.01
# episode  133 score 7631.58 average score 20085.56 epsilon 0.01
# episode  134 score 17551.33 average score 20116.74 epsilon 0.01
# episode  135 score 8345.38 average score 20108.65 epsilon 0.01
# episode  136 score 12302.27 average score 20054.58 epsilon 0.01
# episode  137 score 21218.71 average score 19876.12 epsilon 0.01
# episode  138 score 18631.49 average score 20009.03 epsilon 0.01
# episode  139 score 6966.89 average score 19981.30 epsilon 0.01
# episode  140 score 30571.59 average score 20249.02 epsilon 0.01
# episode  141 score 26488.04 average score 20477.32 epsilon 0.01
# episode  142 score 32679.78 average score 20798.19 epsilon 0.01
# episode  143 score 6751.54 average score 20696.80 epsilon 0.01
# episode  144 score 8434.93 average score 20678.75 epsilon 0.01
# episode  145 score 28476.22 average score 20946.43 epsilon 0.01
# episode  146 score 4038.31 average score 20650.80 epsilon 0.01
# episode  147 score 14603.27 average score 20432.23 epsilon 0.01
# episode  148 score 27216.81 average score 20611.30 epsilon 0.01
# episode  149 score 20169.41 average score 20598.44 epsilon 0.01
# episode  150 score 7516.30 average score 20535.89 epsilon 0.01
# episode  151 score 18864.38 average score 20689.17 epsilon 0.01
# episode  152 score 15663.87 average score 20842.83 epsilon 0.01
# episode  153 score 22975.81 average score 21033.37 epsilon 0.01
# episode  154 score 22917.27 average score 21219.93 epsilon 0.01
# episode  155 score 40794.92 average score 21515.30 epsilon 0.01
# episode  156 score 2241.78 average score 21273.77 epsilon 0.01
# episode  157 score 34866.72 average score 21540.83 epsilon 0.01
# episode  158 score 25460.92 average score 21743.68 epsilon 0.01
# episode  159 score 8164.80 average score 21745.55 epsilon 0.01
# episode  160 score 38953.95 average score 22066.98 epsilon 0.01
# episode  161 score 36015.91 average score 22312.39 epsilon 0.01
# episode  162 score 35940.33 average score 22536.16 epsilon 0.01
# episode  163 score 12936.97 average score 22496.37 epsilon 0.01
# episode  164 score 29920.35 average score 22538.75 epsilon 0.01
# episode  165 score 8947.46 average score 22384.63 epsilon 0.01
# episode  166 score 45661.29 average score 22615.85 epsilon 0.01
# episode  167 score 18187.27 average score 22712.60 epsilon 0.01
# episode  168 score 12656.80 average score 22443.65 epsilon 0.01
# episode  169 score 17076.65 average score 22404.77 epsilon 0.01
# episode  170 score 22181.19 average score 22158.56 epsilon 0.01
# episode  171 score 41561.58 average score 22238.92 epsilon 0.01
# episode  172 score 9350.02 average score 22156.48 epsilon 0.01
# episode  173 score 8682.57 average score 21997.93 epsilon 0.01
# episode  174 score 19849.02 average score 21700.37 epsilon 0.01
# episode  175 score 28369.62 average score 21666.50 epsilon 0.01
# episode  176 score 2254.23 average score 21611.12 epsilon 0.01
# episode  177 score 8491.16 average score 21624.26 epsilon 0.01
# episode  178 score 20723.96 average score 21438.57 epsilon 0.01
# episode  179 score 29205.97 average score 21681.75 epsilon 0.01
# episode  180 score 15991.54 average score 21564.40 epsilon 0.01
# episode  181 score 18385.68 average score 21313.72 epsilon 0.01
# episode  182 score 24624.40 average score 21470.01 epsilon 0.01
# episode  183 score 20277.97 average score 21470.06 epsilon 0.01
# episode  184 score 8020.00 average score 21498.67 epsilon 0.01
# episode  185 score 13394.05 average score 21394.81 epsilon 0.01
# episode  186 score 3701.51 average score 21250.60 epsilon 0.01
# episode  187 score 33086.42 average score 21270.26 epsilon 0.01
# episode  188 score 4115.54 average score 21029.05 epsilon 0.01
# episode  189 score 17615.22 average score 20772.70 epsilon 0.01
# episode  190 score 7522.47 average score 20587.85 epsilon 0.01
# episode  191 score 47160.19 average score 20949.20 epsilon 0.01
# episode  192 score 19950.03 average score 20811.23 epsilon 0.01
# episode  193 score 7301.86 average score 20498.10 epsilon 0.01
# episode  194 score 3570.74 average score 20405.53 epsilon 0.01
# episode  195 score 26067.26 average score 20375.73 epsilon 0.01
# episode  196 score 25790.28 average score 20489.48 epsilon 0.01
# episode  197 score 21762.94 average score 20635.79 epsilon 0.01
# episode  198 score 19853.62 average score 20494.30 epsilon 0.01
# episode  199 score 5076.48 average score 20265.88 epsilon 0.01
# episode  200 score 2829.23 average score 20099.24 epsilon 0.01
# episode  201 score 31381.35 average score 20280.78 epsilon 0.01
# episode  202 score 5715.39 average score 19916.80 epsilon 0.01
# episode  203 score 2893.38 average score 19854.90 epsilon 0.01
# episode  204 score 18862.34 average score 19978.78 epsilon 0.01
# episode  205 score 9239.23 average score 19780.06 epsilon 0.01
# episode  206 score 37732.69 average score 20099.48 epsilon 0.01
# episode  207 score 2407.43 average score 20088.86 epsilon 0.01
# episode  208 score 21668.48 average score 20282.23 epsilon 0.01
# episode  209 score 5425.15 average score 20153.31 epsilon 0.01
# episode  210 score 26341.60 average score 20138.56 epsilon 0.01
# episode  211 score 26092.62 average score 20259.79 epsilon 0.01
# episode  212 score 28709.04 average score 20308.55 epsilon 0.01
# episode  213 score 14798.02 average score 20372.37 epsilon 0.01
# episode  214 score 32181.88 average score 20409.26 epsilon 0.01
# episode  215 score 23248.48 average score 20359.65 epsilon 0.01
# episode  216 score 10606.44 average score 20173.44 epsilon 0.01
# episode  217 score 24540.78 average score 19959.93 epsilon 0.01
# episode  218 score 8542.48 average score 19959.59 epsilon 0.01
# episode  219 score 23324.99 average score 20068.64 epsilon 0.01
# episode  220 score 10040.96 average score 19986.28 epsilon 0.01
# episode  221 score 7718.21 average score 19759.16 epsilon 0.01
# episode  222 score 41728.82 average score 20107.94 epsilon 0.01
# episode  223 score 7402.82 average score 19978.42 epsilon 0.01
# episode  224 score 3004.28 average score 19554.89 epsilon 0.01
# episode  225 score 1785.34 average score 19284.78 epsilon 0.01
# episode  226 score 16499.30 average score 19146.52 epsilon 0.01
# episode  227 score 7969.83 average score 19002.05 epsilon 0.01
# episode  228 score 24119.18 average score 18754.15 epsilon 0.01
# episode  229 score 6954.73 average score 18408.97 epsilon 0.01
# episode  230 score 11516.00 average score 18395.94 epsilon 0.01
# episode  231 score 15435.91 average score 18307.34 epsilon 0.01
# episode  232 score 21567.20 average score 18140.62 epsilon 0.01
# episode  233 score 26289.96 average score 18327.21 epsilon 0.01
# episode  234 score 6609.05 average score 18217.79 epsilon 0.01
# episode  235 score 7958.55 average score 18213.92 epsilon 0.01
# episode  236 score 21514.91 average score 18306.04 epsilon 0.01
# episode  237 score 19973.35 average score 18293.59 epsilon 0.01
# episode  238 score 20457.32 average score 18311.85 epsilon 0.01
# episode  239 score 44281.27 average score 18684.99 epsilon 0.01
# episode  240 score 19115.02 average score 18570.43 epsilon 0.01
# episode  241 score 2768.79 average score 18333.23 epsilon 0.01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-1868e151d38c> in <module>
#      26             score += reward
#      27             agent.store_transition(observation, action, reward, observation_, done)
# ---> 28         agent.learn()
#      29         observation = observation_
#      30     scores.append(score)
#
# <ipython-input-1-a845ef785aee> in learn(self)
#     103         action_batch = self.action_memory[batch]
#     104
# --> 105         q_eval = self.Q_eval.forward(state_batch)[batch_index, action_batch]
#     106         q_next = self.Q_eval.forward(new_state_batch)
#     107         q_next[terminal_batch] = 0.0
#
# <ipython-input-1-a845ef785aee> in forward(self, state)
#      36
#      37     def forward(self, state):
# ---> 38         x = F.relu(self.fc1(state))
#      39         x = F.relu(self.fc2(x))
#      40         actions = self.fc3(x)
#
# ~\Anaconda3\lib\site-packages\torch\nn\functional.py in relu(input, inplace)
#    1117         result = torch.relu_(input)
#    1118     else:
# -> 1119         result = torch.relu(input)
#    1120     return result
#    1121
#
# KeyboardInterrupt:

# %%
from utils import plot_learning_curve
import os
x = [i+1 for i in range(n_games)]
filename = 'lunar_lander_2020.png'
#plot_learning_curve(x, scores, eps_history, filename)
state_dict_path = os.path.join(os.getcwd(),'test.pth')
T.save(agent.Q_eval.state_dict(), state_dict_path)

# %%
import matplotlib.pyplot as plt
plt.scatter(np.arange(len(agent.action_memory)),agent.action_memory)

# %%
agent.Q_eval.load_state_dict(T.load(state_dict_path)) # load saved model
