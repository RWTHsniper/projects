# %%
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np

class DeepQNetwork(nn.Module):
    """
    For a given observation, compute Q values for each action
        Attributes
    ----------
    lr: float
        learning rate
    input_dims : list
        [8]
    fc1_dims : int
        fully-connected layer 1
    fc2_dims : int
        fully-connected layer 2
    n_actions : int
        the number of actions
    """
    def __init__(self, lr, input_dims, fc1_dims, fc2_dims, n_actions, weight_decay=1e-5,p=0.5):
        super(DeepQNetwork, self).__init__()
        self.input_dims = input_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
        self.fc1 = nn.Linear(*self.input_dims, self.fc1_dims)
        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
        self.fc3 = nn.Linear(self.fc2_dims, self.n_actions)
#        self.dropout = nn.Dropout(p) 
        self.optimizer = optim.Adam(self.parameters(), lr=lr, weight_decay=weight_decay)
#        self.loss = nn.MSELoss()
        self.loss = nn.SmoothL1Loss() # Huber loss
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)
    
    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
#        x = self.dropout(x) # dropout for regularization
        actions = self.fc3(x)
        
        return actions

class Agent():
    def __init__(self, gamma, epsilon, lr, input_dims, batch_size, n_actions,
                max_mem_size=100000, eps_end=0.01, eps_dec=1e-5, weight_decay=1e-5):
        self.gamma = gamma
        self.epsilon = epsilon
        self.eps_min = eps_end
        self.eps_dec = eps_dec
        self.lr = lr
        self.action_space = [i for i in range(n_actions)] # list of actions
        self.mem_size = max_mem_size
        self.batch_size = batch_size
        self.mem_cntr = 0
        
        self.Q_eval = DeepQNetwork(self.lr, n_actions=n_actions, input_dims=input_dims, 
                                  fc1_dims=32, fc2_dims=32, weight_decay=weight_decay)
        
        self.state_memory = np.zeros((self.mem_size, *input_dims), dtype= np.float32)
        self.new_state_memory = np.zeros((self.mem_size, *input_dims), dtype=np.float32)
        self.action_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.reward_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)
        
    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size # residual. The memory is finite, so we are reusing
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.reward_memory[index] = reward
        self.action_memory[index] =  action
        self.terminal_memory[index] = done
        
        self.mem_cntr += 1
        
    def choose_action(self, observation):
        if np.random.random() > self.epsilon:
            state = T.tensor([observation]).to(self.Q_eval.device) # [] is used because of the nn library. torch.Size([1, 6])
            actions = self.Q_eval.forward(state)
            action = T.argmax(actions).item() # .item() to get integer
        else:
            action = np.random.choice(self.action_space)
            
        return action
    
    def learn(self):
        if self.mem_cntr < self.batch_size:
            return
        
        self.Q_eval.optimizer.zero_grad()
        
        max_mem = min(self.mem_cntr, self.mem_size) 
        # select samples the number of self.batch_size out of max_mem 
        batch = np.random.choice(max_mem, self.batch_size, replace=False) # Don't select the same thing again
        # array slicing [0,1,2,...,self.batch_size-1]
        batch_index = np.arange(self.batch_size, dtype=np.int32) 
        
        state_batch = T.tensor(self.state_memory[batch]).to(self.Q_eval.device)
        new_state_batch = T.tensor(self.new_state_memory[batch]).to(self.Q_eval.device)
        reward_batch = T.tensor(self.reward_memory[batch]).to(self.Q_eval.device)
        terminal_batch = T.tensor(self.terminal_memory[batch]).to(self.Q_eval.device)
        
        action_batch = self.action_memory[batch]
        
        q_eval = self.Q_eval.forward(state_batch)[batch_index, action_batch]
        q_next = self.Q_eval.forward(new_state_batch)
        q_next[terminal_batch] = 0.0
                                                 
        q_target = reward_batch + self.gamma * T.max(q_next, dim=1)[0]
        
        loss = self.Q_eval.loss(q_target, q_eval).to(self.Q_eval.device)
        loss.backward()
        self.Q_eval.optimizer.step()
        
        self.epsilon = self.epsilon - self.eps_dec if self.epsilon > self.eps_min else self.eps_min

# %%
from env import TradingSPYEnv
#from env2 import TradingSPYEnv
import numpy as np
env = TradingSPYEnv(init_invest=100.0, sma_len=[5,25,50,100])
num_states = len(env.reset())
print("Size of State Space ->  {}".format(num_states))
num_actions = env.action_space.n
print("Size of Action Space ->  {}".format(num_actions))

agent = Agent(gamma=0.99, epsilon=1.0, batch_size=64, n_actions=num_actions, eps_end=0.01, input_dims = [num_states], lr=0.003,
              weight_decay=1e-5)
scores, eps_history = [], []
n_games = 1000


for i in range(n_games):
    score = 0.0
    done = False
    observation = env.reset()
    if observation.dtype == np.float64:
        observation = observation.astype(np.float32)
    while not done:
        action = agent.choose_action(observation)
        observation_, reward, done, info = env.step(action)
        if (observation_ is not None): 
            if (observation_.dtype == np.float64):
                observation_ = observation_.astype(np.float32)
            score += reward
            agent.store_transition(observation, action, reward, observation_, done)
        agent.learn()
        observation = observation_
    scores.append(score)
    eps_history.append(agent.epsilon)
    
    avg_score = np.mean(scores[-100:])
    
    print('episode ', i, 'score %.2f' % score,
         'average score %.2f' % avg_score,
         'epsilon %.2f ' % agent.epsilon,
         'profit_iteration %.2f ' % info['profit_iteration'],
         'iterations %.2f ' % info['iterations'],
         'long_return %.2f ' % info['long_return']
         )
# Out:
# C:\Users\golde\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# Size of State Space ->  8
# Size of Action Space ->  3
# episode  0 score -10.09 average score -10.09 epsilon 1.00  profit_iteration -0.10  iterations 104.00  long_return 1.07
# episode  1 score -32.95 average score -21.52 epsilon 0.97  profit_iteration -0.01  iterations 2866.00  long_return 2.40
# episode  2 score -9.52 average score -17.52 epsilon 0.96  profit_iteration -0.01  iterations 1058.00  long_return 1.60
# episode  3 score 6.13 average score -11.61 epsilon 0.96  profit_iteration 0.02  iterations 306.00  long_return 1.19
# episode  4 score -37.73 average score -16.83 epsilon 0.93  profit_iteration -0.02  iterations 2445.00  long_return 3.74
# episode  5 score -67.57 average score -25.29 epsilon 0.89  profit_iteration -0.02  iterations 3900.00  long_return 4.04
# episode  6 score -32.18 average score -26.27 epsilon 0.89  profit_iteration -0.06  iterations 520.00  long_return 1.39
# episode  7 score 4.42 average score -22.44 epsilon 0.85  profit_iteration 0.00  iterations 3868.00  long_return 4.43
# episode  8 score -1.86 average score -20.15 epsilon 0.85  profit_iteration -0.00  iterations 336.00  long_return 1.20
# episode  9 score -53.61 average score -23.50 epsilon 0.81  profit_iteration -0.01  iterations 3796.00  long_return 3.73
# episode  10 score -19.90 average score -23.17 epsilon 0.80  profit_iteration -0.02  iterations 996.00  long_return 1.52
# episode  11 score 95.98 average score -13.24 epsilon 0.76  profit_iteration 0.03  iterations 3785.00  long_return 3.82
# episode  12 score -47.29 average score -15.86 epsilon 0.74  profit_iteration -0.02  iterations 2258.00  long_return 3.47
# episode  13 score 37.24 average score -12.07 epsilon 0.70  profit_iteration 0.01  iterations 3669.00  long_return 3.45
# episode  14 score -25.98 average score -12.99 epsilon 0.66  profit_iteration -0.01  iterations 3720.00  long_return 3.72
# episode  15 score 69.99 average score -7.81 epsilon 0.63  profit_iteration 0.02  iterations 3065.00  long_return 2.69
# episode  16 score -19.14 average score -8.47 epsilon 0.62  profit_iteration -0.01  iterations 1682.00  long_return 2.60
# episode  17 score -9.59 average score -8.54 epsilon 0.60  profit_iteration -0.00  iterations 2069.00  long_return 2.70
# episode  18 score 28.66 average score -6.58 epsilon 0.59  profit_iteration 0.05  iterations 580.00  long_return 1.41
# episode  19 score 151.19 average score 1.31 epsilon 0.55  profit_iteration 0.04  iterations 4036.00  long_return 3.84
# episode  20 score 10.66 average score 1.75 epsilon 0.54  profit_iteration 0.02  iterations 485.00  long_return 1.32
# episode  21 score 36.34 average score 3.33 epsilon 0.52  profit_iteration 0.01  iterations 2733.00  long_return 2.36
# episode  22 score -12.20 average score 2.65 epsilon 0.52  profit_iteration -0.07  iterations 184.00  long_return 1.10
# episode  23 score -34.28 average score 1.11 epsilon 0.48  profit_iteration -0.01  iterations 3762.00  long_return 3.76
# episode  24 score 51.74 average score 3.14 epsilon 0.45  profit_iteration 0.02  iterations 3207.00  long_return 3.05
# episode  25 score 84.83 average score 6.28 epsilon 0.43  profit_iteration 0.06  iterations 1390.00  long_return 2.11
# episode  26 score -34.47 average score 4.77 epsilon 0.41  profit_iteration -0.01  iterations 2706.00  long_return 2.21
# episode  27 score 7.67 average score 4.87 epsilon 0.40  profit_iteration 0.03  iterations 278.00  long_return 1.16
# episode  28 score 52.35 average score 6.51 epsilon 0.38  profit_iteration 0.03  iterations 1792.00  long_return 2.41
# episode  29 score 14.39 average score 6.77 epsilon 0.37  profit_iteration 0.01  iterations 1504.00  long_return 2.27
# episode  30 score 114.12 average score 10.24 epsilon 0.33  profit_iteration 0.03  iterations 3540.00  long_return 3.24
# episode  31 score 67.11 average score 12.01 epsilon 0.31  profit_iteration 0.02  iterations 2876.00  long_return 2.41
# episode  32 score -30.67 average score 10.72 epsilon 0.28  profit_iteration -0.01  iterations 2525.00  long_return 2.66
# episode  33 score 11.92 average score 10.76 epsilon 0.26  profit_iteration 0.00  iterations 2313.00  long_return 3.67
# episode  34 score -6.78 average score 10.25 epsilon 0.25  profit_iteration -0.01  iterations 1025.00  long_return 1.55
# episode  35 score 9.91 average score 10.24 epsilon 0.21  profit_iteration 0.00  iterations 3573.00  long_return 3.33
# episode  36 score 58.15 average score 11.54 epsilon 0.17  profit_iteration 0.01  iterations 3964.00  long_return 4.69
# episode  37 score 47.78 average score 12.49 epsilon 0.15  profit_iteration 0.03  iterations 1718.00  long_return 2.74
# episode  38 score 158.61 average score 16.24 epsilon 0.12  profit_iteration 0.05  iterations 3259.00  long_return 2.91
# episode  39 score -14.70 average score 15.47 epsilon 0.09  profit_iteration -0.00  iterations 3288.00  long_return 2.97
# episode  40 score -47.98 average score 13.92 epsilon 0.05  profit_iteration -0.01  iterations 3567.00  long_return 3.39
# episode  41 score 2.39 average score 13.64 epsilon 0.04  profit_iteration 0.00  iterations 1187.00  long_return 1.73
# episode  42 score 6.18 average score 13.47 epsilon 0.04  profit_iteration 0.04  iterations 130.00  long_return 1.03
# episode  43 score 13.04 average score 13.46 epsilon 0.03  profit_iteration 0.02  iterations 583.00  long_return 1.42
# episode  44 score 438.82 average score 22.91 epsilon 0.01  profit_iteration 0.12  iterations 3516.00  long_return 3.37
# episode  45 score 119.76 average score 25.02 epsilon 0.01  profit_iteration 0.08  iterations 1516.00  long_return 2.30
# episode  46 score 23.67 average score 24.99 epsilon 0.01  profit_iteration 0.02  iterations 969.00  long_return 1.50
# episode  47 score 32.85 average score 25.15 epsilon 0.01  profit_iteration 0.06  iterations 577.00  long_return 1.42
# episode  48 score 190.30 average score 28.52 epsilon 0.01  profit_iteration 0.09  iterations 1990.00  long_return 3.01
# episode  49 score 58.10 average score 29.12 epsilon 0.01  profit_iteration 0.02  iterations 2799.00  long_return 2.27
# episode  50 score 184.70 average score 32.17 epsilon 0.01  profit_iteration 0.07  iterations 2583.00  long_return 2.50
# episode  51 score 14.31 average score 31.82 epsilon 0.01  profit_iteration 0.07  iterations 190.00  long_return 1.10
# episode  52 score 54.99 average score 32.26 epsilon 0.01  profit_iteration 0.05  iterations 1168.00  long_return 1.70
# episode  53 score 74.41 average score 33.04 epsilon 0.01  profit_iteration 0.03  iterations 2628.00  long_return 2.47
# episode  54 score 199.96 average score 36.08 epsilon 0.01  profit_iteration 0.06  iterations 3277.00  long_return 2.99
# episode  55 score 22.62 average score 35.84 epsilon 0.01  profit_iteration 0.02  iterations 1336.00  long_return 1.99
# episode  56 score 248.93 average score 39.57 epsilon 0.01  profit_iteration 0.07  iterations 3383.00  long_return 3.06
# episode  57 score 81.98 average score 40.31 epsilon 0.01  profit_iteration 0.03  iterations 2630.00  long_return 2.55
# episode  58 score 395.04 average score 46.32 epsilon 0.01  profit_iteration 0.10  iterations 3737.00  long_return 3.63
# episode  59 score 100.91 average score 47.23 epsilon 0.01  profit_iteration 0.06  iterations 1740.00  long_return 2.84
# episode  60 score 85.43 average score 47.85 epsilon 0.01  profit_iteration 0.05  iterations 1682.00  long_return 2.60
# episode  61 score 169.17 average score 49.81 epsilon 0.01  profit_iteration 0.06  iterations 2658.00  long_return 2.37
# episode  62 score 4.56 average score 49.09 epsilon 0.01  profit_iteration 0.03  iterations 114.00  long_return 0.97
# episode  63 score 37.06 average score 48.90 epsilon 0.01  profit_iteration 0.05  iterations 735.00  long_return 1.40
# episode  64 score 85.39 average score 49.47 epsilon 0.01  profit_iteration 0.05  iterations 1629.00  long_return 2.40
# episode  65 score 59.70 average score 49.62 epsilon 0.01  profit_iteration 0.04  iterations 1405.00  long_return 2.18
# episode  66 score 213.57 average score 52.07 epsilon 0.01  profit_iteration 0.05  iterations 3982.00  long_return 4.23
# episode  67 score 136.30 average score 53.31 epsilon 0.01  profit_iteration 0.07  iterations 1930.00  long_return 2.64
# episode  68 score 140.49 average score 54.57 epsilon 0.01  profit_iteration 0.07  iterations 1945.00  long_return 2.74
# episode  69 score 241.20 average score 57.24 epsilon 0.01  profit_iteration 0.07  iterations 3202.00  long_return 3.00
# episode  70 score 54.81 average score 57.20 epsilon 0.01  profit_iteration 0.06  iterations 867.00  long_return 1.49
# episode  71 score 2.69 average score 56.44 epsilon 0.01  profit_iteration 0.18  iterations 11.00  long_return 1.02
# episode  72 score 123.33 average score 57.36 epsilon 0.01  profit_iteration 0.03  iterations 4012.00  long_return 4.38
# episode  73 score 119.22 average score 58.20 epsilon 0.01  profit_iteration 0.04  iterations 2992.00  long_return 2.72
# episode  74 score 98.79 average score 58.74 epsilon 0.01  profit_iteration 0.06  iterations 1532.00  long_return 2.38
# episode  75 score 107.05 average score 59.37 epsilon 0.01  profit_iteration 0.03  iterations 3016.00  long_return 2.86
# episode  76 score 105.54 average score 59.97 epsilon 0.01  profit_iteration 0.05  iterations 2084.00  long_return 2.80
# episode  77 score 150.15 average score 61.13 epsilon 0.01  profit_iteration 0.06  iterations 2471.00  long_return 2.79
# episode  78 score 153.04 average score 62.29 epsilon 0.01  profit_iteration 0.11  iterations 1423.00  long_return 2.26
# episode  79 score 141.22 average score 63.28 epsilon 0.01  profit_iteration 0.07  iterations 2005.00  long_return 2.95
# episode  80 score 79.24 average score 63.48 epsilon 0.01  profit_iteration 0.07  iterations 1166.00  long_return 1.70
# episode  81 score 98.36 average score 63.90 epsilon 0.01  profit_iteration 0.06  iterations 1557.00  long_return 2.24
# episode  82 score 81.89 average score 64.12 epsilon 0.01  profit_iteration 0.03  iterations 2900.00  long_return 2.48
# episode  83 score 18.50 average score 63.58 epsilon 0.01  profit_iteration 0.06  iterations 308.00  long_return 1.20
# episode  84 score 122.77 average score 64.27 epsilon 0.01  profit_iteration 0.07  iterations 1693.00  long_return 2.64
# episode  85 score 164.72 average score 65.44 epsilon 0.01  profit_iteration 0.05  iterations 3469.00  long_return 3.27
# episode  86 score 211.68 average score 67.12 epsilon 0.01  profit_iteration 0.10  iterations 2152.00  long_return 2.95
# episode  87 score 158.08 average score 68.15 epsilon 0.01  profit_iteration 0.05  iterations 2888.00  long_return 2.46
# episode  88 score 45.28 average score 67.90 epsilon 0.01  profit_iteration 0.07  iterations 612.00  long_return 1.52
# episode  89 score 120.32 average score 68.48 epsilon 0.01  profit_iteration 0.07  iterations 1672.00  long_return 2.52
# episode  90 score 76.52 average score 68.57 epsilon 0.01  profit_iteration 0.06  iterations 1207.00  long_return 1.79
# episode  91 score 108.75 average score 69.01 epsilon 0.01  profit_iteration 0.07  iterations 1576.00  long_return 2.25
# episode  92 score 51.01 average score 68.81 epsilon 0.01  profit_iteration 0.05  iterations 1024.00  long_return 1.55
# episode  93 score 139.06 average score 69.56 epsilon 0.01  profit_iteration 0.04  iterations 3163.00  long_return 2.81
# episode  94 score 14.49 average score 68.98 epsilon 0.01  profit_iteration 0.04  iterations 337.00  long_return 1.20
# episode  95 score 155.24 average score 69.88 epsilon 0.01  profit_iteration 0.05  iterations 2857.00  long_return 2.51
# episode  96 score 45.55 average score 69.63 epsilon 0.01  profit_iteration 0.06  iterations 728.00  long_return 1.41
# episode  97 score 236.96 average score 71.33 epsilon 0.01  profit_iteration 0.06  iterations 3623.00  long_return 3.21
# episode  98 score 122.45 average score 71.85 epsilon 0.01  profit_iteration 0.08  iterations 1542.00  long_return 2.37
# episode  99 score 231.72 average score 73.45 epsilon 0.01  profit_iteration 0.06  iterations 3987.00  long_return 4.19
# episode  100 score 265.10 average score 76.20 epsilon 0.01  profit_iteration 0.07  iterations 3985.00  long_return 4.17
# episode  101 score 115.57 average score 77.69 epsilon 0.01  profit_iteration 0.04  iterations 2868.00  long_return 2.40
# episode  102 score 142.57 average score 79.21 epsilon 0.01  profit_iteration 0.09  iterations 1491.00  long_return 2.24
# episode  103 score 108.82 average score 80.23 epsilon 0.01  profit_iteration 0.04  iterations 3030.00  long_return 2.86
# episode  104 score 79.10 average score 81.40 epsilon 0.01  profit_iteration 0.08  iterations 1008.00  long_return 1.53
# episode  105 score 82.09 average score 82.90 epsilon 0.01  profit_iteration 0.07  iterations 1133.00  long_return 1.65
# episode  106 score 289.20 average score 86.11 epsilon 0.01  profit_iteration 0.08  iterations 3563.00  long_return 3.35
# episode  107 score 274.47 average score 88.81 epsilon 0.01  profit_iteration 0.07  iterations 3742.00  long_return 3.71
# episode  108 score -1.43 average score 88.82 epsilon 0.01  profit_iteration -0.02  iterations 121.00  long_return 1.00
# episode  109 score 124.84 average score 90.60 epsilon 0.01  profit_iteration 0.08  iterations 1529.00  long_return 2.36
# episode  110 score 102.08 average score 91.82 epsilon 0.01  profit_iteration 0.04  iterations 2804.00  long_return 2.29
# episode  111 score 36.78 average score 91.23 epsilon 0.01  profit_iteration 0.06  iterations 555.00  long_return 1.38
# episode  112 score 3.79 average score 91.74 epsilon 0.01  profit_iteration 0.06  iterations 52.00  long_return 1.04
# episode  113 score 55.16 average score 91.92 epsilon 0.01  profit_iteration 0.05  iterations 1098.00  long_return 1.64
# episode  114 score 190.35 average score 94.08 epsilon 0.01  profit_iteration 0.06  iterations 3038.00  long_return 2.82
# episode  115 score 121.47 average score 94.60 epsilon 0.01  profit_iteration 0.08  iterations 1518.00  long_return 2.35
# episode  116 score 232.19 average score 97.11 epsilon 0.01  profit_iteration 0.07  iterations 3262.00  long_return 2.92
# episode  117 score 126.27 average score 98.47 epsilon 0.01  profit_iteration 0.07  iterations 1770.00  long_return 2.46
# episode  118 score 160.86 average score 99.79 epsilon 0.01  profit_iteration 0.08  iterations 1893.00  long_return 2.56
# episode  119 score 202.12 average score 100.30 epsilon 0.01  profit_iteration 0.06  iterations 3091.00  long_return 2.74
# episode  120 score 125.71 average score 101.45 epsilon 0.01  profit_iteration 0.07  iterations 1856.00  long_return 2.46
# episode  121 score 16.57 average score 101.25 epsilon 0.01  profit_iteration 0.05  iterations 286.00  long_return 1.18
# episode  122 score 177.70 average score 103.15 epsilon 0.01  profit_iteration 0.08  iterations 2222.00  long_return 3.17
# episode  123 score 16.27 average score 103.66 epsilon 0.01  profit_iteration 0.05  iterations 307.00  long_return 1.21
# episode  124 score 20.53 average score 103.35 epsilon 0.01  profit_iteration 0.07  iterations 278.00  long_return 1.16
# episode  125 score 0.00 average score 102.50 epsilon 0.01  profit_iteration -0.01  iterations 87.00  long_return 1.02
# episode  126 score 53.50 average score 103.38 epsilon 0.01  profit_iteration 0.08  iterations 674.00  long_return 1.39
# episode  127 score 52.16 average score 103.82 epsilon 0.01  profit_iteration 0.05  iterations 962.00  long_return 1.51
# episode  128 score 168.10 average score 104.98 epsilon 0.01  profit_iteration 0.05  iterations 3625.00  long_return 3.19
# episode  129 score 217.40 average score 107.01 epsilon 0.01  profit_iteration 0.06  iterations 3495.00  long_return 3.34
# episode  130 score 49.15 average score 106.36 epsilon 0.01  profit_iteration 0.06  iterations 836.00  long_return 1.43
# episode  131 score 346.17 average score 109.15 epsilon 0.01  profit_iteration 0.09  iterations 3853.00  long_return 4.18
# episode  132 score 241.43 average score 111.87 epsilon 0.01  profit_iteration 0.10  iterations 2434.00  long_return 3.73
# episode  133 score 66.89 average score 112.42 epsilon 0.01  profit_iteration 0.06  iterations 1167.00  long_return 1.70
# episode  134 score 194.27 average score 114.43 epsilon 0.01  profit_iteration 0.10  iterations 1984.00  long_return 3.04
# episode  135 score 85.80 average score 115.19 epsilon 0.01  profit_iteration 0.03  iterations 2840.00  long_return 2.46
# episode  136 score 5.26 average score 114.66 epsilon 0.01  profit_iteration 0.04  iterations 102.00  long_return 1.05
# episode  137 score 43.63 average score 114.62 epsilon 0.01  profit_iteration 0.07  iterations 598.00  long_return 1.49
# episode  138 score 138.71 average score 114.42 epsilon 0.01  profit_iteration 0.07  iterations 1885.00  long_return 2.51
# episode  139 score 32.90 average score 114.90 epsilon 0.01  profit_iteration 0.05  iterations 643.00  long_return 1.45
# episode  140 score 163.12 average score 117.01 epsilon 0.01  profit_iteration 0.08  iterations 2095.00  long_return 2.82
# episode  141 score 135.25 average score 118.34 epsilon 0.01  profit_iteration 0.05  iterations 2762.00  long_return 2.26
# episode  142 score 251.03 average score 120.79 epsilon 0.01  profit_iteration 0.07  iterations 3330.00  long_return 3.14
# episode  143 score 44.08 average score 121.10 epsilon 0.01  profit_iteration 0.06  iterations 728.00  long_return 1.41
# episode  144 score 214.30 average score 118.85 epsilon 0.01  profit_iteration 0.10  iterations 2131.00  long_return 3.01
# episode  145 score 200.01 average score 119.65 epsilon 0.01  profit_iteration 0.12  iterations 1667.00  long_return 2.66
# episode  146 score 128.20 average score 120.70 epsilon 0.01  profit_iteration 0.04  iterations 2855.00  long_return 2.49
# episode  147 score 121.66 average score 121.59 epsilon 0.01  profit_iteration 0.04  iterations 2745.00  long_return 2.46
# episode  148 score 120.70 average score 120.89 epsilon 0.01  profit_iteration 0.07  iterations 1655.00  long_return 2.52
# episode  149 score 136.98 average score 121.68 epsilon 0.01  profit_iteration 0.05  iterations 2767.00  long_return 2.25
# episode  150 score 239.44 average score 122.23 epsilon 0.01  profit_iteration 0.10  iterations 2313.00  long_return 3.67
# episode  151 score 14.52 average score 122.23 epsilon 0.01  profit_iteration 0.07  iterations 209.00  long_return 1.13
# episode  152 score 311.71 average score 124.80 epsilon 0.01  profit_iteration 0.08  iterations 3952.00  long_return 4.22
# episode  153 score 55.05 average score 124.60 epsilon 0.01  profit_iteration 0.05  iterations 1132.00  long_return 1.64
# episode  154 score 95.87 average score 123.56 epsilon 0.01  profit_iteration 0.07  iterations 1359.00  long_return 2.03
# episode  155 score 176.40 average score 125.10 epsilon 0.01  profit_iteration 0.06  iterations 3127.00  long_return 2.84
# episode  156 score 434.05 average score 126.95 epsilon 0.01  profit_iteration 0.11  iterations 3872.00  long_return 4.49
# episode  157 score 182.20 average score 127.95 epsilon 0.01  profit_iteration 0.11  iterations 1649.00  long_return 2.62
# episode  158 score 10.72 average score 124.11 epsilon 0.01  profit_iteration 0.05  iterations 201.00  long_return 1.13
# episode  159 score 153.61 average score 124.64 epsilon 0.01  profit_iteration 0.08  iterations 1870.00  long_return 2.46
# episode  160 score 27.64 average score 124.06 epsilon 0.01  profit_iteration 0.06  iterations 461.00  long_return 1.35
# episode  161 score 161.96 average score 123.99 epsilon 0.01  profit_iteration 0.09  iterations 1881.00  long_return 2.51
# episode  162 score 273.98 average score 126.68 epsilon 0.01  profit_iteration 0.11  iterations 2389.00  long_return 3.86
# episode  163 score 18.60 average score 126.50 epsilon 0.01  profit_iteration 0.06  iterations 283.00  long_return 1.17
# episode  164 score 156.50 average score 127.21 epsilon 0.01  profit_iteration 0.05  iterations 2915.00  long_return 2.49
# episode  165 score 81.94 average score 127.43 epsilon 0.01  profit_iteration 0.07  iterations 1198.00  long_return 1.82
# episode  166 score 218.01 average score 127.48 epsilon 0.01  profit_iteration 0.10  iterations 2126.00  long_return 3.06
# episode  167 score 263.65 average score 128.75 epsilon 0.01  profit_iteration 0.11  iterations 2441.00  long_return 3.61
# episode  168 score 20.55 average score 127.55 epsilon 0.01  profit_iteration 0.07  iterations 310.00  long_return 1.21
# episode  169 score 336.47 average score 128.50 epsilon 0.01  profit_iteration 0.08  iterations 3921.00  long_return 4.17
# episode  170 score 42.73 average score 128.38 epsilon 0.01  profit_iteration 0.08  iterations 542.00  long_return 1.40
# episode  171 score 62.26 average score 128.98 epsilon 0.01  profit_iteration 0.06  iterations 1026.00  long_return 1.55
# episode  172 score 145.85 average score 129.20 epsilon 0.01  profit_iteration 0.06  iterations 2573.00  long_return 2.48
# episode  173 score 172.09 average score 129.73 epsilon 0.01  profit_iteration 0.09  iterations 1799.00  long_return 2.41
# episode  174 score 138.19 average score 130.12 epsilon 0.01  profit_iteration 0.08  iterations 1768.00  long_return 2.42
# episode  175 score 131.32 average score 130.37 epsilon 0.01  profit_iteration 0.07  iterations 1971.00  long_return 2.92
# episode  176 score 299.10 average score 132.30 epsilon 0.01  profit_iteration 0.13  iterations 2359.00  long_return 4.44
# episode  177 score 31.67 average score 131.12 epsilon 0.01  profit_iteration 0.07  iterations 460.00  long_return 1.33
# episode  178 score 175.07 average score 131.34 epsilon 0.01  profit_iteration 0.08  iterations 2169.00  long_return 2.96
# episode  179 score 189.65 average score 131.82 epsilon 0.01  profit_iteration 0.09  iterations 2002.00  long_return 2.94
# episode  180 score 15.59 average score 131.19 epsilon 0.01  profit_iteration 0.06  iterations 268.00  long_return 1.16
# episode  181 score 120.39 average score 131.41 epsilon 0.01  profit_iteration 0.06  iterations 1842.00  long_return 2.55
# episode  182 score 197.40 average score 132.56 epsilon 0.01  profit_iteration 0.06  iterations 3109.00  long_return 2.79
# episode  183 score 97.00 average score 133.35 epsilon 0.01  profit_iteration 0.04  iterations 2559.00  long_return 2.44
# episode  184 score 91.27 average score 133.03 epsilon 0.01  profit_iteration 0.07  iterations 1333.00  long_return 1.97
# episode  185 score 121.72 average score 132.60 epsilon 0.01  profit_iteration 0.08  iterations 1569.00  long_return 2.29
# episode  186 score 300.41 average score 133.49 epsilon 0.01  profit_iteration 0.08  iterations 3849.00  long_return 4.30
# episode  187 score 308.14 average score 134.99 epsilon 0.01  profit_iteration 0.14  iterations 2231.00  long_return 3.21
# episode  188 score 50.78 average score 135.04 epsilon 0.01  profit_iteration 0.04  iterations 1104.00  long_return 1.65
# episode  189 score 174.92 average score 135.59 epsilon 0.01  profit_iteration 0.08  iterations 2129.00  long_return 3.00
# episode  190 score 104.32 average score 135.87 epsilon 0.01  profit_iteration 0.07  iterations 1435.00  long_return 2.20
# episode  191 score 320.09 average score 137.98 epsilon 0.01  profit_iteration 0.08  iterations 3967.00  long_return 4.78
# episode  192 score 181.75 average score 139.29 epsilon 0.01  profit_iteration 0.08  iterations 2211.00  long_return 3.11
# episode  193 score 219.57 average score 140.09 epsilon 0.01  profit_iteration 0.05  iterations 3992.00  long_return 4.14
# episode  194 score 138.37 average score 141.33 epsilon 0.01  profit_iteration 0.05  iterations 2492.00  long_return 2.62
# episode  195 score 51.90 average score 140.30 epsilon 0.01  profit_iteration 0.06  iterations 883.00  long_return 1.47
# episode  196 score 101.99 average score 140.86 epsilon 0.01  profit_iteration 0.07  iterations 1358.00  long_return 2.01
# episode  197 score 119.54 average score 139.69 epsilon 0.01  profit_iteration 0.08  iterations 1445.00  long_return 2.17
# episode  198 score 279.13 average score 141.26 epsilon 0.01  profit_iteration 0.07  iterations 3698.00  long_return 3.53
# episode  199 score 139.97 average score 140.34 epsilon 0.01  profit_iteration 0.09  iterations 1586.00  long_return 2.24
# episode  200 score 79.02 average score 138.48 epsilon 0.01  profit_iteration 0.06  iterations 1228.00  long_return 1.83
# episode  201 score 47.71 average score 137.80 epsilon 0.01  profit_iteration 0.05  iterations 955.00  long_return 1.50
# episode  202 score 362.66 average score 140.00 epsilon 0.01  profit_iteration 0.10  iterations 3487.00  long_return 3.27
# episode  203 score 54.62 average score 139.46 epsilon 0.01  profit_iteration 0.05  iterations 1029.00  long_return 1.54
# episode  204 score 321.44 average score 141.88 epsilon 0.01  profit_iteration 0.08  iterations 3821.00  long_return 4.01
# episode  205 score 56.87 average score 141.63 epsilon 0.01  profit_iteration 0.05  iterations 1123.00  long_return 1.69
# episode  206 score 142.44 average score 140.16 epsilon 0.01  profit_iteration 0.04  iterations 3418.00  long_return 3.06
# episode  207 score 174.40 average score 139.16 epsilon 0.01  profit_iteration 0.08  iterations 2119.00  long_return 3.06
# episode  208 score 89.64 average score 140.07 epsilon 0.01  profit_iteration 0.06  iterations 1365.00  long_return 2.04
# episode  209 score 160.47 average score 140.43 epsilon 0.01  profit_iteration 0.10  iterations 1668.00  long_return 2.65
# episode  210 score 186.86 average score 141.28 epsilon 0.01  profit_iteration 0.05  iterations 3373.00  long_return 3.00
# episode  211 score 51.52 average score 141.42 epsilon 0.01  profit_iteration 0.05  iterations 972.00  long_return 1.49
# episode  212 score 282.90 average score 144.22 epsilon 0.01  profit_iteration 0.08  iterations 3564.00  long_return 3.35
# episode  213 score 331.65 average score 146.98 epsilon 0.01  profit_iteration 0.09  iterations 3851.00  long_return 4.28
# episode  214 score 125.02 average score 146.33 epsilon 0.01  profit_iteration 0.04  iterations 3064.00  long_return 2.68
# episode  215 score 142.24 average score 146.53 epsilon 0.01  profit_iteration 0.05  iterations 2601.00  long_return 2.62
# episode  216 score 228.58 average score 146.50 epsilon 0.01  profit_iteration 0.08  iterations 2860.00  long_return 2.53
# episode  217 score 38.71 average score 145.62 epsilon 0.01  profit_iteration 0.05  iterations 768.00  long_return 1.39
# episode  218 score 169.70 average score 145.71 epsilon 0.01  profit_iteration 0.08  iterations 2033.00  long_return 2.99
# episode  219 score 42.01 average score 144.11 epsilon 0.01  profit_iteration 0.07  iterations 548.00  long_return 1.41
# episode  220 score 69.11 average score 143.54 epsilon 0.01  profit_iteration 0.05  iterations 1248.00  long_return 1.81
# episode  221 score 175.77 average score 145.14 epsilon 0.01  profit_iteration 0.06  iterations 3048.00  long_return 2.76
# episode  222 score 149.04 average score 144.85 epsilon 0.01  profit_iteration 0.05  iterations 2985.00  long_return 2.71
# episode  223 score 59.93 average score 145.29 epsilon 0.01  profit_iteration 0.06  iterations 950.00  long_return 1.54
# episode  224 score 173.25 average score 146.81 epsilon 0.01  profit_iteration 0.09  iterations 1934.00  long_return 2.71
# episode  225 score 1.88 average score 146.83 epsilon 0.01  profit_iteration 0.01  iterations 125.00  long_return 1.02
# episode  226 score 114.71 average score 147.44 epsilon 0.01  profit_iteration 0.04  iterations 2780.00  long_return 2.34
# episode  227 score 161.66 average score 148.54 epsilon 0.01  profit_iteration 0.08  iterations 2114.00  long_return 2.98
# episode  228 score 44.01 average score 147.30 epsilon 0.01  profit_iteration 0.06  iterations 703.00  long_return 1.52
# episode  229 score 316.87 average score 148.29 epsilon 0.01  profit_iteration 0.14  iterations 2258.00  long_return 3.47
# episode  230 score 84.83 average score 148.65 epsilon 0.01  profit_iteration 0.07  iterations 1281.00  long_return 1.86
# episode  231 score 68.82 average score 145.88 epsilon 0.01  profit_iteration 0.06  iterations 1161.00  long_return 1.68
# episode  232 score 338.60 average score 146.85 epsilon 0.01  profit_iteration 0.14  iterations 2329.00  long_return 3.89
# episode  233 score 79.90 average score 146.98 epsilon 0.01  profit_iteration 0.07  iterations 1103.00  long_return 1.64
# episode  234 score 387.23 average score 148.91 epsilon 0.01  profit_iteration 0.10  iterations 3938.00  long_return 4.14
# episode  235 score 130.41 average score 149.35 epsilon 0.01  profit_iteration 0.07  iterations 1810.00  long_return 2.35
# episode  236 score 254.55 average score 151.85 epsilon 0.01  profit_iteration 0.07  iterations 3738.00  long_return 3.61
# episode  237 score 2.69 average score 151.44 epsilon 0.01  profit_iteration 0.06  iterations 33.00  long_return 1.02
# episode  238 score 2.92 average score 150.08 epsilon 0.01  profit_iteration 0.06  iterations 39.00  long_return 1.03
# episode  239 score 287.00 average score 152.62 epsilon 0.01  profit_iteration 0.08  iterations 3716.00  long_return 3.58
# episode  240 score 318.90 average score 154.18 epsilon 0.01  profit_iteration 0.08  iterations 3967.00  long_return 4.78
# episode  241 score 76.35 average score 153.59 epsilon 0.01  profit_iteration 0.06  iterations 1215.00  long_return 1.81
# episode  242 score 35.55 average score 151.43 epsilon 0.01  profit_iteration 0.08  iterations 457.00  long_return 1.34
# episode  243 score 186.82 average score 152.86 epsilon 0.01  profit_iteration 0.05  iterations 3531.00  long_return 3.26
# episode  244 score 4.09 average score 150.76 epsilon 0.01  profit_iteration 0.11  iterations 31.00  long_return 1.02
# episode  245 score 36.31 average score 149.12 epsilon 0.01  profit_iteration 0.05  iterations 659.00  long_return 1.40
# episode  246 score 107.06 average score 148.91 epsilon 0.01  profit_iteration 0.04  iterations 2709.00  long_return 2.22
# episode  247 score 269.04 average score 150.39 epsilon 0.01  profit_iteration 0.07  iterations 3782.00  long_return 3.74
# episode  248 score 47.90 average score 149.66 epsilon 0.01  profit_iteration 0.08  iterations 569.00  long_return 1.42
# episode  249 score 68.31 average score 148.97 epsilon 0.01  profit_iteration 0.06  iterations 1098.00  long_return 1.64
# episode  250 score 51.16 average score 147.09 epsilon 0.01  profit_iteration 0.05  iterations 965.00  long_return 1.50
# episode  251 score 278.71 average score 149.73 epsilon 0.01  profit_iteration 0.11  iterations 2433.00  long_return 3.61
# episode  252 score 4.56 average score 146.66 epsilon 0.01  profit_iteration 0.04  iterations 91.00  long_return 1.04
# episode  253 score 162.52 average score 147.73 epsilon 0.01  profit_iteration 0.09  iterations 1845.00  long_return 2.46
# episode  254 score 6.39 average score 146.84 epsilon 0.01  profit_iteration 0.04  iterations 143.00  long_return 1.05
# episode  255 score 110.36 average score 146.18 epsilon 0.01  profit_iteration 0.08  iterations 1383.00  long_return 2.10
# episode  256 score 54.33 average score 142.38 epsilon 0.01  profit_iteration 0.05  iterations 1038.00  long_return 1.57
# episode  257 score 141.22 average score 141.97 epsilon 0.01  profit_iteration 0.08  iterations 1675.00  long_return 2.55
# episode  258 score 248.00 average score 144.34 epsilon 0.01  profit_iteration 0.10  iterations 2455.00  long_return 3.47
# episode  259 score 330.12 average score 146.11 epsilon 0.01  profit_iteration 0.08  iterations 3954.00  long_return 4.28
# episode  260 score 83.41 average score 146.67 epsilon 0.01  profit_iteration 0.06  iterations 1303.00  long_return 1.88
# episode  261 score 12.59 average score 145.17 epsilon 0.01  profit_iteration 0.06  iterations 197.00  long_return 1.12
# episode  262 score 248.34 average score 144.92 epsilon 0.01  profit_iteration 0.07  iterations 3340.00  long_return 3.06
# episode  263 score 92.24 average score 145.65 epsilon 0.01  profit_iteration 0.07  iterations 1255.00  long_return 1.82
# episode  264 score 170.67 average score 145.79 epsilon 0.01  profit_iteration 0.05  iterations 3563.00  long_return 3.35
# episode  265 score 33.64 average score 145.31 epsilon 0.01  profit_iteration 0.03  iterations 986.00  long_return 1.55
# episode  266 score 126.64 average score 144.40 epsilon 0.01  profit_iteration 0.05  iterations 2735.00  long_return 2.37
# episode  267 score 108.68 average score 142.85 epsilon 0.01  profit_iteration 0.08  iterations 1354.00  long_return 2.07
# episode  268 score 144.47 average score 144.09 epsilon 0.01  profit_iteration 0.07  iterations 1903.00  long_return 2.59
# episode  269 score 179.96 average score 142.52 epsilon 0.01  profit_iteration 0.09  iterations 2032.00  long_return 2.92
# episode  270 score 162.37 average score 143.72 epsilon 0.01  profit_iteration 0.08  iterations 2045.00  long_return 3.05
# episode  271 score 247.21 average score 145.57 epsilon 0.01  profit_iteration 0.10  iterations 2381.00  long_return 4.02
# episode  272 score 198.12 average score 146.09 epsilon 0.01  profit_iteration 0.05  iterations 3652.00  long_return 3.28
# episode  273 score 116.19 average score 145.53 epsilon 0.01  profit_iteration 0.08  iterations 1497.00  long_return 2.25
# episode  274 score 207.87 average score 146.23 epsilon 0.01  profit_iteration 0.06  iterations 3408.00  long_return 3.01
# episode  275 score 160.26 average score 146.52 epsilon 0.01  profit_iteration 0.10  iterations 1650.00  long_return 2.59
# episode  276 score 41.45 average score 143.94 epsilon 0.01  profit_iteration 0.05  iterations 805.00  long_return 1.42
# episode  277 score 30.71 average score 143.93 epsilon 0.01  profit_iteration 0.06  iterations 495.00  long_return 1.32
# episode  278 score 54.85 average score 142.73 epsilon 0.01  profit_iteration 0.08  iterations 701.00  long_return 1.56
# episode  279 score 155.15 average score 142.38 epsilon 0.01  profit_iteration 0.05  iterations 3142.00  long_return 2.78
# episode  280 score 145.70 average score 143.69 epsilon 0.01  profit_iteration 0.06  iterations 2573.00  long_return 2.48
# episode  281 score 227.02 average score 144.75 epsilon 0.01  profit_iteration 0.06  iterations 3579.00  long_return 3.23
# episode  282 score 215.60 average score 144.93 epsilon 0.01  profit_iteration 0.06  iterations 3782.00  long_return 3.74
# episode  283 score 141.73 average score 145.38 epsilon 0.01  profit_iteration 0.07  iterations 2064.00  long_return 2.71
# episode  284 score 244.94 average score 146.92 epsilon 0.01  profit_iteration 0.06  iterations 3804.00  long_return 3.85
# episode  285 score 130.74 average score 147.01 epsilon 0.01  profit_iteration 0.05  iterations 2646.00  long_return 2.44
# episode  286 score 223.89 average score 146.24 epsilon 0.01  profit_iteration 0.11  iterations 1985.00  long_return 3.03
# episode  287 score 104.84 average score 144.21 epsilon 0.01  profit_iteration 0.08  iterations 1342.00  long_return 1.98
# episode  288 score 189.67 average score 145.60 epsilon 0.01  profit_iteration 0.09  iterations 2155.00  long_return 2.96
# episode  289 score 64.66 average score 144.50 epsilon 0.01  profit_iteration 0.06  iterations 1093.00  long_return 1.61
# episode  290 score 148.53 average score 144.94 epsilon 0.01  profit_iteration 0.09  iterations 1719.00  long_return 2.75
# episode  291 score 250.71 average score 144.24 epsilon 0.01  profit_iteration 0.08  iterations 3146.00  long_return 2.77
# episode  292 score 350.30 average score 145.93 epsilon 0.01  profit_iteration 0.09  iterations 3875.00  long_return 4.42
# episode  293 score 52.19 average score 144.26 epsilon 0.01  profit_iteration 0.05  iterations 1106.00  long_return 1.65
# episode  294 score 156.12 average score 144.43 epsilon 0.01  profit_iteration 0.05  iterations 2852.00  long_return 2.52
# episode  295 score 42.37 average score 144.34 epsilon 0.01  profit_iteration 0.05  iterations 836.00  long_return 1.43
# episode  296 score 36.49 average score 143.68 epsilon 0.01  profit_iteration 0.06  iterations 566.00  long_return 1.40
# episode  297 score 159.25 average score 144.08 epsilon 0.01  profit_iteration 0.09  iterations 1831.00  long_return 2.42
# episode  298 score 192.10 average score 143.21 epsilon 0.01  profit_iteration 0.06  iterations 3229.00  long_return 2.90
# episode  299 score 87.13 average score 142.68 epsilon 0.01  profit_iteration 0.07  iterations 1222.00  long_return 1.86
# episode  300 score 73.18 average score 142.62 epsilon 0.01  profit_iteration 0.06  iterations 1278.00  long_return 1.87
# episode  301 score 258.80 average score 144.73 epsilon 0.01  profit_iteration 0.11  iterations 2301.00  long_return 3.69
# episode  302 score 218.04 average score 143.29 epsilon 0.01  profit_iteration 0.06  iterations 3570.00  long_return 3.27
# episode  303 score 202.80 average score 144.77 epsilon 0.01  profit_iteration 0.05  iterations 3742.00  long_return 3.71
# episode  304 score 8.10 average score 141.64 epsilon 0.01  profit_iteration 0.04  iterations 165.00  long_return 1.09
# episode  305 score 197.02 average score 143.04 epsilon 0.01  profit_iteration 0.06  iterations 3055.00  long_return 2.82
# episode  306 score 73.99 average score 142.35 epsilon 0.01  profit_iteration 0.06  iterations 1267.00  long_return 1.91
# episode  307 score 176.75 average score 142.38 epsilon 0.01  profit_iteration 0.08  iterations 2171.00  long_return 2.98
# episode  308 score 159.36 average score 143.07 epsilon 0.01  profit_iteration 0.05  iterations 2893.00  long_return 2.45
# episode  309 score 57.69 average score 142.05 epsilon 0.01  profit_iteration 0.05  iterations 1164.00  long_return 1.68
# episode  310 score 84.05 average score 141.02 epsilon 0.01  profit_iteration 0.07  iterations 1226.00  long_return 1.87
# episode  311 score 136.38 average score 141.87 epsilon 0.01  profit_iteration 0.04  iterations 3435.00  long_return 3.10
# episode  312 score 16.05 average score 139.20 epsilon 0.01  profit_iteration 0.07  iterations 218.00  long_return 1.15
# episode  313 score 102.42 average score 136.91 epsilon 0.01  profit_iteration 0.04  iterations 2811.00  long_return 2.31
# episode  314 score 130.46 average score 136.96 epsilon 0.01  profit_iteration 0.06  iterations 2094.00  long_return 2.80
# episode  315 score 193.94 average score 137.48 epsilon 0.01  profit_iteration 0.06  iterations 3158.00  long_return 2.83
# episode  316 score 18.78 average score 135.38 epsilon 0.01  profit_iteration 0.05  iterations 351.00  long_return 1.21
# episode  317 score 44.28 average score 135.44 epsilon 0.01  profit_iteration 0.06  iterations 669.00  long_return 1.41
# episode  318 score 234.11 average score 136.08 epsilon 0.01  profit_iteration 0.09  iterations 2449.00  long_return 3.61
# episode  319 score 357.68 average score 139.24 epsilon 0.01  profit_iteration 0.09  iterations 3794.00  long_return 3.69
# episode  320 score 115.12 average score 139.70 epsilon 0.01  profit_iteration 0.08  iterations 1396.00  long_return 2.16
# episode  321 score 89.02 average score 138.83 epsilon 0.01  profit_iteration 0.08  iterations 1065.00  long_return 1.62
# episode  322 score 115.95 average score 138.50 epsilon 0.01  profit_iteration 0.08  iterations 1385.00  long_return 2.12
# episode  323 score 40.97 average score 138.31 epsilon 0.01  profit_iteration 0.07  iterations 602.00  long_return 1.51
# episode  324 score 88.10 average score 137.46 epsilon 0.01  profit_iteration 0.06  iterations 1472.00  long_return 2.21
# episode  325 score 205.06 average score 139.49 epsilon 0.01  profit_iteration 0.05  iterations 3723.00  long_return 3.71
# episode  326 score 285.34 average score 141.19 epsilon 0.01  profit_iteration 0.08  iterations 3425.00  long_return 3.06
# episode  327 score 275.16 average score 142.33 epsilon 0.01  profit_iteration 0.08  iterations 3385.00  long_return 3.09
# episode  328 score 37.05 average score 142.26 epsilon 0.01  profit_iteration 0.05  iterations 784.00  long_return 1.40
# episode  329 score 206.17 average score 141.15 epsilon 0.01  profit_iteration 0.07  iterations 2994.00  long_return 2.72
# episode  330 score 153.37 average score 141.84 epsilon 0.01  profit_iteration 0.09  iterations 1777.00  long_return 2.51
# episode  331 score 149.22 average score 142.64 epsilon 0.01  profit_iteration 0.08  iterations 1801.00  long_return 2.39
# episode  332 score 223.85 average score 141.49 epsilon 0.01  profit_iteration 0.10  iterations 2123.00  long_return 2.99
# episode  333 score 55.04 average score 141.25 epsilon 0.01  profit_iteration 0.06  iterations 979.00  long_return 1.51
# episode  334 score 90.25 average score 138.28 epsilon 0.01  profit_iteration 0.07  iterations 1221.00  long_return 1.84
# episode  335 score 59.19 average score 137.56 epsilon 0.01  profit_iteration 0.05  iterations 1109.00  long_return 1.65
# episode  336 score 166.33 average score 136.68 epsilon 0.01  profit_iteration 0.05  iterations 3387.00  long_return 3.10
# episode  337 score 154.88 average score 138.20 epsilon 0.01  profit_iteration 0.06  iterations 2482.00  long_return 2.65
# episode  338 score 205.95 average score 140.23 epsilon 0.01  profit_iteration 0.06  iterations 3319.00  long_return 3.08
# episode  339 score 321.86 average score 140.58 epsilon 0.01  profit_iteration 0.08  iterations 3998.00  long_return 3.93
# episode  340 score 195.68 average score 139.35 epsilon 0.01  profit_iteration 0.09  iterations 2144.00  long_return 2.90
# episode  341 score 68.64 average score 139.27 epsilon 0.01  profit_iteration 0.06  iterations 1089.00  long_return 1.64
# episode  342 score 177.55 average score 140.69 epsilon 0.01  profit_iteration 0.06  iterations 2744.00  long_return 2.45
# episode  343 score 13.30 average score 138.96 epsilon 0.01  profit_iteration 0.05  iterations 273.00  long_return 1.16
# episode  344 score 142.14 average score 140.34 epsilon 0.01  profit_iteration 0.07  iterations 2074.00  long_return 2.70
# episode  345 score 28.04 average score 140.26 epsilon 0.01  profit_iteration 0.06  iterations 470.00  long_return 1.32
# episode  346 score 278.77 average score 141.97 epsilon 0.01  profit_iteration 0.12  iterations 2370.00  long_return 4.04
# episode  347 score 192.14 average score 141.20 epsilon 0.01  profit_iteration 0.07  iterations 2608.00  long_return 2.58
# episode  348 score 2.12 average score 140.75 epsilon 0.01  profit_iteration 0.01  iterations 93.00  long_return 1.02
# episode  349 score 270.17 average score 142.76 epsilon 0.01  profit_iteration 0.11  iterations 2404.00  long_return 3.81
# episode  350 score 59.00 average score 142.84 epsilon 0.01  profit_iteration 0.05  iterations 1089.00  long_return 1.64
# episode  351 score 182.05 average score 141.88 epsilon 0.01  profit_iteration 0.06  iterations 3118.00  long_return 2.78
# episode  352 score 216.27 average score 143.99 epsilon 0.01  profit_iteration 0.06  iterations 3301.00  long_return 3.03
# episode  353 score 222.86 average score 144.60 epsilon 0.01  profit_iteration 0.06  iterations 3632.00  long_return 3.27
# episode  354 score 259.38 average score 147.13 epsilon 0.01  profit_iteration 0.07  iterations 3917.00  long_return 4.16
# episode  355 score 168.06 average score 147.70 epsilon 0.01  profit_iteration 0.04  iterations 3787.00  long_return 3.83
# episode  356 score 180.62 average score 148.97 epsilon 0.01  profit_iteration 0.09  iterations 2075.00  long_return 2.70
# episode  357 score 328.45 average score 150.84 epsilon 0.01  profit_iteration 0.08  iterations 4045.00  long_return 3.66
# episode  358 score 95.35 average score 149.31 epsilon 0.01  profit_iteration 0.03  iterations 2724.00  long_return 2.33
# episode  359 score 228.56 average score 148.30 epsilon 0.01  profit_iteration 0.06  iterations 3532.00  long_return 3.21
# episode  360 score 33.90 average score 147.80 epsilon 0.01  profit_iteration 0.06  iterations 508.00  long_return 1.38
# episode  361 score 62.77 average score 148.30 epsilon 0.01  profit_iteration 0.06  iterations 1015.00  long_return 1.53
# episode  362 score 52.98 average score 146.35 epsilon 0.01  profit_iteration 0.08  iterations 622.00  long_return 1.56
# episode  363 score 300.58 average score 148.43 epsilon 0.01  profit_iteration 0.08  iterations 3515.00  long_return 3.38
# episode  364 score 55.26 average score 147.28 epsilon 0.01  profit_iteration 0.06  iterations 938.00  long_return 1.58
# episode  365 score 46.17 average score 147.40 epsilon 0.01  profit_iteration 0.06  iterations 737.00  long_return 1.41
# episode  366 score 75.17 average score 146.89 epsilon 0.01  profit_iteration 0.06  iterations 1237.00  long_return 1.81
# episode  367 score 223.36 average score 148.04 epsilon 0.01  profit_iteration 0.06  iterations 3533.00  long_return 3.23
# episode  368 score 443.72 average score 151.03 epsilon 0.01  profit_iteration 0.11  iterations 3983.00  long_return 4.24
# episode  369 score 32.01 average score 149.55 epsilon 0.01  profit_iteration 0.07  iterations 471.00  long_return 1.32
# episode  370 score 132.46 average score 149.25 epsilon 0.01  profit_iteration 0.08  iterations 1544.00  long_return 2.38
# episode  371 score 303.66 average score 149.82 epsilon 0.01  profit_iteration 0.08  iterations 3830.00  long_return 4.10
# episode  372 score 83.07 average score 148.66 epsilon 0.01  profit_iteration 0.06  iterations 1293.00  long_return 1.85
# episode  373 score 8.62 average score 147.59 epsilon 0.01  profit_iteration 0.11  iterations 71.00  long_return 1.06
# episode  374 score 42.82 average score 145.94 epsilon 0.01  profit_iteration 0.07  iterations 570.00  long_return 1.40
# episode  375 score 175.54 average score 146.09 epsilon 0.01  profit_iteration 0.09  iterations 2028.00  long_return 2.92
# episode  376 score 42.97 average score 146.11 epsilon 0.01  profit_iteration 0.04  iterations 1155.00  long_return 1.68
# episode  377 score 240.63 average score 148.21 epsilon 0.01  profit_iteration 0.10  iterations 2310.00  long_return 3.67
# episode  378 score 5.21 average score 147.71 epsilon 0.01  profit_iteration 0.03  iterations 138.00  long_return 1.05
# episode  379 score 370.07 average score 149.86 epsilon 0.01  profit_iteration 0.10  iterations 3849.00  long_return 4.30
# episode  380 score 183.28 average score 150.23 epsilon 0.01  profit_iteration 0.07  iterations 2471.00  long_return 2.79
# episode  381 score 51.54 average score 148.48 epsilon 0.01  profit_iteration 0.06  iterations 877.00  long_return 1.49
# episode  382 score 157.21 average score 147.90 epsilon 0.01  profit_iteration 0.08  iterations 1963.00  long_return 2.86
# episode  383 score 117.91 average score 147.66 epsilon 0.01  profit_iteration 0.07  iterations 1584.00  long_return 2.25
# episode  384 score 148.94 average score 146.70 epsilon 0.01  profit_iteration 0.05  iterations 3009.00  long_return 2.79
# episode  385 score 326.43 average score 148.65 epsilon 0.01  profit_iteration 0.14  iterations 2369.00  long_return 4.02
# episode  386 score 34.40 average score 146.76 epsilon 0.01  profit_iteration 0.06  iterations 541.00  long_return 1.41
# episode  387 score 278.24 average score 148.49 epsilon 0.01  profit_iteration 0.11  iterations 2431.00  long_return 3.77
# episode  388 score 303.37 average score 149.63 epsilon 0.01  profit_iteration 0.12  iterations 2414.00  long_return 3.85
# episode  389 score 24.78 average score 149.23 epsilon 0.01  profit_iteration 0.06  iterations 395.00  long_return 1.26
# episode  390 score 195.17 average score 149.70 epsilon 0.01  profit_iteration 0.05  iterations 3663.00  long_return 3.40
# episode  391 score 26.23 average score 147.45 epsilon 0.01  profit_iteration 0.07  iterations 371.00  long_return 1.26
# episode  392 score 231.16 average score 146.26 epsilon 0.01  profit_iteration 0.11  iterations 2041.00  long_return 2.96
# episode  393 score 162.95 average score 147.37 epsilon 0.01  profit_iteration 0.10  iterations 1656.00  long_return 2.56
# ...
# episode  869 score 123.82 average score 141.07 epsilon 0.01  profit_iteration 0.08  iterations 1575.00  long_return 2.25
# episode  870 score 231.68 average score 142.13 epsilon 0.01  profit_iteration 0.07  iterations 3485.00  long_return 3.26
# episode  871 score 186.42 average score 143.53 epsilon 0.01  profit_iteration 0.09  iterations 1961.00  long_return 2.82
# episode  872 score 126.91 average score 144.78 epsilon 0.01  profit_iteration 0.05  iterations 2763.00  long_return 2.26
# episode  873 score 135.40 average score 146.09 epsilon 0.01  profit_iteration 0.05  iterations 2947.00  long_return 2.56
# episode  874 score 173.70 average score 147.31 epsilon 0.01  profit_iteration 0.05  iterations 3138.00  long_return 2.82
# episode  875 score 44.07 average score 146.68 epsilon 0.01  profit_iteration 0.08  iterations 554.00  long_return 1.39
# episode  876 score 146.73 average score 146.49 epsilon 0.01  profit_iteration 0.04  iterations 3345.00  long_return 3.11
# episode  877 score 208.26 average score 148.14 epsilon 0.01  profit_iteration 0.06  iterations 3727.00  long_return 3.59
# episode  878 score 160.11 average score 147.79 epsilon 0.01  profit_iteration 0.05  iterations 2999.00  long_return 2.78
# episode  879 score 142.72 average score 147.15 epsilon 0.01  profit_iteration 0.07  iterations 1880.00  long_return 2.52
# episode  880 score 97.16 average score 146.55 epsilon 0.01  profit_iteration 0.03  iterations 2913.00  long_return 2.49
# episode  881 score 17.33 average score 145.18 epsilon 0.01  profit_iteration 0.08  iterations 219.00  long_return 1.15
# episode  882 score 23.26 average score 143.51 epsilon 0.01  profit_iteration 0.06  iterations 359.00  long_return 1.24
# episode  883 score 227.29 average score 144.04 epsilon 0.01  profit_iteration 0.06  iterations 3802.00  long_return 3.78
# episode  884 score 382.11 average score 147.45 epsilon 0.01  profit_iteration 0.09  iterations 4029.00  long_return 4.12
# episode  885 score 122.04 average score 144.28 epsilon 0.01  profit_iteration 0.04  iterations 2705.00  long_return 2.23
# episode  886 score 205.32 average score 145.84 epsilon 0.01  profit_iteration 0.06  iterations 3451.00  long_return 3.33
# episode  887 score 312.10 average score 147.89 epsilon 0.01  profit_iteration 0.08  iterations 3872.00  long_return 4.49
# episode  888 score 211.87 average score 149.32 epsilon 0.01  profit_iteration 0.05  iterations 4057.00  long_return 3.56
# episode  889 score 212.11 average score 150.23 epsilon 0.01  profit_iteration 0.09  iterations 2221.00  long_return 3.15
# episode  890 score 68.89 average score 150.05 epsilon 0.01  profit_iteration 0.06  iterations 1148.00  long_return 1.70
# episode  891 score 45.58 average score 148.99 epsilon 0.01  profit_iteration 0.05  iterations 910.00  long_return 1.44
# episode  892 score 172.01 average score 147.08 epsilon 0.01  profit_iteration 0.05  iterations 3246.00  long_return 2.95
# episode  893 score 176.35 average score 148.00 epsilon 0.01  profit_iteration 0.10  iterations 1723.00  long_return 2.71
# episode  894 score 224.19 average score 147.95 epsilon 0.01  profit_iteration 0.07  iterations 3033.00  long_return 2.84
# episode  895 score 97.73 average score 148.57 epsilon 0.01  profit_iteration 0.07  iterations 1305.00  long_return 1.90
# episode  896 score 16.70 average score 145.76 epsilon 0.01  profit_iteration 0.06  iterations 251.00  long_return 1.16
# episode  897 score 262.57 average score 147.95 epsilon 0.01  profit_iteration 0.11  iterations 2349.00  long_return 4.45
# episode  898 score 136.50 average score 147.48 epsilon 0.01  profit_iteration 0.05  iterations 2726.00  long_return 2.35
# episode  899 score 55.68 average score 145.97 epsilon 0.01  profit_iteration 0.06  iterations 973.00  long_return 1.50
# episode  900 score 341.74 average score 147.01 epsilon 0.01  profit_iteration 0.09  iterations 3974.00  long_return 4.41
# episode  901 score 41.95 average score 145.95 epsilon 0.01  profit_iteration 0.04  iterations 980.00  long_return 1.51
# episode  902 score 36.56 average score 144.44 epsilon 0.01  profit_iteration 0.04  iterations 805.00  long_return 1.42
# episode  903 score 116.27 average score 144.08 epsilon 0.01  profit_iteration 0.04  iterations 2739.00  long_return 2.37
# episode  904 score 32.11 average score 142.61 epsilon 0.01  profit_iteration 0.06  iterations 491.00  long_return 1.33
# episode  905 score 37.51 average score 139.81 epsilon 0.01  profit_iteration 0.06  iterations 634.00  long_return 1.45
# episode  906 score 168.18 average score 140.46 epsilon 0.01  profit_iteration 0.05  iterations 3527.00  long_return 3.30
# episode  907 score 190.81 average score 140.05 epsilon 0.01  profit_iteration 0.09  iterations 2035.00  long_return 3.00
# episode  908 score 171.92 average score 140.01 epsilon 0.01  profit_iteration 0.09  iterations 1789.00  long_return 2.43
# episode  909 score 192.57 average score 140.37 epsilon 0.01  profit_iteration 0.11  iterations 1666.00  long_return 2.72
# episode  910 score 310.41 average score 142.94 epsilon 0.01  profit_iteration 0.13  iterations 2385.00  long_return 4.17
# episode  911 score 278.88 average score 144.12 epsilon 0.01  profit_iteration 0.08  iterations 3541.00  long_return 3.24
# episode  912 score 39.51 average score 141.17 epsilon 0.01  profit_iteration 0.07  iterations 535.00  long_return 1.38
# episode  913 score 185.19 average score 142.44 epsilon 0.01  profit_iteration 0.09  iterations 2036.00  long_return 3.08
# episode  914 score 207.48 average score 144.49 epsilon 0.01  profit_iteration 0.09  iterations 2298.00  long_return 3.65
# episode  915 score 116.60 average score 144.13 epsilon 0.01  profit_iteration 0.04  iterations 2869.00  long_return 2.41
# episode  916 score 43.62 average score 144.04 epsilon 0.01  profit_iteration 0.07  iterations 647.00  long_return 1.44
# episode  917 score 22.07 average score 141.99 epsilon 0.01  profit_iteration 0.06  iterations 370.00  long_return 1.26
# episode  918 score 193.19 average score 141.32 epsilon 0.01  profit_iteration 0.06  iterations 3009.00  long_return 2.79
# episode  919 score 180.53 average score 141.06 epsilon 0.01  profit_iteration 0.06  iterations 3224.00  long_return 2.92
# episode  920 score 260.12 average score 143.05 epsilon 0.01  profit_iteration 0.07  iterations 3658.00  long_return 3.33
# episode  921 score 66.04 average score 142.16 epsilon 0.01  profit_iteration 0.06  iterations 1046.00  long_return 1.61
# episode  922 score 54.99 average score 139.16 epsilon 0.01  profit_iteration 0.09  iterations 608.00  long_return 1.57
# episode  923 score 136.50 average score 139.28 epsilon 0.01  profit_iteration 0.05  iterations 2845.00  long_return 2.43
# episode  924 score 198.55 average score 140.92 epsilon 0.01  profit_iteration 0.05  iterations 4035.00  long_return 3.91
# episode  925 score 76.38 average score 141.03 epsilon 0.01  profit_iteration 0.07  iterations 1142.00  long_return 1.65
# episode  926 score 283.04 average score 143.85 epsilon 0.01  profit_iteration 0.07  iterations 3871.00  long_return 4.45
# episode  927 score 166.41 average score 143.89 epsilon 0.01  profit_iteration 0.10  iterations 1701.00  long_return 2.77
# episode  928 score 164.27 average score 145.09 epsilon 0.01  profit_iteration 0.09  iterations 1725.00  long_return 2.61
# episode  929 score 12.86 average score 142.64 epsilon 0.01  profit_iteration 0.05  iterations 236.00  long_return 1.14
# episode  930 score 142.85 average score 141.34 epsilon 0.01  profit_iteration 0.07  iterations 1901.00  long_return 2.59
# episode  931 score 418.06 average score 145.13 epsilon 0.01  profit_iteration 0.11  iterations 3939.00  long_return 4.17
# episode  932 score 151.38 average score 145.30 epsilon 0.01  profit_iteration 0.08  iterations 1907.00  long_return 2.60
# episode  933 score 241.47 average score 145.66 epsilon 0.01  profit_iteration 0.07  iterations 3538.00  long_return 3.23
# episode  934 score 21.46 average score 145.17 epsilon 0.01  profit_iteration 0.07  iterations 309.00  long_return 1.21
# episode  935 score 215.43 average score 146.93 epsilon 0.01  profit_iteration 0.07  iterations 3230.00  long_return 2.89
# episode  936 score 80.68 average score 145.78 epsilon 0.01  profit_iteration 0.07  iterations 1153.00  long_return 1.68
# episode  937 score 237.87 average score 146.32 epsilon 0.01  profit_iteration 0.06  iterations 3750.00  long_return 3.72
# episode  938 score 46.01 average score 144.44 epsilon 0.01  profit_iteration 0.05  iterations 980.00  long_return 1.51
# episode  939 score 186.65 average score 145.76 epsilon 0.01  profit_iteration 0.08  iterations 2198.00  long_return 3.01
# episode  940 score 20.42 average score 144.82 epsilon 0.01  profit_iteration 0.07  iterations 291.00  long_return 1.18
# episode  941 score 30.12 average score 143.69 epsilon 0.01  profit_iteration 0.04  iterations 794.00  long_return 1.39
# episode  942 score 42.90 average score 142.58 epsilon 0.01  profit_iteration 0.06  iterations 669.00  long_return 1.41
# episode  943 score 23.26 average score 141.20 epsilon 0.01  profit_iteration 0.06  iterations 353.00  long_return 1.22
# episode  944 score 176.00 average score 139.42 epsilon 0.01  profit_iteration 0.05  iterations 3367.00  long_return 3.02
# episode  945 score 117.37 average score 140.13 epsilon 0.01  profit_iteration 0.04  iterations 2741.00  long_return 2.40
# episode  946 score 168.48 average score 141.33 epsilon 0.01  profit_iteration 0.06  iterations 2571.00  long_return 2.48
# episode  947 score 7.08 average score 139.29 epsilon 0.01  profit_iteration 0.04  iterations 159.00  long_return 1.09
# episode  948 score 242.87 average score 139.79 epsilon 0.01  profit_iteration 0.07  iterations 3607.00  long_return 3.29
# episode  949 score 132.66 average score 138.02 epsilon 0.01  profit_iteration 0.09  iterations 1539.00  long_return 2.35
# episode  950 score 495.80 average score 142.74 epsilon 0.01  profit_iteration 0.12  iterations 4010.00  long_return 4.39
# episode  951 score 17.96 average score 142.71 epsilon 0.01  profit_iteration 0.06  iterations 302.00  long_return 1.19
# episode  952 score 292.74 average score 144.29 epsilon 0.01  profit_iteration 0.12  iterations 2448.00  long_return 3.63
# episode  953 score 166.67 average score 145.13 epsilon 0.01  profit_iteration 0.07  iterations 2477.00  long_return 2.68
# episode  954 score 109.64 average score 144.44 epsilon 0.01  profit_iteration 0.08  iterations 1351.00  long_return 2.04
# episode  955 score 173.89 average score 145.68 epsilon 0.01  profit_iteration 0.06  iterations 2679.00  long_return 2.37
# episode  956 score 244.32 average score 147.16 epsilon 0.01  profit_iteration 0.06  iterations 4006.00  long_return 4.19
# episode  957 score 185.90 average score 148.64 epsilon 0.01  profit_iteration 0.07  iterations 2588.00  long_return 2.51
# episode  958 score 22.90 average score 148.52 epsilon 0.01  profit_iteration 0.04  iterations 497.00  long_return 1.33
# episode  959 score 122.96 average score 149.31 epsilon 0.01  profit_iteration 0.05  iterations 2580.00  long_return 2.57
# episode  960 score 132.97 average score 149.60 epsilon 0.01  profit_iteration 0.05  iterations 2868.00  long_return 2.40
# episode  961 score 180.57 average score 149.94 epsilon 0.01  profit_iteration 0.08  iterations 2146.00  long_return 2.92
# episode  962 score 114.96 average score 150.75 epsilon 0.01  profit_iteration 0.04  iterations 3083.00  long_return 2.76
# episode  963 score 114.21 average score 150.69 epsilon 0.01  profit_iteration 0.08  iterations 1403.00  long_return 2.17
# episode  964 score 135.00 average score 150.78 epsilon 0.01  profit_iteration 0.09  iterations 1544.00  long_return 2.38
# episode  965 score 156.05 average score 150.20 epsilon 0.01  profit_iteration 0.05  iterations 3230.00  long_return 2.89
# episode  966 score 126.24 average score 149.19 epsilon 0.01  profit_iteration 0.05  iterations 2704.00  long_return 2.21
# episode  967 score 48.71 average score 147.88 epsilon 0.01  profit_iteration 0.05  iterations 927.00  long_return 1.48
# episode  968 score 53.16 average score 146.71 epsilon 0.01  profit_iteration 0.09  iterations 605.00  long_return 1.53
# episode  969 score 233.04 average score 147.80 epsilon 0.01  profit_iteration 0.12  iterations 1921.00  long_return 2.69
# episode  970 score 105.33 average score 146.53 epsilon 0.01  profit_iteration 0.04  iterations 2667.00  long_return 2.33
# episode  971 score 272.68 average score 147.40 epsilon 0.01  profit_iteration 0.12  iterations 2330.00  long_return 4.04
# episode  972 score 193.77 average score 148.07 epsilon 0.01  profit_iteration 0.06  iterations 3273.00  long_return 2.96
# episode  973 score 239.92 average score 149.11 epsilon 0.01  profit_iteration 0.07  iterations 3423.00  long_return 3.06
# episode  974 score 153.34 average score 148.91 epsilon 0.01  profit_iteration 0.08  iterations 1830.00  long_return 2.41
# episode  975 score 206.24 average score 150.53 epsilon 0.01  profit_iteration 0.06  iterations 3694.00  long_return 3.51
# episode  976 score 132.89 average score 150.39 epsilon 0.01  profit_iteration 0.05  iterations 2717.00  long_return 2.29
# episode  977 score 127.18 average score 149.58 epsilon 0.01  profit_iteration 0.05  iterations 2557.00  long_return 2.43
# episode  978 score 250.97 average score 150.49 epsilon 0.01  profit_iteration 0.07  iterations 3723.00  long_return 3.71
# episode  979 score 140.30 average score 150.46 epsilon 0.01  profit_iteration 0.05  iterations 2632.00  long_return 2.54
# episode  980 score 177.81 average score 151.27 epsilon 0.01  profit_iteration 0.10  iterations 1724.00  long_return 2.64
# episode  981 score 219.75 average score 153.29 epsilon 0.01  profit_iteration 0.06  iterations 3715.00  long_return 3.57
# episode  982 score 52.13 average score 153.58 epsilon 0.01  profit_iteration 0.05  iterations 1069.00  long_return 1.66
# episode  983 score 176.09 average score 153.07 epsilon 0.01  profit_iteration 0.06  iterations 3015.00  long_return 2.82
# episode  984 score 250.44 average score 151.75 epsilon 0.01  profit_iteration 0.12  iterations 2035.00  long_return 3.00
# episode  985 score 103.38 average score 151.57 epsilon 0.01  profit_iteration 0.07  iterations 1379.00  long_return 2.09
# episode  986 score 215.23 average score 151.67 epsilon 0.01  profit_iteration 0.06  iterations 3738.00  long_return 3.61
# episode  987 score 121.66 average score 149.76 epsilon 0.01  profit_iteration 0.08  iterations 1592.00  long_return 2.25
# episode  988 score 22.90 average score 147.87 epsilon 0.01  profit_iteration 0.06  iterations 398.00  long_return 1.27
# episode  989 score 122.87 average score 146.98 epsilon 0.01  profit_iteration 0.08  iterations 1436.00  long_return 2.20
# episode  990 score 32.34 average score 146.62 epsilon 0.01  profit_iteration 0.04  iterations 794.00  long_return 1.39
# episode  991 score 313.15 average score 149.29 epsilon 0.01  profit_iteration 0.13  iterations 2361.00  long_return 4.34
# episode  992 score 187.47 average score 149.45 epsilon 0.01  profit_iteration 0.06  iterations 3054.00  long_return 2.84
# episode  993 score 228.04 average score 149.96 epsilon 0.01  profit_iteration 0.06  iterations 3946.00  long_return 4.12
# episode  994 score 206.82 average score 149.79 epsilon 0.01  profit_iteration 0.08  iterations 2469.00  long_return 2.84
# episode  995 score 175.49 average score 150.57 epsilon 0.01  profit_iteration 0.08  iterations 2095.00  long_return 2.82
# episode  996 score 205.94 average score 152.46 epsilon 0.01  profit_iteration 0.10  iterations 2126.00  long_return 3.06
# episode  997 score 146.01 average score 151.29 epsilon 0.01  profit_iteration 0.09  iterations 1675.00  long_return 2.55
# episode  998 score 247.77 average score 152.41 epsilon 0.01  profit_iteration 0.06  iterations 3824.00  long_return 4.02
# episode  999 score 23.23 average score 152.08 epsilon 0.01  profit_iteration 0.06  iterations 355.00  long_return 1.23

# %% [markdown]
# # Save the trained model

# %%
import os
state_dict_path = os.path.join(os.getcwd(),'test2.pth')
T.save(agent.Q_eval.state_dict(), state_dict_path)

# %%
from utils import plot_learning_curve
x = [i+1 for i in range(n_games)]
filename = 'Phil-deepQ2.png'
plot_learning_curve(x, scores, eps_history, filename)

# %%
import matplotlib.pyplot as plt
plt.scatter(np.arange(len(agent.action_memory)),agent.action_memory)

# %%
agent.Q_eval.load_state_dict(T.load(state_dict_path)) # load saved model

# %%
print(agent.state_memory[-4:],
        agent.new_state_memory[-4:], 
        agent.action_memory[-4:], 
        agent.reward_memory[-4:], 
        agent.terminal_memory[-4:])

# %%
tmp = agent.action_memory[-500:]
print('mean', np.mean(tmp))
print('max', np.max(tmp))
print('min', np.min(tmp))

# %%
info
