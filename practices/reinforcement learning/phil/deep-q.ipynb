# %%
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np

class DeepQNetwork(nn.Module):
    def __init__(self, lr, input_dims, fc1_dims, fc2_dims, n_actions):
        super(DeepQNetwork, self).__init__()
        self.input_dims = input_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
        self.fc1 = nn.Linear(*self.input_dims, self.fc1_dims)
        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
        self.fc3 = nn.Linear(self.fc2_dims, self.n_actions)
        self.optimizer = optim.Adam(self.parameters(), lr=lr)
        self.loss = nn.MSELoss()
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)
    
    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        actions = self.fc3(x)
        
        return actions

class Agent():
    def __init__(self, gamma, epsilon, lr, input_dims, batch_size, n_actions,
                max_mem_size=100000, eps_end=0.01, eps_dec=5e-4):
        self.gamma = gamma
        self.epsilon = epsilon
        self.eps_min = eps_end
        self.eps_dec = eps_dec
        self.lr = lr
        self.action_space = [i for i in range(n_actions)]
        self.mem_size = max_mem_size
        self.batch_size = batch_size
        self.mem_cntr = 0
        
        self.Q_eval = DeepQNetwork(self.lr, n_actions=n_actions, input_dims=input_dims, 
                                  fc1_dims=256, fc2_dims=256)
        
        self.state_memory = np.zeros((self.mem_size, *input_dims), dtype= np.float32)
        self.new_state_memory = np.zeros((self.mem_size, *input_dims), dtype=np.float32)
        self.action_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.reward_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)
        
    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size # residual. The memory is finite, so we are reusing
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.reward_memory[index] = reward
        self.action_memory[index] =  action
        self.terminal_memory[index] = done
        
        self.mem_cntr += 1
        
    def choose_action(self, observation):
        if np.random.random() > self.epsilon:
            state = T.tensor([observation]).to(self.Q_eval.device) # [] is used because of the nn library
            actions = self.Q_eval.forward(state)
            action = T.argmax(actions).item() # .item() to get integer
        else:
            action = np.random.choice(self.action_space)
            
        return action
    
    def learn(self):
        if self.mem_cntr < self.batch_size:
            return
        
        self.Q_eval.optimizer.zero_grad()
        
        max_mem = min(self.mem_cntr, self.mem_size) 
        # select samples the number of self.batch_size out of max_mem 
        batch = np.random.choice(max_mem, self.batch_size, replace=False) # Don't select the same thing again
        # array slicing [0,1,2,...,self.batch_size-1]
        batch_index = np.arange(self.batch_size, dtype=np.int32) 
        
        state_batch = T.tensor(self.state_memory[batch]).to(self.Q_eval.device)
        new_state_batch = T.tensor(self.new_state_memory[batch]).to(self.Q_eval.device)
        reward_batch = T.tensor(self.reward_memory[batch]).to(self.Q_eval.device)
        terminal_batch = T.tensor(self.terminal_memory[batch]).to(self.Q_eval.device)
        
        action_batch = self.action_memory[batch]
        
        q_eval = self.Q_eval.forward(state_batch)[batch_index, action_batch]
        q_next = self.Q_eval.forward(new_state_batch)
        q_next[terminal_batch] = 0.0
                                                 
        q_target = reward_batch + self.gamma * T.max(q_next, dim=1)[0]
        
        loss = self.Q_eval.loss(q_target, q_eval).to(self.Q_eval.device)
        loss.backward()
        self.Q_eval.optimizer.step()
        
        self.epsilon = self.epsilon - self.eps_dec if self.epsilon > self.eps_min else self.eps_min

# %%
import gym
import numpy as np
from utils import plot_learning_curve

env = gym.make('LunarLander-v2')
agent = Agent(gamma=0.99, epsilon=1.0, batch_size=64, n_actions=4, eps_end=0.01, input_dims = [8], lr=0.003)
scores, eps_history = [], []
n_games = 500

for i in range(n_games):
    score = 0
    done = False
    observation = env.reset()
    while not done:
        action = agent.choose_action(observation)
        observation_, reward, done, info = env.step(action)
        score += reward
        agent.store_transition(observation, action, reward, observation_, done)
        agent.learn()
        observation = observation_
    scores.append(score)
    eps_history.append(agent.epsilon)
    
    avg_score = np.mean(scores[-100:])
    
    print('episode ', i, 'score %.2f' % score,
         'average score %.2f' % avg_score,
         'epsilon %.2f ' % agent.epsilon)
x = [i+1 for i in range(n_games)]
filename = 'lunar_lander_2020.png'
plot_learning_curve(x, scores, eps_history, filename)
# Out:
# episode  0 score -207.90 average score -207.90 epsilon 0.99
# episode  1 score 4.32 average score -101.79 epsilon 0.95
# episode  2 score -169.46 average score -124.34 epsilon 0.91
# episode  3 score -298.81 average score -167.96 epsilon 0.86
# episode  4 score -226.16 average score -179.60 epsilon 0.82
# episode  5 score -73.62 average score -161.94 epsilon 0.76
# episode  6 score -102.26 average score -153.41 epsilon 0.70
# episode  7 score -59.79 average score -141.71 epsilon 0.64
# episode  8 score -77.22 average score -134.54 epsilon 0.59
# episode  9 score -269.75 average score -148.06 epsilon 0.49
# episode  10 score -12.17 average score -135.71 epsilon 0.42
# episode  11 score -103.38 average score -133.01 epsilon 0.28
# episode  12 score -59.69 average score -127.37 epsilon 0.18
# episode  13 score -161.55 average score -129.82 epsilon 0.10
# episode  14 score -82.82 average score -126.68 epsilon 0.01
# episode  15 score -53.73 average score -122.12 epsilon 0.01
# episode  16 score 33.31 average score -112.98 epsilon 0.01
# episode  17 score -114.63 average score -113.07 epsilon 0.01
# episode  18 score -91.39 average score -111.93 epsilon 0.01
# episode  19 score -81.09 average score -110.39 epsilon 0.01
# episode  20 score 38.67 average score -103.29 epsilon 0.01
# episode  21 score -46.99 average score -100.73 epsilon 0.01
# episode  22 score -13.12 average score -96.92 epsilon 0.01
# episode  23 score -93.97 average score -96.80 epsilon 0.01
# episode  24 score -65.14 average score -95.53 epsilon 0.01
# episode  25 score -37.98 average score -93.32 epsilon 0.01
# episode  26 score -129.45 average score -94.66 epsilon 0.01
# episode  27 score -303.30 average score -102.11 epsilon 0.01
# episode  28 score -37.81 average score -99.89 epsilon 0.01
# episode  29 score -51.86 average score -98.29 epsilon 0.01
# episode  30 score -66.23 average score -97.26 epsilon 0.01
# episode  31 score -17.90 average score -94.78 epsilon 0.01
# episode  32 score -24.50 average score -92.65 epsilon 0.01
# episode  33 score -2.05 average score -89.98 epsilon 0.01
# episode  34 score -28.88 average score -88.24 epsilon 0.01
# episode  35 score 254.55 average score -78.71 epsilon 0.01
# episode  36 score -30.63 average score -77.41 epsilon 0.01
# episode  37 score -26.14 average score -76.07 epsilon 0.01
# episode  38 score -77.54 average score -76.10 epsilon 0.01
# episode  39 score -16.76 average score -74.62 epsilon 0.01
# episode  40 score -76.49 average score -74.67 epsilon 0.01
# episode  41 score -55.43 average score -74.21 epsilon 0.01
# episode  42 score -21.08 average score -72.97 epsilon 0.01
# episode  43 score -89.27 average score -73.34 epsilon 0.01
# episode  44 score -18.84 average score -72.13 epsilon 0.01
# episode  45 score -306.26 average score -77.22 epsilon 0.01
# episode  46 score -44.44 average score -76.52 epsilon 0.01
# episode  47 score -63.10 average score -76.24 epsilon 0.01
# episode  48 score -24.49 average score -75.19 epsilon 0.01
# episode  49 score -6.23 average score -73.81 epsilon 0.01
# episode  50 score -44.31 average score -73.23 epsilon 0.01
# episode  51 score -69.18 average score -73.15 epsilon 0.01
# episode  52 score 2.17 average score -71.73 epsilon 0.01
# episode  53 score 8.03 average score -70.25 epsilon 0.01
# episode  54 score -15.69 average score -69.26 epsilon 0.01
# episode  55 score 2.97 average score -67.97 epsilon 0.01
# episode  56 score 29.14 average score -66.27 epsilon 0.01
# episode  57 score 24.20 average score -64.71 epsilon 0.01
# episode  58 score -60.39 average score -64.64 epsilon 0.01
# episode  59 score 44.01 average score -62.82 epsilon 0.01
# episode  60 score 60.35 average score -60.81 epsilon 0.01
# episode  61 score 211.04 average score -56.42 epsilon 0.01
# episode  62 score -35.05 average score -56.08 epsilon 0.01
# episode  63 score 119.16 average score -53.34 epsilon 0.01
# episode  64 score 199.89 average score -49.45 epsilon 0.01
# episode  65 score 48.29 average score -47.97 epsilon 0.01
# episode  66 score 147.54 average score -45.05 epsilon 0.01
# episode  67 score -8.87 average score -44.52 epsilon 0.01
# episode  68 score -69.91 average score -44.88 epsilon 0.01
# episode  69 score 281.60 average score -40.22 epsilon 0.01
# episode  70 score -10.05 average score -39.80 epsilon 0.01
# episode  71 score -408.41 average score -44.92 epsilon 0.01
# episode  72 score 210.92 average score -41.41 epsilon 0.01
# episode  73 score -202.25 average score -43.58 epsilon 0.01
# episode  74 score 4.44 average score -42.94 epsilon 0.01
# episode  75 score -32.00 average score -42.80 epsilon 0.01
# episode  76 score -171.67 average score -44.47 epsilon 0.01
# episode  77 score -81.36 average score -44.95 epsilon 0.01
# episode  78 score -93.03 average score -45.56 epsilon 0.01
# episode  79 score -47.19 average score -45.58 epsilon 0.01
# episode  80 score -27.13 average score -45.35 epsilon 0.01
# episode  81 score -16.22 average score -44.99 epsilon 0.01
# episode  82 score 201.79 average score -42.02 epsilon 0.01
# episode  83 score 191.37 average score -39.24 epsilon 0.01
# episode  84 score -14.27 average score -38.95 epsilon 0.01
# episode  85 score -15.75 average score -38.68 epsilon 0.01
# episode  86 score -238.50 average score -40.97 epsilon 0.01
# episode  87 score 202.67 average score -38.21 epsilon 0.01
# episode  88 score -147.06 average score -39.43 epsilon 0.01
# episode  89 score -40.25 average score -39.44 epsilon 0.01
# episode  90 score -12.09 average score -39.14 epsilon 0.01
# episode  91 score 17.00 average score -38.53 epsilon 0.01
# episode  92 score -57.25 average score -38.73 epsilon 0.01
# episode  93 score -29.58 average score -38.63 epsilon 0.01
# episode  94 score 227.29 average score -35.83 epsilon 0.01
# episode  95 score -58.16 average score -36.06 epsilon 0.01
# episode  96 score 100.36 average score -34.66 epsilon 0.01
# episode  97 score -251.79 average score -36.87 epsilon 0.01
# episode  98 score 11.03 average score -36.39 epsilon 0.01
# episode  99 score 152.47 average score -34.50 epsilon 0.01
# episode  100 score 143.27 average score -30.99 epsilon 0.01
# episode  101 score -424.19 average score -35.27 epsilon 0.01
# episode  102 score -51.86 average score -34.10 epsilon 0.01
# episode  103 score 252.28 average score -28.59 epsilon 0.01
# episode  104 score -78.09 average score -27.11 epsilon 0.01
# episode  105 score 212.41 average score -24.25 epsilon 0.01
# episode  106 score 203.68 average score -21.19 epsilon 0.01
# episode  107 score -152.25 average score -22.11 epsilon 0.01
# episode  108 score -8.49 average score -21.42 epsilon 0.01
# episode  109 score 237.12 average score -16.36 epsilon 0.01
# episode  110 score -132.71 average score -17.56 epsilon 0.01
# episode  111 score -36.04 average score -16.89 epsilon 0.01
# episode  112 score -278.39 average score -19.08 epsilon 0.01
# episode  113 score 146.29 average score -16.00 epsilon 0.01
# episode  114 score -54.98 average score -15.72 epsilon 0.01
# episode  115 score 6.70 average score -15.11 epsilon 0.01
# episode  116 score 240.78 average score -13.04 epsilon 0.01
# episode  117 score 288.25 average score -9.01 epsilon 0.01
# episode  118 score -91.10 average score -9.01 epsilon 0.01
# episode  119 score 206.07 average score -6.14 epsilon 0.01
# episode  120 score 170.00 average score -4.82 epsilon 0.01
# episode  121 score 271.08 average score -1.64 epsilon 0.01
# episode  122 score 190.93 average score 0.40 epsilon 0.01
# episode  123 score 243.38 average score 3.77 epsilon 0.01
# episode  124 score 20.28 average score 4.63 epsilon 0.01
# episode  125 score -337.53 average score 1.63 epsilon 0.01
# episode  126 score 254.08 average score 5.47 epsilon 0.01
# episode  127 score 243.04 average score 10.93 epsilon 0.01
# episode  128 score 241.94 average score 13.73 epsilon 0.01
# episode  129 score 287.92 average score 17.12 epsilon 0.01
# episode  130 score -2.71 average score 17.76 epsilon 0.01
# episode  131 score 231.97 average score 20.26 epsilon 0.01
# episode  132 score 213.50 average score 22.64 epsilon 0.01
# episode  133 score -84.34 average score 21.82 epsilon 0.01
# episode  134 score 259.42 average score 24.70 epsilon 0.01
# episode  135 score 250.81 average score 24.66 epsilon 0.01
# episode  136 score 253.98 average score 27.51 epsilon 0.01
# episode  137 score 258.92 average score 30.36 epsilon 0.01
# episode  138 score -27.06 average score 30.86 epsilon 0.01
# episode  139 score -112.31 average score 29.91 epsilon 0.01
# episode  140 score 279.61 average score 33.47 epsilon 0.01
# episode  141 score -37.16 average score 33.65 epsilon 0.01
# episode  142 score -4.81 average score 33.81 epsilon 0.01
# episode  143 score 125.01 average score 35.96 epsilon 0.01
# episode  144 score 197.17 average score 38.12 epsilon 0.01
# episode  145 score 279.16 average score 43.97 epsilon 0.01
# episode  146 score 257.09 average score 46.99 epsilon 0.01
# episode  147 score 196.53 average score 49.58 epsilon 0.01
# episode  148 score 173.32 average score 51.56 epsilon 0.01
# episode  149 score 210.80 average score 53.73 epsilon 0.01
# episode  150 score 224.63 average score 56.42 epsilon 0.01
# episode  151 score -12.95 average score 56.98 epsilon 0.01
# episode  152 score 241.50 average score 59.38 epsilon 0.01
# episode  153 score 224.27 average score 61.54 epsilon 0.01
# episode  154 score 228.09 average score 63.98 epsilon 0.01
# episode  155 score 216.02 average score 66.11 epsilon 0.01
# episode  156 score 275.52 average score 68.57 epsilon 0.01
# episode  157 score 204.11 average score 70.37 epsilon 0.01
# episode  158 score 270.39 average score 73.68 epsilon 0.01
# episode  159 score 233.46 average score 75.57 epsilon 0.01
# episode  160 score -62.92 average score 74.34 epsilon 0.01
# episode  161 score -159.52 average score 70.63 epsilon 0.01
# episode  162 score 239.92 average score 73.38 epsilon 0.01
# episode  163 score 31.81 average score 72.51 epsilon 0.01
# episode  164 score 268.56 average score 73.20 epsilon 0.01
# episode  165 score 261.50 average score 75.33 epsilon 0.01
# episode  166 score 231.76 average score 76.17 epsilon 0.01
# episode  167 score 32.53 average score 76.59 epsilon 0.01
# episode  168 score 211.92 average score 79.40 epsilon 0.01
# episode  169 score 215.06 average score 78.74 epsilon 0.01
# episode  170 score 2.22 average score 78.86 epsilon 0.01
# episode  171 score 289.24 average score 85.84 epsilon 0.01
# episode  172 score 213.52 average score 85.86 epsilon 0.01
# episode  173 score 78.72 average score 88.67 epsilon 0.01
# episode  174 score 185.35 average score 90.48 epsilon 0.01
# episode  175 score 200.12 average score 92.80 epsilon 0.01
# episode  176 score 28.11 average score 94.80 epsilon 0.01
# episode  177 score 199.50 average score 97.61 epsilon 0.01
# episode  178 score 12.09 average score 98.66 epsilon 0.01
# episode  179 score -220.87 average score 96.92 epsilon 0.01
# episode  180 score 20.64 average score 97.40 epsilon 0.01
# episode  181 score 312.11 average score 100.69 epsilon 0.01
# episode  182 score -11.13 average score 98.56 epsilon 0.01
# episode  183 score 302.13 average score 99.66 epsilon 0.01
# episode  184 score 229.86 average score 102.10 epsilon 0.01
# episode  185 score 266.78 average score 104.93 epsilon 0.01
# episode  186 score -21.88 average score 107.10 epsilon 0.01
# episode  187 score -181.09 average score 103.26 epsilon 0.01
# episode  188 score -64.62 average score 104.08 epsilon 0.01
# episode  189 score 37.42 average score 104.86 epsilon 0.01
# episode  190 score -7.86 average score 104.90 epsilon 0.01
# episode  191 score -94.81 average score 103.78 epsilon 0.01
# episode  192 score -54.58 average score 103.81 epsilon 0.01
# episode  193 score 203.99 average score 106.15 epsilon 0.01
# episode  194 score 273.41 average score 106.61 epsilon 0.01
# episode  195 score 26.32 average score 107.45 epsilon 0.01
# episode  196 score 270.34 average score 109.15 epsilon 0.01
# episode  197 score 257.70 average score 114.25 epsilon 0.01
# episode  198 score 22.71 average score 114.36 epsilon 0.01
# episode  199 score 191.99 average score 114.76 epsilon 0.01
# episode  200 score -1.63 average score 113.31 epsilon 0.01
# episode  201 score 235.91 average score 119.91 epsilon 0.01
# episode  202 score 212.90 average score 122.56 epsilon 0.01
# episode  203 score -24.61 average score 119.79 epsilon 0.01
# episode  204 score -189.92 average score 118.67 epsilon 0.01
# episode  205 score -34.43 average score 116.20 epsilon 0.01
# episode  206 score 234.61 average score 116.51 epsilon 0.01
# episode  207 score 228.80 average score 120.32 epsilon 0.01
# episode  208 score -191.24 average score 118.50 epsilon 0.01
# episode  209 score -195.90 average score 114.17 epsilon 0.01
# episode  210 score 12.25 average score 115.61 epsilon 0.01
# episode  211 score -180.11 average score 114.17 epsilon 0.01
# episode  212 score 10.30 average score 117.06 epsilon 0.01
# episode  213 score 295.00 average score 118.55 epsilon 0.01
# episode  214 score 263.09 average score 121.73 epsilon 0.01
# episode  215 score -69.73 average score 120.96 epsilon 0.01
# episode  216 score 286.49 average score 121.42 epsilon 0.01
# episode  217 score -215.08 average score 116.39 epsilon 0.01
# episode  218 score 221.07 average score 119.51 epsilon 0.01
# episode  219 score -44.52 average score 117.00 epsilon 0.01
# episode  220 score -147.51 average score 113.83 epsilon 0.01
# episode  221 score 164.37 average score 112.76 epsilon 0.01
# episode  222 score 245.25 average score 113.31 epsilon 0.01
# episode  223 score 223.82 average score 113.11 epsilon 0.01
# episode  224 score -29.13 average score 112.62 epsilon 0.01
# episode  225 score 290.14 average score 118.89 epsilon 0.01
# episode  226 score 65.17 average score 117.00 epsilon 0.01
# episode  227 score 241.41 average score 116.99 epsilon 0.01
# episode  228 score -38.78 average score 114.18 epsilon 0.01
# episode  229 score -352.01 average score 107.78 epsilon 0.01
# episode  230 score 214.17 average score 109.95 epsilon 0.01
# episode  231 score 227.99 average score 109.91 epsilon 0.01
# episode  232 score 252.62 average score 110.30 epsilon 0.01
# episode  233 score 32.53 average score 111.47 epsilon 0.01
# episode  234 score 184.10 average score 110.72 epsilon 0.01
# episode  235 score 222.47 average score 110.43 epsilon 0.01
# episode  236 score -5.77 average score 107.83 epsilon 0.01
# episode  237 score 195.56 average score 107.20 epsilon 0.01
# episode  238 score -187.64 average score 105.60 epsilon 0.01
# episode  239 score 50.11 average score 107.22 epsilon 0.01
# episode  240 score -241.76 average score 102.01 epsilon 0.01
# episode  241 score -250.91 average score 99.87 epsilon 0.01
# episode  242 score -10.69 average score 99.81 epsilon 0.01
# episode  243 score 257.46 average score 101.13 epsilon 0.01
# episode  244 score 217.03 average score 101.33 epsilon 0.01
# episode  245 score -122.30 average score 97.32 epsilon 0.01
# episode  246 score 26.97 average score 95.02 epsilon 0.01
# episode  247 score 40.51 average score 93.46 epsilon 0.01
# episode  248 score -68.58 average score 91.04 epsilon 0.01
# episode  249 score 282.42 average score 91.75 epsilon 0.01
# episode  250 score -22.30 average score 89.28 epsilon 0.01
# episode  251 score 171.34 average score 91.13 epsilon 0.01
# episode  252 score 282.09 average score 91.53 epsilon 0.01
# episode  253 score -48.68 average score 88.80 epsilon 0.01
# episode  254 score 186.96 average score 88.39 epsilon 0.01
# episode  255 score 209.60 average score 88.33 epsilon 0.01
# episode  256 score -32.26 average score 85.25 epsilon 0.01
# episode  257 score 260.13 average score 85.81 epsilon 0.01
# episode  258 score 261.89 average score 85.73 epsilon 0.01
# episode  259 score -102.96 average score 82.36 epsilon 0.01
# episode  260 score 247.55 average score 85.47 epsilon 0.01
# episode  261 score -124.22 average score 85.82 epsilon 0.01
# episode  262 score -76.10 average score 82.66 epsilon 0.01
# episode  263 score -124.58 average score 81.10 epsilon 0.01
# episode  264 score -221.58 average score 76.19 epsilon 0.01
# episode  265 score 187.59 average score 75.45 epsilon 0.01
# episode  266 score -137.73 average score 71.76 epsilon 0.01
# episode  267 score -24.73 average score 71.19 epsilon 0.01
# episode  268 score 24.80 average score 69.32 epsilon 0.01
# episode  269 score -96.43 average score 66.20 epsilon 0.01
# episode  270 score 239.21 average score 68.57 epsilon 0.01
# episode  271 score 224.12 average score 67.92 epsilon 0.01
# episode  272 score 16.16 average score 65.95 epsilon 0.01
# episode  273 score -94.95 average score 64.21 epsilon 0.01
# episode  274 score -126.19 average score 61.09 epsilon 0.01
# episode  275 score 211.42 average score 61.21 epsilon 0.01
# episode  276 score -20.33 average score 60.72 epsilon 0.01
# episode  277 score 226.65 average score 60.99 epsilon 0.01
# episode  278 score -40.17 average score 60.47 epsilon 0.01
# episode  279 score -278.38 average score 59.90 epsilon 0.01
# episode  280 score 268.19 average score 62.37 epsilon 0.01
# episode  281 score -64.38 average score 58.61 epsilon 0.01
# episode  282 score -47.71 average score 58.24 epsilon 0.01
# episode  283 score -30.24 average score 54.92 epsilon 0.01
# episode  284 score 46.28 average score 53.08 epsilon 0.01
# episode  285 score -204.46 average score 48.37 epsilon 0.01
# episode  286 score 199.00 average score 50.58 epsilon 0.01
# episode  287 score 242.06 average score 54.81 epsilon 0.01
# episode  288 score -4.72 average score 55.41 epsilon 0.01
# episode  289 score -139.74 average score 53.64 epsilon 0.01
# episode  290 score -92.61 average score 52.79 epsilon 0.01
# episode  291 score 175.64 average score 55.49 epsilon 0.01
# episode  292 score -77.77 average score 55.26 epsilon 0.01
# episode  293 score -93.22 average score 52.29 epsilon 0.01
# episode  294 score -122.40 average score 48.33 epsilon 0.01
# episode  295 score -86.72 average score 47.20 epsilon 0.01
# episode  296 score -52.52 average score 43.97 epsilon 0.01
# episode  297 score 197.23 average score 43.37 epsilon 0.01
# episode  298 score -122.12 average score 41.92 epsilon 0.01
# episode  299 score 253.41 average score 42.53 epsilon 0.01
# episode  300 score 29.72 average score 42.85 epsilon 0.01
# episode  301 score 261.28 average score 43.10 epsilon 0.01
# episode  302 score -19.81 average score 40.77 epsilon 0.01
# episode  303 score 207.74 average score 43.10 epsilon 0.01
# episode  304 score 216.99 average score 47.17 epsilon 0.01
# episode  305 score 233.71 average score 49.85 epsilon 0.01
# episode  306 score -3.67 average score 47.47 epsilon 0.01
# episode  307 score -76.54 average score 44.41 epsilon 0.01
# episode  308 score -183.50 average score 44.49 epsilon 0.01
# episode  309 score -60.44 average score 45.84 epsilon 0.01
# episode  310 score 270.74 average score 48.43 epsilon 0.01
# episode  311 score -3.77 average score 50.19 epsilon 0.01
# episode  312 score 176.00 average score 51.85 epsilon 0.01
# episode  313 score -31.47 average score 48.58 epsilon 0.01
# episode  314 score 249.50 average score 48.45 epsilon 0.01
# episode  315 score 284.93 average score 52.00 epsilon 0.01
# episode  316 score -64.99 average score 48.48 epsilon 0.01
# episode  317 score 275.58 average score 53.39 epsilon 0.01
# episode  318 score 275.59 average score 53.93 epsilon 0.01
# episode  319 score 227.57 average score 56.65 epsilon 0.01
# episode  320 score 210.72 average score 60.24 epsilon 0.01
# episode  321 score 54.62 average score 59.14 epsilon 0.01
# episode  322 score 12.56 average score 56.81 epsilon 0.01
# episode  323 score 1.04 average score 54.58 epsilon 0.01
# episode  324 score 267.72 average score 57.55 epsilon 0.01
# episode  325 score 187.88 average score 56.53 epsilon 0.01
# episode  326 score -40.82 average score 55.47 epsilon 0.01
# episode  327 score -234.69 average score 50.71 epsilon 0.01
# episode  328 score 273.85 average score 53.83 epsilon 0.01
# episode  329 score -166.11 average score 55.69 epsilon 0.01
# episode  330 score -28.05 average score 53.27 epsilon 0.01
# episode  331 score -265.24 average score 48.34 epsilon 0.01
# episode  332 score 217.23 average score 47.98 epsilon 0.01
# episode  333 score 245.38 average score 50.11 epsilon 0.01
# episode  334 score -280.63 average score 45.47 epsilon 0.01
# episode  335 score 246.40 average score 45.71 epsilon 0.01
# episode  336 score 105.34 average score 46.82 epsilon 0.01
# episode  337 score 267.43 average score 47.53 epsilon 0.01
# episode  338 score 201.78 average score 51.43 epsilon 0.01
# episode  339 score -43.75 average score 50.49 epsilon 0.01
# episode  340 score 264.07 average score 55.55 epsilon 0.01
# episode  341 score 219.70 average score 60.25 epsilon 0.01
# episode  342 score -28.21 average score 60.08 epsilon 0.01
# episode  343 score 244.10 average score 59.95 epsilon 0.01
# episode  344 score 189.59 average score 59.67 epsilon 0.01
# episode  345 score 237.67 average score 63.27 epsilon 0.01
# episode  346 score 214.63 average score 65.15 epsilon 0.01
# episode  347 score -19.70 average score 64.55 epsilon 0.01
# episode  348 score 225.47 average score 67.49 epsilon 0.01
# episode  349 score 260.87 average score 67.27 epsilon 0.01
# episode  350 score -265.30 average score 64.84 epsilon 0.01
# episode  351 score 177.77 average score 64.91 epsilon 0.01
# episode  352 score -70.34 average score 61.38 epsilon 0.01
# episode  353 score 10.23 average score 61.97 epsilon 0.01
# episode  354 score 205.18 average score 62.15 epsilon 0.01
# episode  355 score -22.52 average score 59.83 epsilon 0.01
# episode  356 score -173.70 average score 58.42 epsilon 0.01
# episode  357 score 195.70 average score 57.77 epsilon 0.01
# episode  358 score -96.62 average score 54.19 epsilon 0.01
# episode  359 score 255.10 average score 57.77 epsilon 0.01
# episode  360 score 20.62 average score 55.50 epsilon 0.01
# episode  361 score 241.80 average score 59.16 epsilon 0.01
# episode  362 score 257.63 average score 62.50 epsilon 0.01
# episode  363 score 218.19 average score 65.92 epsilon 0.01
# episode  364 score 219.38 average score 70.33 epsilon 0.01
# episode  365 score 203.17 average score 70.49 epsilon 0.01
# episode  366 score 32.99 average score 72.20 epsilon 0.01
# episode  367 score 253.63 average score 74.98 epsilon 0.01
# episode  368 score 221.32 average score 76.95 epsilon 0.01
# episode  369 score 225.44 average score 80.16 epsilon 0.01
# episode  370 score 241.87 average score 80.19 epsilon 0.01
# episode  371 score 218.55 average score 80.13 epsilon 0.01
# episode  372 score 223.10 average score 82.20 epsilon 0.01
# episode  373 score 213.79 average score 85.29 epsilon 0.01
# episode  374 score 226.08 average score 88.81 epsilon 0.01
# episode  375 score 247.80 average score 89.18 epsilon 0.01
# episode  376 score 229.95 average score 91.68 epsilon 0.01
# episode  377 score 287.28 average score 92.29 epsilon 0.01
# episode  378 score 214.40 average score 94.83 epsilon 0.01
# episode  379 score 196.72 average score 99.58 epsilon 0.01
# episode  380 score 249.25 average score 99.39 epsilon 0.01
# episode  381 score 172.45 average score 101.76 epsilon 0.01
# episode  382 score 224.60 average score 104.49 epsilon 0.01
# episode  383 score 200.60 average score 106.79 epsilon 0.01
# episode  384 score 223.93 average score 108.57 epsilon 0.01
# episode  385 score 237.53 average score 112.99 epsilon 0.01
# episode  386 score 217.24 average score 113.17 epsilon 0.01
# episode  387 score 271.05 average score 113.46 epsilon 0.01
# episode  388 score 207.74 average score 115.59 epsilon 0.01
# episode  389 score 231.73 average score 119.30 epsilon 0.01
# episode  390 score 310.09 average score 123.33 epsilon 0.01
# episode  391 score -104.63 average score 120.53 epsilon 0.01
# episode  392 score 210.13 average score 123.41 epsilon 0.01
# episode  393 score -5.36 average score 124.28 epsilon 0.01
# episode  394 score 253.57 average score 128.04 epsilon 0.01
# episode  395 score 266.71 average score 131.58 epsilon 0.01
# episode  396 score 251.74 average score 134.62 epsilon 0.01
# episode  397 score 312.33 average score 135.77 epsilon 0.01
# episode  398 score 203.42 average score 139.03 epsilon 0.01
# episode  399 score 223.43 average score 138.73 epsilon 0.01
# episode  400 score 215.61 average score 140.59 epsilon 0.01
# episode  401 score 268.66 average score 140.66 epsilon 0.01
# episode  402 score 229.60 average score 143.15 epsilon 0.01
# episode  403 score 218.22 average score 143.26 epsilon 0.01
# episode  404 score 206.81 average score 143.16 epsilon 0.01
# episode  405 score 261.77 average score 143.44 epsilon 0.01
# episode  406 score 241.56 average score 145.89 epsilon 0.01
# episode  407 score 213.13 average score 148.79 epsilon 0.01
# episode  408 score 233.34 average score 152.96 epsilon 0.01
# episode  409 score 127.94 average score 154.84 epsilon 0.01
# episode  410 score 257.43 average score 154.71 epsilon 0.01
# episode  411 score 239.68 average score 157.14 epsilon 0.01
# episode  412 score -12.31 average score 155.26 epsilon 0.01
# episode  413 score 233.52 average score 157.91 epsilon 0.01
# episode  414 score 162.73 average score 157.04 epsilon 0.01
# episode  415 score 257.48 average score 156.77 epsilon 0.01
# episode  416 score 269.11 average score 160.11 epsilon 0.01
# episode  417 score 264.69 average score 160.00 epsilon 0.01
# episode  418 score 237.06 average score 159.61 epsilon 0.01
# episode  419 score 272.55 average score 160.06 epsilon 0.01
# episode  420 score 255.50 average score 160.51 epsilon 0.01
# episode  421 score 253.36 average score 162.50 epsilon 0.01
# episode  422 score 230.85 average score 164.68 epsilon 0.01
# episode  423 score -15.83 average score 164.51 epsilon 0.01
# episode  424 score 254.25 average score 164.38 epsilon 0.01
# episode  425 score 238.86 average score 164.89 epsilon 0.01
# episode  426 score 48.15 average score 165.78 epsilon 0.01
# episode  427 score 228.70 average score 170.41 epsilon 0.01
# episode  428 score 182.40 average score 169.50 epsilon 0.01
# episode  429 score 256.73 average score 173.72 epsilon 0.01
# episode  430 score 219.10 average score 176.20 epsilon 0.01
# episode  431 score 10.73 average score 178.96 epsilon 0.01
# episode  432 score 166.56 average score 178.45 epsilon 0.01
# episode  433 score 232.43 average score 178.32 epsilon 0.01
# episode  434 score 87.16 average score 182.00 epsilon 0.01
# episode  435 score 249.35 average score 182.03 epsilon 0.01
# episode  436 score 253.23 average score 183.51 epsilon 0.01
# episode  437 score 245.11 average score 183.28 epsilon 0.01
# episode  438 score 231.35 average score 183.58 epsilon 0.01
# episode  439 score 235.70 average score 186.37 epsilon 0.01
# episode  440 score 210.64 average score 185.84 epsilon 0.01
# episode  441 score 270.62 average score 186.35 epsilon 0.01
# episode  442 score 148.81 average score 188.12 epsilon 0.01
# episode  443 score 203.90 average score 187.72 epsilon 0.01
# episode  444 score 273.45 average score 188.55 epsilon 0.01
# episode  445 score 265.84 average score 188.84 epsilon 0.01
# episode  446 score -78.40 average score 185.91 epsilon 0.01
# episode  447 score -86.75 average score 185.24 epsilon 0.01
# episode  448 score 204.87 average score 185.03 epsilon 0.01
# episode  449 score -113.07 average score 181.29 epsilon 0.01
# episode  450 score -53.04 average score 183.41 epsilon 0.01
# episode  451 score 264.33 average score 184.28 epsilon 0.01
# episode  452 score 65.58 average score 185.64 epsilon 0.01
# episode  453 score 251.78 average score 188.05 epsilon 0.01
# episode  454 score 167.27 average score 187.67 epsilon 0.01
# episode  455 score 270.71 average score 190.61 epsilon 0.01
# episode  456 score 248.76 average score 194.83 epsilon 0.01
# episode  457 score 208.41 average score 194.96 epsilon 0.01
# episode  458 score 252.72 average score 198.45 epsilon 0.01
# episode  459 score 225.21 average score 198.15 epsilon 0.01
# episode  460 score 297.01 average score 200.92 epsilon 0.01
# episode  461 score 236.06 average score 200.86 epsilon 0.01
# episode  462 score 255.09 average score 200.83 epsilon 0.01
# episode  463 score 231.76 average score 200.97 epsilon 0.01
# episode  464 score 26.81 average score 199.04 epsilon 0.01
# episode  465 score -46.34 average score 196.55 epsilon 0.01
# episode  466 score 222.19 average score 198.44 epsilon 0.01
# episode  467 score 292.75 average score 198.83 epsilon 0.01
# episode  468 score 276.78 average score 199.39 epsilon 0.01
# episode  469 score 212.01 average score 199.25 epsilon 0.01
# episode  470 score 265.80 average score 199.49 epsilon 0.01
# episode  471 score -9.92 average score 197.21 epsilon 0.01
# episode  472 score 250.45 average score 197.48 epsilon 0.01
# episode  473 score 253.17 average score 197.87 epsilon 0.01
# episode  474 score 229.50 average score 197.91 epsilon 0.01
# episode  475 score 238.98 average score 197.82 epsilon 0.01
# episode  476 score 273.88 average score 198.26 epsilon 0.01
# episode  477 score 220.19 average score 197.59 epsilon 0.01
# episode  478 score -31.28 average score 195.13 epsilon 0.01
# episode  479 score -5.33 average score 193.11 epsilon 0.01
# episode  480 score 216.75 average score 192.79 epsilon 0.01
# episode  481 score 272.65 average score 193.79 epsilon 0.01
# episode  482 score 237.30 average score 193.91 epsilon 0.01
# episode  483 score 241.66 average score 194.33 epsilon 0.01
# episode  484 score 41.39 average score 192.50 epsilon 0.01
# episode  485 score 227.64 average score 192.40 epsilon 0.01
# episode  486 score 252.00 average score 192.75 epsilon 0.01
# episode  487 score 129.87 average score 191.34 epsilon 0.01
# episode  488 score 266.12 average score 191.92 epsilon 0.01
# episode  489 score 232.80 average score 191.93 epsilon 0.01
# episode  490 score 239.07 average score 191.22 epsilon 0.01
# episode  491 score 229.21 average score 194.56 epsilon 0.01
# episode  492 score 280.12 average score 195.26 epsilon 0.01
# episode  493 score 211.68 average score 197.43 epsilon 0.01
# episode  494 score 275.16 average score 197.65 epsilon 0.01
# episode  495 score 258.28 average score 197.56 epsilon 0.01
# episode  496 score 245.44 average score 197.50 epsilon 0.01
# episode  497 score 273.49 average score 197.11 epsilon 0.01
# episode  498 score 287.37 average score 197.95 epsilon 0.01
# episode  499 score 239.32 average score 198.11 epsilon 0.01
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b788d8c437af> in <module>
#      29 x = [i+1 for i in range(n_games)]
#      30 filename = 'lunar_lander_2020.png'
# ---> 31 plot_learning_curve(x, scores, eps_history, filename)
#      32
#
# ~\Documents\GitHub\projects\practices\reinforcement learning\phil\utils.py in plot_learning_curve(x, scores, epsilons, filename, lines)
#      18     running_avg = np.empty(N)
#      19     for t in range(N):
# ---> 20         running_avg[t] = np.mean(socres[max(0,t-20):(t+1)])
#      21     ax2.scatter(x, running_avg, color="C1")
#      22     ax2.axes.get_xaxis().set_visible(False)
#
# NameError: name 'socres' is not defined
