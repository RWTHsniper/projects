# %% [markdown]
# Actor-Critic using TD

# %%
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

#Hyperparameters
learning_rate = 0.0002
gamma         = 0.98 # discount factor
n_rollout     = 20

class ActorCritic(nn.Module):
    def __init__(self):
        super(ActorCritic, self).__init__()
        self.data = [] # list containing data
        self.fc1 = nn.Linear(4,256) # fully conected first
        self.fc_pi = nn.Linear(256,2) # fully connected pi
        self.fc_v = nn.Linear(256,1) # fully connected value
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)
        
    # Neural network of policy
    def pi(self, x, softmax_dim = 0):
        x = F.relu(self.fc1(x))
        x = self.fc_pi(x)
        prob = F.softmax(x, dim=softmax_dim)
        return prob
    
    # NN for value function
    def v(self, x):
        x = F.relu(self.fc1(x))
        v = self.fc_v(x)
        return v
    
    def put_data(self, transition):
        self.data.append(transition)
        
    def make_batch(self):
        s_lst, a_lst, r_lst, s_prime_lst, done_lst = [], [], [], [], []
        for transition in self.data:
            s,a,r,s_prime,done = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r/100.0])
            s_prime_lst.append(s_prime) # next state
            done_mask = 0.0 if done else 1.0 # If an episode is done (terminated), done_mask = 0
            done_lst.append([done_mask])
        
        # Convert the lists into torch.tensor
        s_batch, a_batch, r_batch, s_prime_batch, done_batch = torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst), \
                                                               torch.tensor(r_lst, dtype=torch.float), torch.tensor(s_prime_lst, dtype=torch.float), \
                                                               torch.tensor(done_lst, dtype=torch.float)
        self.data = [] # Clear data after make_batch
        return s_batch, a_batch, r_batch, s_prime_batch, done_batch
  
    def train_net(self):
        s, a, r, s_prime, done = self.make_batch() # start with make_batch from accumulated data
        td_target = r + gamma * self.v(s_prime) * done # I guess it is tensor operation. (Vector)
        delta = td_target - self.v(s) # TD-target, advantage
        
        pi = self.pi(s, softmax_dim=1)
        pi_a = pi.gather(1,a)
        # If you use just delta, it means network. Thus, use delta.detach() since it is a constant
        loss = -torch.log(pi_a) * delta.detach() + F.smooth_l1_loss(self.v(s), td_target.detach()) # policy loss + value loss

        self.optimizer.zero_grad()
        loss.mean().backward()
        self.optimizer.step()

# %%
import numpy as np
env = gym.make('CartPole-v1')
num_states = env.observation_space.shape[0]
print("Size of State Space ->  {}".format(num_states))
num_actions = env.action_space.n
print("Size of Action Space ->  {}".format(num_actions))

model = ActorCritic()    
print_interval = 50
score = 0.0

for n_epi in range(10000):
#for n_epi in range(500): # small test
    done = False
    s = env.reset()
    while not done:
        a_list = []    
        for t in range(n_rollout):
            prob = model.pi(torch.from_numpy(s).float()) # tensor of probability. torch.from_numpy: numpy to torch tensor
            m = Categorical(prob) # Category object defined by its probability
            # m.sample() returns a tensor. draw an action 
            a = m.sample().item() # .item() returns Int
            a_list.append(a)
            s_prime, r, done, info = env.step(a) # Action and new step
            model.put_data((s,a,r,s_prime,done)) # accumulate data

            s = s_prime # update state
            score += r

            if done:
                break                     

        model.train_net()

    if n_epi%print_interval==0 and n_epi!=0:
        print('action mean max min ', np.mean(a_list), np.max(a_list), np.min(a_list))
        print("# of episode :{}, avg score : {:.1f}".format(n_epi, score/print_interval))
        score = 0.0
env.close()
# Out:
# Size of State Space ->  4
# Size of Action Space ->  2
# action mean max min  0.46153846153846156 1 0
# # of episode :50, avg score : 17.1
# action mean max min  0.625 1 0
# # of episode :100, avg score : 18.1
# action mean max min  0.2727272727272727 1 0
# # of episode :150, avg score : 23.1
# action mean max min  0.6 1 0
# # of episode :200, avg score : 27.2
# action mean max min  0.5 1 0
# # of episode :250, avg score : 33.9
# action mean max min  0.5 1 0
# # of episode :300, avg score : 40.6
# action mean max min  1.0 1 1
# # of episode :350, avg score : 53.3
# action mean max min  0.47058823529411764 1 0
# # of episode :400, avg score : 58.8
# action mean max min  0.75 1 0
# # of episode :450, avg score : 84.9
# action mean max min  0.5833333333333334 1 0
# # of episode :500, avg score : 120.9
# action mean max min  0.6 1 0
# # of episode :550, avg score : 149.4
# action mean max min  0.55 1 0
# # of episode :600, avg score : 198.7
# action mean max min  0.46153846153846156 1 0
# # of episode :650, avg score : 212.8
# action mean max min  0.25 1 0
# # of episode :700, avg score : 155.2
# action mean max min  0.6666666666666666 1 0
# # of episode :750, avg score : 167.9
# action mean max min  0.5 1 0
# # of episode :800, avg score : 163.7
# action mean max min  0.3333333333333333 1 0
# # of episode :850, avg score : 153.7
# action mean max min  0.5384615384615384 1 0
# # of episode :900, avg score : 168.2
# action mean max min  0.5 1 0
# # of episode :950, avg score : 227.5
# action mean max min  0.5333333333333333 1 0
# # of episode :1000, avg score : 355.2
# action mean max min  0.5454545454545454 1 0
# # of episode :1050, avg score : 400.0
# action mean max min  0.5 1 0
# # of episode :1100, avg score : 226.8
# action mean max min  0.5333333333333333 1 0
# # of episode :1150, avg score : 224.8
# action mean max min  0.45 1 0
# # of episode :1200, avg score : 382.2
# action mean max min  0.5 1 0
# # of episode :1250, avg score : 414.7
# action mean max min  0.55 1 0
# # of episode :1300, avg score : 455.3
# action mean max min  0.5 1 0
# # of episode :1350, avg score : 491.1
# action mean max min  0.5 1 0
# # of episode :1400, avg score : 498.5
# action mean max min  0.5 1 0
# # of episode :1450, avg score : 500.0
# action mean max min  0.45 1 0
# # of episode :1500, avg score : 500.0
# action mean max min  0.5 1 0
# # of episode :1550, avg score : 491.9
# action mean max min  0.45 1 0
# # of episode :1600, avg score : 500.0
# action mean max min  0.45 1 0
# # of episode :1650, avg score : 500.0
# action mean max min  0.45 1 0
# # of episode :1700, avg score : 494.8
# action mean max min  0.5 1 0
# # of episode :1750, avg score : 495.2
# action mean max min  0.5 1 0
# # of episode :1800, avg score : 496.5
# action mean max min  0.5 1 0
# # of episode :1850, avg score : 500.0
# action mean max min  0.45 1 0
# # of episode :1900, avg score : 500.0
# action mean max min  0.45 1 0
# # of episode :1950, avg score : 500.0
# action mean max min  0.6 1 0
# # of episode :2000, avg score : 500.0
# action mean max min  0.6 1 0
# # of episode :2050, avg score : 494.1
# action mean max min  0.45 1 0
# # of episode :2100, avg score : 500.0
# action mean max min  0.5 1 0
# # of episode :2150, avg score : 500.0
# action mean max min  0.5 1 0
# # of episode :2200, avg score : 500.0
# action mean max min  0.4 1 0
# # of episode :2250, avg score : 495.3
# action mean max min  0.45 1 0
# # of episode :2300, avg score : 500.0
# action mean max min  0.5 1 0
# # of episode :2350, avg score : 500.0
# action mean max min  0.5 1 0
# # of episode :2400, avg score : 500.0
# action mean max min  0.55 1 0
# # of episode :2450, avg score : 419.7
# action mean max min  0.5 1 0
# # of episode :2500, avg score : 500.0
# action mean max min  0.55 1 0
# # of episode :2550, avg score : 500.0
# action mean max min  0.5 1 0
# # of episode :2600, avg score : 500.0
# action mean max min  0.5 1 0
# # of episode :2650, avg score : 500.0
# action mean max min  0.5 1 0
# # of episode :2700, avg score : 500.0
# action mean max min  0.4 1 0
# # of episode :2750, avg score : 500.0
# action mean max min  0.45 1 0
# # of episode :2800, avg score : 500.0
# action mean max min  0.5 1 0
# # of episode :2850, avg score : 500.0
# action mean max min  0.5 1 0
# # of episode :2900, avg score : 500.0
# action mean max min  0.5 1 0
# # of episode :2950, avg score : 500.0
# action mean max min  0.5 1 0
# # of episode :3000, avg score : 500.0
# action mean max min  0.45 1 0
# # of episode :3050, avg score : 494.9
# action mean max min  0.5 1 0
# # of episode :3100, avg score : 500.0
# action mean max min  0.5 1 0
# # of episode :3150, avg score : 500.0
# action mean max min  0.45 1 0
# # of episode :3200, avg score : 500.0
# action mean max min  0.6 1 0
# # of episode :3250, avg score : 500.0
# action mean max min  0.55 1 0
# # of episode :3300, avg score : 500.0
# action mean max min  0.5 1 0
# # of episode :3350, avg score : 500.0
# action mean max min  0.5 1 0
# # of episode :3400, avg score : 500.0
# action mean max min  0.55 1 0
# # of episode :3450, avg score : 500.0
# action mean max min  0.5 1 0
# # of episode :3500, avg score : 444.5
# action mean max min  0.35714285714285715 1 0
# # of episode :3550, avg score : 499.1
# action mean max min  0.45454545454545453 1 0
# # of episode :3600, avg score : 237.6
# action mean max min  0.5384615384615384 1 0
# # of episode :3650, avg score : 122.0
# action mean max min  0.55 1 0
# # of episode :3700, avg score : 129.4
# action mean max min  0.5 1 0
# # of episode :3750, avg score : 119.2
# action mean max min  0.5 1 0
# # of episode :3800, avg score : 120.1
# action mean max min  0.5 1 0
# # of episode :3850, avg score : 126.6
# action mean max min  1.0 1 1
# # of episode :3900, avg score : 128.3
# action mean max min  0.42857142857142855 1 0
# # of episode :3950, avg score : 126.8
# action mean max min  0.375 1 0
# # of episode :4000, avg score : 134.8
# action mean max min  0.45454545454545453 1 0
# # of episode :4050, avg score : 134.1
# action mean max min  0.4444444444444444 1 0
# # of episode :4100, avg score : 134.9
# action mean max min  0.45454545454545453 1 0
# # of episode :4150, avg score : 130.4
# action mean max min  0.47368421052631576 1 0
# # of episode :4200, avg score : 143.4
# action mean max min  1.0 1 1
# # of episode :4250, avg score : 159.8
# action mean max min  0.45 1 0
# # of episode :4300, avg score : 163.8
# action mean max min  0.5 1 0
# # of episode :4350, avg score : 211.4
# action mean max min  0.55 1 0
# # of episode :4400, avg score : 358.9
# action mean max min  0.5 1 0
# # of episode :4450, avg score : 279.3
# action mean max min  0.5555555555555556 1 0
# # of episode :4500, avg score : 333.5
# action mean max min  0.5 1 0
# # of episode :4550, avg score : 378.0
# action mean max min  0.6 1 0
# # of episode :4600, avg score : 346.6
# action mean max min  0.5333333333333333 1 0
# # of episode :4650, avg score : 357.8
# action mean max min  0.5 1 0
# # of episode :4700, avg score : 293.2
# action mean max min  0.5714285714285714 1 0
# # of episode :4750, avg score : 384.8
# action mean max min  0.0 0 0
# # of episode :4800, avg score : 296.6
# action mean max min  0.4444444444444444 1 0
# # of episode :4850, avg score : 355.1
# action mean max min  0.4444444444444444 1 0
# # of episode :4900, avg score : 312.3
# action mean max min  0.45454545454545453 1 0
# # of episode :4950, avg score : 195.3
# action mean max min  1.0 1 1
# # of episode :5000, avg score : 88.2
# action mean max min  0.5 1 0
# # of episode :5050, avg score : 66.0
# action mean max min  0.375 1 0
# # of episode :5100, avg score : 70.9
# action mean max min  0.3333333333333333 1 0
# # of episode :5150, avg score : 73.2
# action mean max min  0.5 1 0
# # of episode :5200, avg score : 88.0
# action mean max min  0.4375 1 0
# # of episode :5250, avg score : 108.5
# action mean max min  0.6 1 0
# # of episode :5300, avg score : 220.9
# action mean max min  0.6666666666666666 1 0
# # of episode :5350, avg score : 200.0
# action mean max min  0.5384615384615384 1 0
# # of episode :5400, avg score : 189.9
# action mean max min  0.5 1 0
# # of episode :5450, avg score : 197.4
# action mean max min  0.4444444444444444 1 0
# # of episode :5500, avg score : 209.9
# action mean max min  0.5625 1 0
# # of episode :5550, avg score : 193.6
# action mean max min  0.6666666666666666 1 0
# # of episode :5600, avg score : 207.4
# action mean max min  0.5 1 0
# # of episode :5650, avg score : 195.2
# action mean max min  0.5294117647058824 1 0
# # of episode :5700, avg score : 209.2
# action mean max min  0.5882352941176471 1 0
# # of episode :5750, avg score : 204.5
# action mean max min  0.3333333333333333 1 0
# # of episode :5800, avg score : 219.0
# action mean max min  0.5384615384615384 1 0
# # of episode :5850, avg score : 258.1
# action mean max min  0.5 1 0
# # of episode :5900, avg score : 216.6
# action mean max min  0.5714285714285714 1 0
# # of episode :5950, avg score : 200.2
# action mean max min  0.5714285714285714 1 0
# # of episode :6000, avg score : 223.2
# action mean max min  0.625 1 0
# # of episode :6050, avg score : 278.9
# action mean max min  0.5 1 0
# # of episode :6100, avg score : 253.5
# action mean max min  0.0 0 0
# # of episode :6150, avg score : 264.7
# action mean max min  0.5833333333333334 1 0
# # of episode :6200, avg score : 226.5
# action mean max min  0.4 1 0
# # of episode :6250, avg score : 197.3
# action mean max min  0.5333333333333333 1 0
# # of episode :6300, avg score : 208.4
# action mean max min  0.5 1 0
# # of episode :6350, avg score : 211.2
# action mean max min  0.5555555555555556 1 0
# # of episode :6400, avg score : 256.9
# action mean max min  0.5 1 0
# # of episode :6450, avg score : 315.6
# action mean max min  0.5 1 0
# # of episode :6500, avg score : 410.9
# action mean max min  0.42857142857142855 1 0
# # of episode :6550, avg score : 429.2
# action mean max min  0.4666666666666667 1 0
# # of episode :6600, avg score : 283.0
# action mean max min  0.45454545454545453 1 0
# # of episode :6650, avg score : 246.5
# action mean max min  0.5 1 0
# # of episode :6700, avg score : 328.8
# action mean max min  0.5 1 0
# # of episode :6750, avg score : 476.1
# action mean max min  0.5 1 0
# # of episode :6800, avg score : 436.1
# action mean max min  0.5555555555555556 1 0
# # of episode :6850, avg score : 359.5
# action mean max min  0.5 1 0
# # of episode :6900, avg score : 377.2
# action mean max min  0.46153846153846156 1 0
# # of episode :6950, avg score : 383.4
# action mean max min  0.46153846153846156 1 0
# # of episode :7000, avg score : 309.9
# action mean max min  0.45454545454545453 1 0
# # of episode :7050, avg score : 334.5
# action mean max min  0.4666666666666667 1 0
# # of episode :7100, avg score : 272.4
# action mean max min  0.4 1 0
# # of episode :7150, avg score : 285.6
# action mean max min  0.4444444444444444 1 0
# # of episode :7200, avg score : 360.8
# action mean max min  0.45 1 0
# # of episode :7250, avg score : 354.4
# action mean max min  0.42857142857142855 1 0
# # of episode :7300, avg score : 359.2
# action mean max min  0.375 1 0
# # of episode :7350, avg score : 285.7
# action mean max min  0.55 1 0
# # of episode :7400, avg score : 435.6
# action mean max min  0.45 1 0
# # of episode :7450, avg score : 414.7
# action mean max min  0.55 1 0
# # of episode :7500, avg score : 313.5
# action mean max min  0.5 1 0
# # of episode :7550, avg score : 260.6
# action mean max min  0.5454545454545454 1 0
# # of episode :7600, avg score : 246.2
# action mean max min  0.5384615384615384 1 0
# # of episode :7650, avg score : 238.8
# action mean max min  1.0 1 1
# # of episode :7700, avg score : 406.6
# action mean max min  0.5 1 0
# # of episode :7750, avg score : 445.3
# action mean max min  0.47368421052631576 1 0
# # of episode :7800, avg score : 352.4
# action mean max min  0.4666666666666667 1 0
# # of episode :7850, avg score : 307.4
# action mean max min  0.5294117647058824 1 0
# # of episode :7900, avg score : 423.6
# action mean max min  0.5 1 0
# # of episode :7950, avg score : 389.3
# action mean max min  0.5 1 0
# # of episode :8000, avg score : 408.1
# action mean max min  0.4444444444444444 1 0
# # of episode :8050, avg score : 308.6
# action mean max min  0.4 1 0
# # of episode :8100, avg score : 359.6
# action mean max min  0.4444444444444444 1 0
# # of episode :8150, avg score : 397.0
# action mean max min  0.47368421052631576 1 0
# # of episode :8200, avg score : 378.6
# action mean max min  0.4 1 0
# # of episode :8250, avg score : 371.3
# action mean max min  0.46153846153846156 1 0
# # of episode :8300, avg score : 385.1
# action mean max min  0.4444444444444444 1 0
# # of episode :8350, avg score : 436.7
# action mean max min  0.4 1 0
# # of episode :8400, avg score : 374.3
# action mean max min  0.38461538461538464 1 0
# # of episode :8450, avg score : 287.6
# action mean max min  0.4444444444444444 1 0
# # of episode :8500, avg score : 217.3
# action mean max min  0.3333333333333333 1 0
# # of episode :8550, avg score : 276.6
# action mean max min  0.4375 1 0
# # of episode :8600, avg score : 165.2
# action mean max min  0.5 1 0
# # of episode :8650, avg score : 235.3
# action mean max min  0.35294117647058826 1 0
# # of episode :8700, avg score : 376.3
# action mean max min  0.45 1 0
# # of episode :8750, avg score : 372.5
# action mean max min  0.4375 1 0
# # of episode :8800, avg score : 362.8
# action mean max min  0.42105263157894735 1 0
# # of episode :8850, avg score : 350.3
# action mean max min  0.625 1 0
# # of episode :8900, avg score : 294.8
# action mean max min  0.7272727272727273 1 0
# # of episode :8950, avg score : 240.1
# action mean max min  0.5789473684210527 1 0
# # of episode :9000, avg score : 200.4
# action mean max min  1.0 1 1
# # of episode :9050, avg score : 178.5
# action mean max min  0.6 1 0
# # of episode :9100, avg score : 165.8
# action mean max min  0.5555555555555556 1 0
# # of episode :9150, avg score : 172.5
# action mean max min  0.16666666666666666 1 0
# # of episode :9200, avg score : 179.7
# action mean max min  0.6666666666666666 1 0
# # of episode :9250, avg score : 184.3
# action mean max min  1.0 1 1
# # of episode :9300, avg score : 205.2
# action mean max min  0.6153846153846154 1 0
# # of episode :9350, avg score : 213.2
# action mean max min  0.5 1 0
# # of episode :9400, avg score : 231.9
# action mean max min  0.5454545454545454 1 0
# # of episode :9450, avg score : 335.4
# action mean max min  0.47058823529411764 1 0
# # of episode :9500, avg score : 344.9
# action mean max min  0.35714285714285715 1 0
# # of episode :9550, avg score : 268.2
# action mean max min  0.4 1 0
# # of episode :9600, avg score : 238.7
# action mean max min  0.5 1 0
# # of episode :9650, avg score : 223.3
# action mean max min  0.45 1 0
# # of episode :9700, avg score : 203.5
# action mean max min  0.4444444444444444 1 0
# # of episode :9750, avg score : 276.0
# action mean max min  0.4444444444444444 1 0
# # of episode :9800, avg score : 340.0
# action mean max min  0.5294117647058824 1 0
# # of episode :9850, avg score : 310.4
# action mean max min  0.6666666666666666 1 0
# # of episode :9900, avg score : 322.5
# action mean max min  0.5384615384615384 1 0
# # of episode :9950, avg score : 267.9
