# %%
import gym
import numpy as np
from ddqn_agent import DDQNAgent
from utils import plot_learning_curve

from env6 import TradingSPYEnv
#from env6_noshort import TradingSPYEnv
import numpy as np
import os

# %%
#env = TradingSPYEnv(init_invest=100.0, sma_len=[5,10,15,20,25],train_test_split=0.6)
#env = TradingSPYEnv(init_invest=100.0, sma_len=[5,25,50],train_test_split=0.3)
env = TradingSPYEnv(train_data_path='historySPY.csv',init_invest=100.0, sma_len=[5,25,50],train_test_split=0.3)
first_test_step = env.current_step

num_states = env.reset(first_test_step).shape[0]
print("Size of State Space ->  {}".format(num_states))
num_actions = env.action_space.n
print("Size of Action Space ->  {}".format(num_actions))


agent = DDQNAgent(gamma=0.99, epsilon=1.0, lr=0.0001,
                 input_dims=[num_states],
                 n_actions=num_actions, mem_size=100000, eps_min=0.1,
                 batch_size=1024, replace=10000, eps_dec=5e-6,
                 chkpt_dir='models/', algo='DDQNAgent',
                 env_name='stock',
                 fc1_dims=128, fc2_dims=128, p = 0.2, weight_decay=1e-5)


#agent = Agent(gamma=0.99, epsilon=0.5, batch_size=8192, n_actions=num_actions, eps_dec=1e-5, eps_end=0.1, 
#              input_dims = [num_states], lr=0.00005, p=0.5,
#              weight_decay=1e-5)
# Out:
# C:\Users\golde\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# Size of State Space ->  51
# Size of Action Space ->  3

# %%
scores, eps_history = [], []
n_games = 1000
max_score = 0.0
#learn_frequency = 4
#learn_count = 0


for i in range(n_games):
    score = 0.0
    done = False
    observation = env.reset(first_test_step)
    while not done:
        action = agent.choose_action(observation)
        observation_, reward, done, info = env.step(action)
        if (observation_ is not None): 
            score += reward
            agent.store_transition(observation, action, reward, observation_, done)
        agent.learn()
#        if learn_count == learn_frequency:
#            agent.learn()
#            learn_count = 0
#        else:
#            learn_count += 1
        observation = observation_
#    agent.learn() # Learn after one episode
    scores.append(score)
    eps_history.append(agent.epsilon)
    
    avg_score = np.mean(scores[-100:])
    
    print('episode ', i, 'score %.2f' % score,
         'average score %.2f' % avg_score,
         'epsilon %.2f ' % agent.epsilon,
         'profit_iteration %.2f ' % info['profit_iteration'],
         'iterations %.2f ' % info['iterations'],
         'long_return %.2f ' % info['long_return']
         )
    
    if (i !=0) and(i % 10 == 0):
        agent.save_models()
        print("saved check point")
# Out:
# episode  0 score -0.48 average score -0.48 epsilon 1.00  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  1 score -0.16 average score -0.32 epsilon 1.00  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  2 score -0.46 average score -0.37 epsilon 1.00  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  3 score -0.55 average score -0.41 epsilon 1.00  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  4 score -0.29 average score -0.39 epsilon 0.99  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  5 score -0.23 average score -0.36 epsilon 0.99  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  6 score -0.39 average score -0.37 epsilon 0.99  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  7 score -0.40 average score -0.37 epsilon 0.99  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  8 score -0.42 average score -0.38 epsilon 0.98  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  9 score -0.82 average score -0.42 epsilon 0.98  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  10 score -0.47 average score -0.43 epsilon 0.98  profit_iteration 0.00  iterations 490.00  long_return 1.49
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  11 score -0.63 average score -0.44 epsilon 0.98  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  12 score -0.65 average score -0.46 epsilon 0.97  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  13 score -0.41 average score -0.45 epsilon 0.97  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  14 score -0.45 average score -0.45 epsilon 0.97  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode
profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  125 score -0.08 average score -0.39 epsilon 0.70  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  126 score -0.40 average score -0.40 epsilon 0.69  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  127 score -0.26 average score -0.39 epsilon 0.69  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  128 score -0.47 average score -0.39 epsilon 0.69  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  129 score -0.31 average score -0.39 epsilon 0.69  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  130 score -0.40 average score -0.39 epsilon 0.68  profit_iteration 0.00  iterations 490.00  long_return 1.49
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  131 score -0.29 average score -0.39 epsilon 0.68  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  132 score -0.10 average score -0.39 epsilon 0.68  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  133 score -0.34 average score -0.39 epsilon 0.68  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  134 score -0.23 average score -0.39 epsilon 0.67  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  135 score -0.09 average score -0.38 epsilon 0.67  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  136 score -0.33 average score -0.38 epsilon 0.67  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  137 score -0.14 average score -0.38 epsilon 0.67  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  138 score -0.37 average score -0.38 epsilon 0.66  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  139 score -0.48 average score -0.39 epsilon 0.66  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  140 score -0.14 average score -0.38 epsilon 0.66  profit_iteration 0.00  iterations 490.00  long_return 1.49
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  141 score -0.28 average score -0.38 epsilon 0.66  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  142 score -0.44 average score -0.38 epsilon 0.65  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  143 score -0.41 average score -0.38 epsilon 0.65  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  144 score -0.45 average score -0.38 epsilon 0.65  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  145 score -0.42 average score -0.39 epsilon 0.65  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  146 score -0.21 average score -0.38 epsilon 0.64  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  147 score 0.00 average score -0.38 epsilon 0.64  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  148 score -0.07 average score -0.38 epsilon 0.64  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  149 score -0.44 average score -0.38 epsilon 0.64  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  150 score -0.37 average score -0.37 epsilon 0.63  profit_iteration 0.00  iterations 490.00  long_return 1.49
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  151 score 0.03 average score -0.37 epsilon 0.63  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  152 score -0.11 average score -0.36 epsilon 0.63  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  153 score -0.20 average score -0.36 epsilon 0.63  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  154 score -0.34 average score -0.36 epsilon 0.62  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  155 score 0.00 average score -0.36 epsilon 0.62  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  156 score -0.40 average score -0.36 epsilon 0.62  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  157 score -0.26 average score -0.36 epsilon 0.62  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  158 score -0.25 average score -0.35 epsilon 0.61  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  159 score 0.01 average score -0.35 epsilon 0.61  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  160 score -0.17 average score -0.35 epsilon 0.61  profit_iteration 0.00  iterations 490.00  long_return 1.49
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  161 score -0.38 average score -0.34 epsilon 0.61  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  162 score -0.07 average score -0.34 epsilon 0.60  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  163 score -0.46 average score -0.34 epsilon 0.60  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  164 score -0.55 average score -0.34 epsilon 0.60  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  165 score -0.17 average score -0.34 epsilon 0.60  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  166 score -0.51 average score -0.34 epsilon 0.60  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  167 score -0.11 average score -0.34 epsilon 0.59  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  168 score -0.18 average score -0.34 epsilon 0.59  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  169 score -0.19 average score -0.34 epsilon 0.59  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  170 score -0.24 average score -0.33 epsilon 0.59  profit_iteration 0.00  iterations 490.00  long_return 1.49
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  171 score -0.21 average score -0.33 epsilon 0.58  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  172 score -0.18 average score -0.33 epsilon 0.58  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  173 score -0.11 average score -0.33 epsilon 0.58  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  174 score -0.40 average score -0.33 epsilon 0.58  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  175 score -0.35 average score -0.33 epsilon 0.57  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  176 score -0.35 average score -0.33 epsilon 0.57  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  177 score -0.31 average score -0.33 epsilon 0.57  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  178 score -0.31 average score -0.32 epsilon 0.57  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  179 score 0.01 average score -0.32 epsilon 0.56  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  180 score -0.23 average score -0.32 epsilon 0.56  profit_iteration 0.00  iterations 490.00  long_return 1.49
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  181 score -0.18 average score -0.31 epsilon 0.56  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  182 score -0.10 average score -0.31 epsilon 0.56  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  183 score -0.23 average score -0.31 epsilon 0.55  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  184 score -0.21 average score -0.31 epsilon 0.55  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  185 score -0.14 average score -0.31 epsilon 0.55  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  186 score 0.09 average score -0.30 epsilon 0.55  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  187 score -0.36 average score -0.30 epsilon 0.54  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  188 score -0.21 average score -0.30 epsilon 0.54  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  189 score -0.48 average score -0.30 epsilon 0.54  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  190 score -0.25 average score -0.30 epsilon 0.54  profit_iteration 0.00  iterations 490.00  long_return 1.49
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  191 score -0.13 average score -0.29 epsilon 0.53  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  192 score -0.22 average score -0.29 epsilon 0.53  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  193 score -0.17 average score -0.29 epsilon 0.53  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  194 score -0.47 average score -0.29 epsilon 0.53  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  195 score -0.02 average score -0.28 epsilon 0.52  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  196 score -0.21 average score -0.28 epsilon 0.52  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  197 score -0.04 average score -0.27 epsilon 0.52  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  198 score -0.22 average score -0.27 epsilon 0.52  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  199 score -0.35 average score -0.27 epsilon 0.51  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  200 score -0.34 average score -0.27 epsilon 0.51  profit_iteration 0.00  iterations 490.00  long_return 1.49
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  201 score -0.20 average score -0.27 epsilon 0.51  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  202 score 0.19 average score -0.27 epsilon 0.51  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  203 score -0.20 average score -0.27 epsilon 0.50  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  204 score -0.11 average score -0.26 epsilon 0.50  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  205 score -0.06 average score -0.26 epsilon 0.50  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  206 score -0.06 average score -0.26 epsilon 0.50  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  207 score 0.13 average score -0.25 epsilon 0.49  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  208 score -0.45 average score -0.25 epsilon 0.49  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  209 score -0.13 average score -0.25 epsilon 0.49  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  210 score -0.14 average score -0.25 epsilon 0.49  profit_iteration 0.00  iterations 490.00  long_return 1.49
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  211 score -0.30 average score -0.24 epsilon 0.48  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  212 score -0.05 average score -0.24 epsilon 0.48  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  213 score -0.20 average score -0.24 epsilon 0.48  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  214 score -0.18 average score -0.23 epsilon 0.48  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  215 score -0.20 average score -0.23 epsilon 0.47  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  216 score -0.40 average score -0.24 epsilon 0.47  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  217 score 0.08 average score -0.23 epsilon 0.47  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  218 score -0.15 average score -0.23 epsilon 0.47  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  219 score -0.32 average score -0.23 epsilon 0.47  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  220 score -0.08 average score -0.23 epsilon 0.46  profit_iteration 0.00  iterations 490.00  long_return 1.49
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  221 score -0.38 average score -0.23 epsilon 0.46  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  222 score -0.21 average score -0.23 epsilon 0.46  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  223 score -0.15 average score -0.23 epsilon 0.46  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  224 score -0.18 average score -0.22 epsilon 0.45  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  225 score -0.20 average score -0.23 epsilon 0.45  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  226 score -0.17 average score -0.22 epsilon 0.45  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  227 score -0.15 average score -0.22 epsilon 0.45  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  228 score 0.05 average score -0.22 epsilon 0.44  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  229 score -0.19 average score -0.22 epsilon 0.44  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  230 score 0.16 average score -0.21 epsilon 0.44  profit_iteration 0.00  iterations 490.00  long_return 1.49
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  231 score -0.13 average score -0.21 epsilon 0.44  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  232 score -0.23 average score -0.21 epsilon 0.43  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  233 score -0.08 average score -0.21 epsilon 0.43  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  234 score -0.02 average score -0.21 epsilon 0.43  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  235 score -0.04 average score -0.21 epsilon 0.43  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  236 score -0.22 average score -0.20 epsilon 0.42  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  237 score -0.15 average score -0.20 epsilon 0.42  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  238 score -0.05 average score -0.20 epsilon 0.42  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  239 score -0.23 average score -0.20 epsilon 0.42  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  240 score 0.08 average score -0.20 epsilon 0.41  profit_iteration 0.00  iterations 490.00  long_return 1.49
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  241 score -0.18 average score -0.20 epsilon 0.41  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  242 score -0.18 average score -0.19 epsilon 0.41  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  243 score 0.09 average score -0.19 epsilon 0.41  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  244 score -0.05 average score -0.18 epsilon 0.40  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  245 score 0.28 average score -0.18 epsilon 0.40  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  246 score -0.04 average score -0.17 epsilon 0.40  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  247 score -0.14 average score -0.18 epsilon 0.40  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  248 score -0.09 average score -0.18 epsilon 0.39  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  249 score 0.05 average score -0.17 epsilon 0.39  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  250 score -0.02 average score -0.17 epsilon 0.39  profit_iteration 0.00  iterations 490.00  long_return 1.49
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  251 score -0.09 average score -0.17 epsilon 0.39  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  252 score 0.02 average score -0.17 epsilon 0.38  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  253 score 0.04 average score -0.17 epsilon 0.38  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  254 score -0.06 average score -0.16 epsilon 0.38  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  255 score 0.13 average score -0.16 epsilon 0.38  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  256 score -0.12 average score -0.16 epsilon 0.37  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  257 score -0.03 average score -0.16 epsilon 0.37  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  258 score -0.17 average score -0.16 epsilon 0.37  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  259 score -0.17 average score -0.16 epsilon 0.37  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  260 score -0.05 average score -0.16 epsilon 0.36  profit_iteration 0.00  iterations 490.00  long_return 1.49
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  261 score -0.30 average score -0.16 epsilon 0.36  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  262 score 0.03 average score -0.15 epsilon 0.36  profit_iteration 0.00  iterations 490.00  long_return 1.49
# episode  263 score 0.05 average score -0.15 epsilon 0.36  profit_iteration 0.00  iterations 490.00  long_return 1.49
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-a4fbccf4249a> in <module>
#      16             score += reward
#      17             agent.store_transition(observation, action, reward, observation_, done)
# ---> 18         agent.learn()
#      19 #        if learn_count == learn_frequency:
#      20 #            agent.learn()
#
# ~\Documents\GitHub\projects\practices\reinforcement learning\DDQN-stock-sma\ddqn_agent.py in learn(self)
#      84
#      85         q_pred = self.q_eval.forward(states)[indices, actions]
# ---> 86         q_next = self.q_next.forward(states_)
#      87         q_eval = self.q_eval.forward(states_)
#      88
#
# ~\Documents\GitHub\projects\practices\reinforcement learning\DDQN-stock-sma\deep_q_network.py in forward(self, state)
#      38
#      39         actions = T.tanh(self.fc1(state))
# ---> 40         actions = T.tanh(self.fc2(actions))
#      41         actions = self.dropout(actions) # dropout for regularization
#      42         actions = self.fc3(actions)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      89
#      90     def forward(self, input: Tensor) -> Tensor:
# ---> 91         return F.linear(input, self.weight, self.bias)
#      92
#      93     def extra_repr(self) -> str:
#
# ~\Anaconda3\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1672     if input.dim() == 2 and bias is not None:
#    1673         # fused op is marginally faster
# -> 1674         ret = torch.addmm(bias, input, weight.t())
#    1675     else:
#    1676         output = input.matmul(weight.t())
#
# KeyboardInterrupt:
