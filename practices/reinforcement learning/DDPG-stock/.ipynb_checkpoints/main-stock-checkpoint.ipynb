# %%
import os
#from stock_env import TradingSPYEnv
from env2 import TradingSPYEnv
import numpy as np
from ddpg_torch import Agent
from utils import plot_learning_curve

# %%
#env = TradingSPYEnv(init_invest=100.0, sma_len=[5,10,15,20])
env = TradingSPYEnv(init_invest=100.0, sma_len=[5,10,15,20])

num_states = len(env._get_observation())
print("Size of State Space ->  {}".format(num_states))
num_actions = env.action_space.n
print("Size of Action Space ->  {}".format(num_actions))

"""
agent = Agent(alpha=0.0001, beta=0.001, 
                input_dims=[num_states], tau=0.001,
                batch_size=64, fc1_dims=400, fc2_dims=300, 
                n_actions=num_actions, chkpt_dir=os.getcwd())
"""
agent = Agent(alpha=0.0001, beta=0.001, 
                input_dims=[num_states], tau=0.1,
                batch_size=64, fc1_dims=16, fc2_dims=16, 
                n_actions=num_actions, chkpt_dir=os.getcwd())
n_games = 1000
filename = 'LunarLander_alpha_' + str(agent.alpha) + '_beta_' + \
            str(agent.beta) + '_' + str(n_games) + '_games'
figure_file = 'plots/' + filename + '.png'
# Out:
# C:\Users\golde\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# Size of State Space ->  7
# Size of Action Space ->  3

# %%
best_score = 1000
score_history = []

# %%
for i in range(n_games):
    observation = env.reset()
    done = False
    score = 0
    agent.noise.reset()
    while not done:
        action = agent.choose_action(observation)
        action = action.argmax()
        observation_, reward, done, info = env.step(action)
        if done:
            break
        agent.remember(observation, action, reward, observation_, done)
        agent.learn()
        score += reward
        observation = observation_
    score_history.append(score)
    avg_score = np.mean(score_history[-100:])

    if avg_score > best_score:
        best_score = avg_score
        agent.save_models()
        
    print('episode ', i, 'score %.2f' % score,
     'average score %.2f' % avg_score,
     'profit_iteration %.2f ' % info['profit_iteration'],
     'iterations %.2f ' % info['iterations'],
     'long_return %.2f ' % info['long_return']
     )
    
    
x = [i+1 for i in range(n_games)]
plot_learning_curve(x, score_history, figure_file)
# Out:
# episode  0 score -4.46 average score -4.46 profit_iteration -0.00  iterations 4195.00  long_return 3.42
# episode  1 score -17.44 average score -10.95 profit_iteration -0.02  iterations 1123.00  long_return 1.60
# episode  2 score 10.42 average score -3.83 profit_iteration 0.03  iterations 394.00  long_return 1.20
# episode  3 score 24.58 average score 3.27 profit_iteration 0.01  iterations 2251.00  long_return 2.99
# episode  4 score 107.88 average score 24.20 profit_iteration 0.05  iterations 1990.00  long_return 2.69
# episode  5 score -19.37 average score 16.94 profit_iteration -0.01  iterations 2977.00  long_return 2.48
# episode  6 score 5.86 average score 15.35 profit_iteration 0.00  iterations 3163.00  long_return 2.73
# episode  7 score 1.47 average score 13.62 profit_iteration 0.00  iterations 2452.00  long_return 3.97
# episode  8 score -68.81 average score 4.46 profit_iteration -0.03  iterations 2435.00  long_return 4.33
# episode  9 score -0.51 average score 3.96 profit_iteration -0.00  iterations 619.00  long_return 1.40
# episode  10 score 51.34 average score 8.27 profit_iteration 0.05  iterations 996.00  long_return 1.47
# episode  11 score -76.75 average score 1.18 profit_iteration -0.03  iterations 2356.00  long_return 3.58
# episode  12 score 25.10 average score 3.02 profit_iteration 0.02  iterations 1327.00  long_return 1.82
# episode  13 score -14.78 average score 1.75 profit_iteration -0.01  iterations 1095.00  long_return 1.53
# episode  14 score -7.55 average score 1.13 profit_iteration -0.00  iterations 2635.00  long_return 2.41
# episode  15 score 198.28 average score 13.45 profit_iteration 0.05  iterations 3718.00  long_return 3.25
# episode  16 score -11.57 average score 11.98 profit_iteration -0.00  iterations 3859.00  long_return 3.82
# episode  17 score 23.72 average score 12.63 profit_iteration 0.01  iterations 3395.00  long_return 3.16
# episode  18 score 72.04 average score 15.76 profit_iteration 0.02  iterations 3532.00  long_return 3.25
# episode  19 score -33.98 average score 13.27 profit_iteration -0.01  iterations 3547.00  long_return 3.23
# episode  20 score 9.36 average score 13.09 profit_iteration 0.01  iterations 763.00  long_return 1.45
# episode  21 score -8.70 average score 12.10 profit_iteration -0.01  iterations 672.00  long_return 1.51
# episode  22 score -39.72 average score 9.84 profit_iteration -0.04  iterations 1060.00  long_return 1.57
# episode  23 score 66.11 average score 12.19 profit_iteration 0.04  iterations 1666.00  long_return 2.29
# episode  24 score 59.79 average score 14.09 profit_iteration 0.02  iterations 2884.00  long_return 2.33
# episode  25 score -47.20 average score 11.73 profit_iteration -0.01  iterations 3396.00  long_return 3.12
# episode  26 score 8.91 average score 11.63 profit_iteration 0.03  iterations 336.00  long_return 1.16
# episode  27 score 11.20 average score 11.61 profit_iteration 0.15  iterations 80.00  long_return 1.02
# episode  28 score 65.78 average score 13.48 profit_iteration 0.05  iterations 1215.00  long_return 1.65
# episode  29 score -13.24 average score 12.59 profit_iteration -0.03  iterations 467.00  long_return 1.25
# episode  30 score -68.53 average score 9.97 profit_iteration -0.02  iterations 3328.00  long_return 2.88
# episode  31 score 171.00 average score 15.01 profit_iteration 0.07  iterations 2350.00  long_return 3.71
# episode  32 score 41.20 average score 15.80 profit_iteration 0.06  iterations 632.00  long_return 1.37
# episode  33 score -63.53 average score 13.47 profit_iteration -0.02  iterations 3849.00  long_return 3.75
# episode  34 score 16.98 average score 13.57 profit_iteration 0.04  iterations 454.00  long_return 1.26
# episode  35 score -17.65 average score 12.70 profit_iteration -0.01  iterations 2050.00  long_return 3.08
# episode  36 score -26.60 average score 11.64 profit_iteration -0.01  iterations 3542.00  long_return 3.28
# episode  37 score -2.80 average score 11.26 profit_iteration -0.00  iterations 2660.00  long_return 2.50
# episode  38 score 31.08 average score 11.77 profit_iteration 0.02  iterations 1364.00  long_return 1.85
# episode  39 score -44.33 average score 10.36 profit_iteration -0.02  iterations 1800.00  long_return 2.70
# episode  40 score -5.04 average score 9.99 profit_iteration -0.00  iterations 2739.00  long_return 2.32
# episode  41 score 69.32 average score 11.40 profit_iteration 0.03  iterations 2470.00  long_return 3.77
# episode  42 score 72.97 average score 12.83 profit_iteration 0.02  iterations 3809.00  long_return 3.62
# episode  43 score -9.74 average score 12.32 profit_iteration -0.01  iterations 953.00  long_return 1.45
# episode  44 score 5.11 average score 12.16 profit_iteration 0.08  iterations 71.00  long_return 0.99
# episode  45 score -2.11 average score 11.85 profit_iteration -0.01  iterations 113.00  long_return 1.02
# episode  46 score -47.26 average score 10.59 profit_iteration -0.01  iterations 4171.00  long_return 3.32
# episode  47 score 15.39 average score 10.69 profit_iteration 0.01  iterations 2235.00  long_return 2.97
# episode  48 score 69.25 average score 11.89 profit_iteration 0.03  iterations 2677.00  long_return 2.62
# episode  49 score -45.43 average score 10.74 profit_iteration -0.03  iterations 1571.00  long_return 2.33
# episode  50 score 19.30 average score 10.91 profit_iteration 0.01  iterations 1607.00  long_return 2.45
# episode  51 score 79.92 average score 12.24 profit_iteration 0.02  iterations 3759.00  long_return 3.52
# episode  52 score 25.31 average score 12.48 profit_iteration 0.08  iterations 328.00  long_return 1.16
# episode  53 score 15.07 average score 12.53 profit_iteration 0.04  iterations 347.00  long_return 1.16
# episode  54 score -24.31 average score 11.86 profit_iteration -0.02  iterations 1404.00  long_return 1.96
# episode  55 score -11.72 average score 11.44 profit_iteration -0.01  iterations 1262.00  long_return 1.75
# episode  56 score -50.09 average score 10.36 profit_iteration -0.02  iterations 2378.00  long_return 3.75
# episode  57 score -25.31 average score 9.74 profit_iteration -0.01  iterations 3437.00  long_return 3.00
# episode  58 score 24.99 average score 10.00 profit_iteration 0.01  iterations 2578.00  long_return 2.75
# episode  59 score 70.08 average score 11.00 profit_iteration 0.06  iterations 1096.00  long_return 1.54
# episode  60 score -63.78 average score 9.78 profit_iteration -0.04  iterations 1771.00  long_return 2.74
# episode  61 score 53.99 average score 10.49 profit_iteration 0.04  iterations 1348.00  long_return 1.86
# episode  62 score -63.87 average score 9.31 profit_iteration -0.02  iterations 3581.00  long_return 3.33
# episode  63 score -66.37 average score 8.13 profit_iteration -0.02  iterations 2753.00  long_return 2.34
# episode  64 score -69.78 average score 6.93 profit_iteration -0.02  iterations 3862.00  long_return 3.75
# episode  65 score 149.19 average score 9.09 profit_iteration 0.05  iterations 3109.00  long_return 2.83
# episode  66 score -52.86 average score 8.16 profit_iteration -0.01  iterations 4020.00  long_return 4.18
# episode  67 score -28.54 average score 7.62 profit_iteration -0.01  iterations 3215.00  long_return 2.77
# episode  68 score -6.78 average score 7.41 profit_iteration -0.00  iterations 3469.00  long_return 3.07
# episode  69 score 119.85 average score 9.02 profit_iteration 0.03  iterations 3916.00  long_return 4.26
# episode  70 score -58.19 average score 8.07 profit_iteration -0.02  iterations 2403.00  long_return 4.08
# episode  71 score -58.83 average score 7.14 profit_iteration -0.02  iterations 2621.00  long_return 2.46
# episode  72 score -56.62 average score 6.27 profit_iteration -0.02  iterations 2856.00  long_return 2.29
# episode  73 score 9.18 average score 6.31 profit_iteration 0.03  iterations 283.00  long_return 1.14
# episode  74 score -43.31 average score 5.65 profit_iteration -0.02  iterations 1818.00  long_return 2.54
# episode  75 score -46.22 average score 4.96 profit_iteration -0.02  iterations 1937.00  long_return 2.43
# episode  76 score 68.14 average score 5.79 profit_iteration 0.03  iterations 2288.00  long_return 3.10
# episode  77 score 85.38 average score 6.81 profit_iteration 0.03  iterations 2682.00  long_return 2.51
# episode  78 score -65.44 average score 5.89 profit_iteration -0.03  iterations 2355.00  long_return 3.63
# episode  79 score 0.16 average score 5.82 profit_iteration 0.00  iterations 685.00  long_return 1.52
# episode  80 score 54.36 average score 6.42 profit_iteration 0.08  iterations 705.00  long_return 1.44
# episode  81 score -67.06 average score 5.52 profit_iteration -0.03  iterations 2412.00  long_return 4.09
# episode  82 score -4.16 average score 5.41 profit_iteration -0.01  iterations 399.00  long_return 1.21
# episode  83 score -55.22 average score 4.68 profit_iteration -0.02  iterations 3271.00  long_return 2.99
# episode  84 score 10.12 average score 4.75 profit_iteration 0.05  iterations 179.00  long_return 1.04
# episode  85 score 36.49 average score 5.12 profit_iteration 0.07  iterations 528.00  long_return 1.34
# episode  86 score 39.57 average score 5.51 profit_iteration 0.07  iterations 583.00  long_return 1.39
# episode  87 score -19.62 average score 5.23 profit_iteration -0.04  iterations 517.00  long_return 1.32
# episode  88 score 2.10 average score 5.19 profit_iteration 0.05  iterations 52.00  long_return 0.97
# episode  89 score 1.63 average score 5.15 profit_iteration 0.00  iterations 2459.00  long_return 3.97
# episode  90 score 42.17 average score 5.56 profit_iteration 0.04  iterations 1091.00  long_return 1.54
# episode  91 score 20.97 average score 5.73 profit_iteration 0.01  iterations 2183.00  long_return 2.95
# episode  92 score -3.13 average score 5.63 profit_iteration -0.00  iterations 1298.00  long_return 1.87
# episode  93 score 102.09 average score 6.66 profit_iteration 0.04  iterations 2764.00  long_return 2.26
# episode  94 score 35.54 average score 6.96 profit_iteration 0.04  iterations 977.00  long_return 1.43
# episode  95 score 11.11 average score 7.01 profit_iteration 0.01  iterations 1706.00  long_return 2.44
# episode  96 score -8.58 average score 6.84 profit_iteration -0.00  iterations 2505.00  long_return 3.60
# episode  97 score 202.68 average score 8.84 profit_iteration 0.06  iterations 3476.00  long_return 3.00
# episode  98 score -22.99 average score 8.52 profit_iteration -0.01  iterations 4126.00  long_return 3.63
# episode  99 score 68.54 average score 9.12 profit_iteration 0.03  iterations 2126.00  long_return 2.81
# episode  100 score 0.48 average score 9.17 profit_iteration 0.00  iterations 2215.00  long_return 2.88
# episode  101 score -38.13 average score 8.96 profit_iteration -0.02  iterations 2220.00  long_return 2.91
# episode  102 score 92.80 average score 9.79 profit_iteration 0.03  iterations 3549.00  long_return 3.23
# episode  103 score -10.28 average score 9.44 profit_iteration -0.02  iterations 446.00  long_return 1.25
# episode  104 score -30.48 average score 8.06 profit_iteration -0.03  iterations 1129.00  long_return 1.60
# episode  105 score 15.20 average score 8.40 profit_iteration 0.02  iterations 616.00  long_return 1.40
# episode  106 score 66.13 average score 9.00 profit_iteration 0.02  iterations 3900.00  long_return 4.07
# episode  107 score 26.25 average score 9.25 profit_iteration 0.06  iterations 399.00  long_return 1.21
# episode  108 score -24.96 average score 9.69 profit_iteration -0.01  iterations 3841.00  long_return 3.76
# episode  109 score 19.52 average score 9.89 profit_iteration 0.00  iterations 3865.00  long_return 3.68
# episode  110 score 60.36 average score 9.98 profit_iteration 0.02  iterations 3383.00  long_return 3.09
# episode  111 score 20.03 average score 10.95 profit_iteration 0.05  iterations 394.00  long_return 1.20
# episode  112 score -3.74 average score 10.66 profit_iteration -0.38  iterations 11.00  long_return 0.96
# episode  113 score 370.42 average score 14.51 profit_iteration 0.14  iterations 2633.00  long_return 2.46
# episode  114 score 217.72 average score 16.77 profit_iteration 0.08  iterations 2790.00  long_return 2.28
# episode  115 score -28.88 average score 14.49 profit_iteration -0.01  iterations 2181.00  long_return 2.96
# episode  116 score -27.82 average score 14.33 profit_iteration -0.02  iterations 1310.00  long_return 1.80
# episode  117 score -23.87 average score 13.86 profit_iteration -0.02  iterations 1528.00  long_return 2.15
# episode  118 score -43.90 average score 12.70 profit_iteration -0.02  iterations 2055.00  long_return 3.08
# episode  119 score 7.09 average score 13.11 profit_iteration 0.01  iterations 1015.00  long_return 1.56
# episode  120 score -76.20 average score 12.25 profit_iteration -0.02  iterations 3483.00  long_return 3.01
# episode  121 score -56.36 average score 11.77 profit_iteration -0.02  iterations 2348.00  long_return 3.60
# episode  122 score 14.30 average score 12.31 profit_iteration 0.03  iterations 423.00  long_return 1.21
# episode  123 score 0.16 average score 11.66 profit_iteration 0.00  iterations 2131.00  long_return 2.89
# episode  124 score -16.10 average score 10.90 profit_iteration -0.00  iterations 3423.00  long_return 3.05
# episode  125 score 20.32 average score 11.57 profit_iteration 0.02  iterations 803.00  long_return 1.40
# episode  126 score 111.95 average score 12.60 profit_iteration 0.05  iterations 2091.00  long_return 3.18
# episode  127 score 54.11 average score 13.03 profit_iteration 0.05  iterations 1153.00  long_return 1.62
# episode  128 score -21.80 average score 12.16 profit_iteration -0.01  iterations 3035.00  long_return 2.64
# episode  129 score -26.17 average score 12.03 profit_iteration -0.02  iterations 1563.00  long_return 2.23
# episode  130 score 13.24 average score 12.84 profit_iteration 0.02  iterations 908.00  long_return 1.42
# episode  131 score -18.53 average score 10.95 profit_iteration -0.02  iterations 1182.00  long_return 1.66
# episode  132 score -19.52 average score 10.34 profit_iteration -0.03  iterations 552.00  long_return 1.31
# episode  133 score -35.04 average score 10.63 profit_iteration -0.03  iterations 1044.00  long_return 1.49
# episode  134 score 44.19 average score 10.90 profit_iteration 0.01  iterations 4148.00  long_return 3.50
# episode  135 score 35.80 average score 11.43 profit_iteration 0.01  iterations 3678.00  long_return 3.32
# episode  136 score -25.53 average score 11.44 profit_iteration -0.03  iterations 968.00  long_return 1.48
# episode  137 score 79.77 average score 12.27 profit_iteration 0.04  iterations 1854.00  long_return 2.51
# episode  138 score -15.20 average score 11.81 profit_iteration -0.03  iterations 438.00  long_return 1.24
# episode  139 score 45.20 average score 12.70 profit_iteration 0.01  iterations 3933.00  long_return 4.66
# episode  140 score -18.62 average score 12.57 profit_iteration -0.02  iterations 772.00  long_return 1.55
# episode  141 score -4.26 average score 11.83 profit_iteration -0.00  iterations 1945.00  long_return 2.50
# episode  142 score -40.70 average score 10.69 profit_iteration -0.01  iterations 3249.00  long_return 2.82
# episode  143 score -50.38 average score 10.29 profit_iteration -0.01  iterations 3692.00  long_return 3.23
# episode  144 score -57.39 average score 9.66 profit_iteration -0.02  iterations 2434.00  long_return 4.49
# episode  145 score 31.54 average score 10.00 profit_iteration 0.03  iterations 1052.00  long_return 1.51
# episode  146 score 115.87 average score 11.63 profit_iteration 0.04  iterations 2817.00  long_return 2.46
# episode  147 score 26.63 average score 11.74 profit_iteration 0.02  iterations 1173.00  long_return 1.63
# episode  148 score -1.67 average score 11.03 profit_iteration -0.00  iterations 1825.00  long_return 2.37
# episode  149 score -11.95 average score 11.37 profit_iteration -0.01  iterations 1151.00  long_return 1.62
# episode  150 score -69.85 average score 10.48 profit_iteration -0.02  iterations 3432.00  long_return 2.95
# episode  151 score -43.77 average score 9.24 profit_iteration -0.02  iterations 2325.00  long_return 3.39
# episode  152 score 5.46 average score 9.04 profit_iteration 0.01  iterations 532.00  long_return 1.33
# episode  153 score 21.66 average score 9.11 profit_iteration 0.03  iterations 641.00  long_return 1.42
# episode  154 score 70.85 average score 10.06 profit_iteration 0.09  iterations 784.00  long_return 1.49
# episode  155 score -1.55 average score 10.16 profit_iteration -0.04  iterations 51.00  long_return 0.97
# episode  156 score -50.57 average score 10.15 profit_iteration -0.01  iterations 4141.00  long_return 3.53
# episode  157 score 38.14 average score 10.79 profit_iteration 0.02  iterations 1729.00  long_return 2.50
# episode  158 score 25.58 average score 10.80 profit_iteration 0.01  iterations 3477.00  long_return 2.99
# episode  159 score 66.60 average score 10.76 profit_iteration 0.02  iterations 3646.00  long_return 3.29
# episode  160 score 99.79 average score 12.40 profit_iteration 0.04  iterations 2370.00  long_return 3.65
# episode  161 score 24.53 average score 12.10 profit_iteration 0.02  iterations 1126.00  long_return 1.60
# episode  162 score 44.26 average score 13.18 profit_iteration 0.02  iterations 2842.00  long_return 2.28
# episode  163 score 958.95 average score 23.44 profit_iteration 0.23  iterations 4065.00  long_return 4.11
# episode  164 score 88.52 average score 25.02 profit_iteration 0.05  iterations 1764.00  long_return 2.58
# episode  165 score -6.08 average score 23.47 profit_iteration -0.00  iterations 2887.00  long_return 2.31
# episode  166 score -2.69 average score 23.97 profit_iteration -0.00  iterations 3646.00  long_return 3.29
# episode  167 score 11.89 average score 24.37 profit_iteration 0.00  iterations 3545.00  long_return 3.29
# episode  168 score 53.98 average score 24.98 profit_iteration 0.02  iterations 2947.00  long_return 2.41
# episode  169 score 157.61 average score 25.36 profit_iteration 0.05  iterations 3201.00  long_return 2.82
# episode  170 score 134.94 average score 27.29 profit_iteration 0.03  iterations 3903.00  long_return 4.06
# episode  171 score -14.12 average score 27.74 profit_iteration -0.02  iterations 898.00  long_return 1.43
# episode  172 score 24.94 average score 28.55 profit_iteration 0.04  iterations 593.00  long_return 1.39
# episode  173 score 8.61 average score 28.55 profit_iteration 0.00  iterations 3897.00  long_return 4.07
# episode  174 score 24.93 average score 29.23 profit_iteration 0.01  iterations 2203.00  long_return 3.00
# episode  175 score -53.11 average score 29.16 profit_iteration -0.03  iterations 1603.00  long_return 2.36
# episode  176 score -23.39 average score 28.24 profit_iteration -0.02  iterations 1020.00  long_return 1.52
# episode  177 score -33.36 average score 27.06 profit_iteration -0.03  iterations 1050.00  long_return 1.50
# episode  178 score -13.22 average score 27.58 profit_iteration -0.07  iterations 179.00  long_return 1.04
# episode  179 score -8.15 average score 27.50 profit_iteration -0.04  iterations 236.00  long_return 1.08
# episode  180 score 49.22 average score 27.44 profit_iteration 0.04  iterations 1239.00  long_return 1.70
# episode  181 score -74.12 average score 27.37 profit_iteration -0.03  iterations 2472.00  long_return 3.85
# episode  182 score 4.16 average score 27.46 profit_iteration 0.07  iterations 70.00  long_return 0.99
# episode  183 score -49.97 average score 27.51 profit_iteration -0.02  iterations 2012.00  long_return 2.72
# episode  184 score -2.12 average score 27.39 profit_iteration -0.00  iterations 402.00  long_return 1.19
# episode  185 score -42.07 average score 26.60 profit_iteration -0.01  iterations 3400.00  long_return 3.11
# episode  186 score -11.27 average score 26.09 profit_iteration -0.04  iterations 310.00  long_return 1.14
# episode  187 score -24.99 average score 26.04 profit_iteration -0.02  iterations 1242.00  long_return 1.69
# episode  188 score -37.78 average score 25.64 profit_iteration -0.01  iterations 3137.00  long_return 2.68
# episode  189 score 27.16 average score 25.90 profit_iteration 0.01  iterations 2907.00  long_return 2.41
# episode  190 score -68.82 average score 24.79 profit_iteration -0.02  iterations 2918.00  long_return 2.43
# episode  191 score 19.50 average score 24.77 profit_iteration 0.03  iterations 733.00  long_return 1.40
# episode  192 score 54.89 average score 25.35 profit_iteration 0.01  iterations 3994.00  long_return 4.16
# episode  193 score -0.43 average score 24.33 profit_iteration 0.00  iterations 72.00  long_return 1.00
# episode  194 score 5.66 average score 24.03 profit_iteration 0.03  iterations 213.00  long_return 1.05
# episode  195 score 291.65 average score 26.83 profit_iteration 0.11  iterations 2559.00  long_return 2.62
# episode  196 score -47.03 average score 26.45 profit_iteration -0.02  iterations 2847.00  long_return 2.28
# episode  197 score 27.49 average score 24.70 profit_iteration 0.04  iterations 636.00  long_return 1.39
# episode  198 score -36.39 average score 24.56 profit_iteration -0.01  iterations 2471.00  long_return 3.86
# episode  199 score 68.42 average score 24.56 profit_iteration 0.03  iterations 2142.00  long_return 2.71
# episode  200 score 20.59 average score 24.76 profit_iteration 0.01  iterations 3296.00  long_return 2.91
# episode  201 score -37.56 average score 24.77 profit_iteration -0.01  iterations 3203.00  long_return 2.77
# episode  202 score 42.06 average score 24.26 profit_iteration 0.01  iterations 4133.00  long_return 3.45
# episode  203 score -40.00 average score 23.96 profit_iteration -0.02  iterations 2430.00  long_return 4.54
# episode  204 score 32.43 average score 24.59 profit_iteration 0.01  iterations 2663.00  long_return 2.57
# episode  205 score -15.20 average score 24.29 profit_iteration -0.00  iterations 3202.00  long_return 2.81
# episode  206 score -38.02 average score 23.25 profit_iteration -0.02  iterations 2392.00  long_return 3.90
# episode  207 score -59.39 average score 22.39 profit_iteration -0.02  iterations 3791.00  long_return 3.64
# episode  208 score 1.52 average score 22.66 profit_iteration 0.01  iterations 81.00  long_return 1.03
# episode  209 score -8.89 average score 22.37 profit_iteration -0.03  iterations 251.00  long_return 1.09
# episode  210 score -1.73 average score 21.75 profit_iteration -0.00  iterations 264.00  long_return 1.11
# episode  211 score 98.36 average score 22.53 profit_iteration 0.07  iterations 1479.00  long_return 2.18
# episode  212 score -16.76 average score 22.40 profit_iteration -0.04  iterations 418.00  long_return 1.20
# episode  213 score -3.83 average score 18.66 profit_iteration -0.00  iterations 1545.00  long_return 2.22
# episode  214 score -24.99 average score 16.23 profit_iteration -0.02  iterations 1260.00  long_return 1.74
# episode  215 score 264.71 average score 19.17 profit_iteration 0.10  iterations 2714.00  long_return 2.45
# episode  216 score 285.52 average score 22.30 profit_iteration 0.09  iterations 3028.00  long_return 2.60
# episode  217 score 181.29 average score 24.36 profit_iteration 0.05  iterations 3523.00  long_return 3.33
# episode  218 score 401.70 average score 28.81 profit_iteration 0.10  iterations 3807.00  long_return 3.62
# episode  219 score 18.01 average score 28.92 profit_iteration 0.13  iterations 137.00  long_return 1.06
# episode  220 score -51.74 average score 29.16 profit_iteration -0.02  iterations 2217.00  long_return 2.94
# episode  221 score 54.10 average score 30.27 profit_iteration 0.01  iterations 3635.00  long_return 3.35
# episode  222 score -11.23 average score 30.01 profit_iteration -0.03  iterations 348.00  long_return 1.16
# episode  223 score -18.13 average score 29.83 profit_iteration -0.05  iterations 365.00  long_return 1.18
# episode  224 score -26.77 average score 29.72 profit_iteration -0.01  iterations 2230.00  long_return 2.97
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-98e46ea8e7de> in <module>
#       7     agent.noise.reset()
#       8     while not done:
# ----> 9         action = agent.choose_action(observation)
#      10         action = action.argmax()
#      11         observation_, reward, done, info = env.step(action)
#
# ~\Documents\GitHub\projects\practices\reinforcement learning\DDPG-stock\ddpg_torch.py in choose_action(self, observation)
#      37         self.actor.eval() # eval mode
#      38         state = T.tensor([observation], dtype=T.float).to(self.actor.device)
# ---> 39         mu = self.actor.forward(state).to(self.actor.device)
#      40         mu_prime = mu + T.tensor(self.noise(),
#      41                                     dtype=T.float).to(self.actor.device)
#
# ~\Documents\GitHub\projects\practices\reinforcement learning\DDPG-stock\networks.py in forward(self, state)
#     126
#     127     def forward(self, state):
# --> 128         x = self.fc1(state)
#     129         x = self.bn1(x)
#     130         x = F.relu(x)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      89
#      90     def forward(self, input: Tensor) -> Tensor:
# ---> 91         return F.linear(input, self.weight, self.bias)
#      92
#      93     def extra_repr(self) -> str:
#
# ~\Anaconda3\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1672     if input.dim() == 2 and bias is not None:
#    1673         # fused op is marginally faster
# -> 1674         ret = torch.addmm(bias, input, weight.t())
#    1675     else:
#    1676         output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %%
# agent.noise.x_prev

# %%
env.observation_space.shape
