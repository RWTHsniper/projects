# %%
import gym
import numpy as np
from ddqn_agent import DDQNAgent
from utils import plot_learning_curve

from env6 import TradingSPYEnv
import numpy as np
import os

# %%
#env = TradingSPYEnv(init_invest=100.0, sma_len=[5,10,15,20,25],train_test_split=0.5)
env = TradingSPYEnv(init_invest=100.0, sma_len=[5,25,50],train_test_split=0.5,train_data_path='BTCUSD=X.csv')
first_test_step = env.current_step

num_states = env.reset(first_test_step).shape[0]
print("Size of State Space ->  {}".format(num_states))
num_actions = env.action_space.n
print("Size of Action Space ->  {}".format(num_actions))


agent = DDQNAgent(gamma=0.99, epsilon=1.0, lr=0.0005,
                 input_dims=[num_states],
                 n_actions=num_actions, mem_size=100000, eps_min=0.1,
                 batch_size=256, replace=5000, eps_dec=1e-5,
                 chkpt_dir='btc/', algo='DDQNAgent',
                 env_name='btc',
                 fc1_dims=64, fc2_dims=64, p=0.2)


#agent = Agent(gamma=0.99, epsilon=0.5, batch_size=8192, n_actions=num_actions, eps_dec=1e-5, eps_end=0.1, 
#              input_dims = [num_states], lr=0.00005, p=0.5,
#              weight_decay=1e-5)
# Out:
# C:\Users\golde\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# Size of State Space ->  200
# Size of Action Space ->  3

# %%
#agent.Q_eval.load_state_dict(T.load(state_dict_path))
#agent.Q_eval.load_state_dict(T.load(best_state_dict_path))
scores, eps_history = [], []
n_games = 1000
max_score = 0.0
#learn_frequency = 4
#learn_count = 0


for i in range(n_games):
    score = 0.0
    done = False
    observation = env.reset(first_test_step)
    while not done:
        action = agent.choose_action(observation)
        observation_, reward, done, info = env.step(action)
        if (observation_ is not None): 
            score += reward
            agent.store_transition(observation, action, reward, observation_, done)
        agent.learn()
#        if learn_count == learn_frequency:
#            agent.learn()
#            learn_count = 0
#        else:
#            learn_count += 1
        observation = observation_
#    agent.learn() # Learn after one episode
    scores.append(score)
    eps_history.append(agent.epsilon)
    
    avg_score = np.mean(scores[-100:])
    
    print('episode ', i, 'score %.2f' % score,
         'average score %.2f' % avg_score,
         'epsilon %.2f ' % agent.epsilon,
         'profit_iteration %.2f ' % info['profit_iteration'],
         'iterations %.2f ' % info['iterations'],
         'long_return %.2f ' % info['long_return']
         )
    
    if (i !=0) and(i % 10 == 0):
        agent.save_models()
        print("saved check point")
# Out:
# episode  0 score -0.10 average score -0.10 epsilon 1.00  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  1 score -0.54 average score -0.32 epsilon 1.00  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  2 score -0.33 average score -0.33 epsilon 1.00  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  3 score -0.53 average score -0.38 epsilon 1.00  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  4 score -0.57 average score -0.41 epsilon 1.00  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  5 score 0.68 average score -0.23 epsilon 1.00  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  6 score 0.29 average score -0.16 epsilon 1.00  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  7 score -0.04 average score -0.14 epsilon 1.00  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  8 score 0.15 average score -0.11 epsilon 1.00  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  9 score -1.07 average score -0.21 epsilon 1.00  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  10 score 0.16 average score -0.17 epsilon 1.00  profit_iteration 0.00  iterations 137.00  long_return 2.02
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  11 score -1.29 average score -0.27 epsilon 0.99  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  12 score -0.03 average score -0.25 epsilon 0.99  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  13 score -0.45 average score -0.26 epsilon 0.99  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  14 score -0.31 average score -0.27 epsilon 0.99  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  15 score -0.23 average score -0.26 epsilon 0.99  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  16 score -0.32 average score -0.27 epsilon 0.99  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  17 score -0.30 average score -0.27 epsilon 0.99  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  18 score -0.11 average score -0.26 epsilon 0.98  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  19 score 0.22 average score -0.24 epsilon 0.98  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  20 score -0.50 average score -0.25 epsilon 0.98  profit_iteration 0.00  iterations 137.00  long_return 2.02
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  21 score -0.19 average score -0.25 epsilon 0.98  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  22 score -0.57 average score -0.26 epsilon 0.98  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  23 score -0.01 average score -0.25 epsilon 0.98  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  24 score -0.86 average score -0.27 epsilon 0.98  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  25 score -0.55 average score -0.28 epsilon 0.97  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  26 score 0.10 average score -0.27 epsilon 0.97  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  27 score -1.05 average score -0.30 epsilon 0.97  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  28 score 0.22 average score -0.28 epsilon 0.97  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  29 score -0.49 average score -0.29 epsilon 0.97  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  30 score -0.49 average score -0.29 epsilon 0.97  profit_iteration 0.00  iterations 137.00  long_return 2.02
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  31 score 0.58 average score -0.27 epsilon 0.97  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  32 score -0.24 average score -0.27 epsilon 0.96  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  33 score 0.34 average score -0.25 epsilon 0.96  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  34 score -0.84 average score -0.26 epsilon 0.96  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  35 score 0.70 average score -0.24 epsilon 0.96  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  36 score -0.12 average score -0.23 epsilon 0.96  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  37 score 0.53 average score -0.21 epsilon 0.96  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  38 score -0.74 average score -0.23 epsilon 0.96  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  39 score -0.03 average score -0.22 epsilon 0.96  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  40 score -0.12 average score -0.22 epsilon 0.95  profit_iteration 0.00  iterations 137.00  long_return 2.02
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  41 score -0.35 average score -0.22 epsilon 0.95  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  42 score -0.32 average score -0.23 epsilon 0.95  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  43 score -0.91 average score -0.24 epsilon 0.95  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  44 score -0.92 average score -0.26 epsilon 0.95  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  45 score -0.70 average score -0.27 epsilon 0.95  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  46 score 0.44 average score -0.25 epsilon 0.95  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  47 score 0.02 average score -0.25 epsilon 0.94  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  48 score -0.40 average score -0.25 epsilon 0.94  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  49 score 0.82 average score -0.23 epsilon 0.94  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  50 score -0.78 average score -0.24 epsilon 0.94  profit_iteration 0.00  iterations 137.00  long_return 2.02
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  51 score -0.40 average score -0.24 epsilon 0.94  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  52 score -0.25 average score -0.24 epsilon 0.94  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  53 score 0.16 average score -0.23 epsilon 0.94  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  54 score -0.49 average score -0.24 epsilon 0.93  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  55 score -0.03 average score -0.24 epsilon 0.93  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  56 score -0.66 average score -0.24 epsilon 0.93  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  57 score 0.61 average score -0.23 epsilon 0.93  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  58 score 0.22 average score -0.22 epsilon 0.93  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  59 score -0.14 average score -0.22 epsilon 0.93  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  60 score 0.11 average score -0.21 epsilon 0.93  profit_iteration 0.00  iterations 137.00  long_return 2.02
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  61 score -0.04 average score -0.21 epsilon 0.92  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  62 score 0.17 average score -0.20 epsilon 0.92  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  63 score 0.12 average score -0.20 epsilon 0.92  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  64 score -0.46 average score -0.20 epsilon 0.92  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  65 score 0.16 average score -0.20 epsilon 0.92  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  66 score -0.14 average score -0.20 epsilon 0.92  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  67 score -0.09 average score -0.20 epsilon 0.92  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  68 score 0.32 average score -0.19 epsilon 0.92  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  69 score 0.33 average score -0.18 epsilon 0.91  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  70 score -0.76 average score -0.19 epsilon 0.91  profit_iteration 0.00  iterations 137.00  long_return 2.02
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  71 score 0.24 average score -0.18 epsilon 0.91  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  72 score -0.62 average score -0.19 epsilon 0.91  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  73 score -0.67 average score -0.20 epsilon 0.91  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  74 score -0.99 average score -0.21 epsilon 0.91  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  75 score -1.25 average score -0.22 epsilon 0.91  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  76 score -0.12 average score -0.22 epsilon 0.90  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  77 score 0.34 average score -0.21 epsilon 0.90  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  78 score -0.56 average score -0.22 epsilon 0.90  profit_iteration 0.00  iterations 137.00  long_return 2.02
# episode  79 score 0.09 average score -0.21 epsilon 0.90  profit_iteration 0.00  iterations 137.00  long_return 2.02
