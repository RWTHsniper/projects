# %%
import gym
import numpy as np
from ddqn_agent import DDQNAgent
from utils import plot_learning_curve

from env6 import TradingSPYEnv
import numpy as np
import os

# %%
#env = TradingSPYEnv(init_invest=100.0, sma_len=[5,10,15,20,25],train_test_split=0.5)
env = TradingSPYEnv(init_invest=100.0, sma_len=[5,25,50],train_test_split=0.5)
first_test_step = env.current_step

num_states = env.reset(first_test_step).shape[0]
print("Size of State Space ->  {}".format(num_states))
num_actions = env.action_space.n
print("Size of Action Space ->  {}".format(num_actions))


agent = DDQNAgent(gamma=0.99, epsilon=1.0, lr=0.0005,
                 input_dims=[num_states],
                 n_actions=num_actions, mem_size=100000, eps_min=0.1,
                 batch_size=1024, replace=5000, eps_dec=1e-5,
                 chkpt_dir='models3/', algo='DDQNAgent',
                 env_name='stock',
                 fc1_dims=64, fc2_dims=64, p=0.2)


#agent = Agent(gamma=0.99, epsilon=0.5, batch_size=8192, n_actions=num_actions, eps_dec=1e-5, eps_end=0.1, 
#              input_dims = [num_states], lr=0.00005, p=0.5,
#              weight_decay=1e-5)
# Out:
# Size of State Space ->  300
# Size of Action Space ->  3
# /Users/jungjaeyong/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
#agent.Q_eval.load_state_dict(T.load(state_dict_path))
#agent.Q_eval.load_state_dict(T.load(best_state_dict_path))
scores, eps_history = [], []
n_games = 1000
max_score = 0.0
#learn_frequency = 4
#learn_count = 0


for i in range(n_games):
    score = 0.0
    done = False
    observation = env.reset(first_test_step)
    while not done:
        action = agent.choose_action(observation)
        observation_, reward, done, info = env.step(action)
        if (observation_ is not None): 
            score += reward
            agent.store_transition(observation, action, reward, observation_, done)
        agent.learn()
#        if learn_count == learn_frequency:
#            agent.learn()
#            learn_count = 0
#        else:
#            learn_count += 1
        observation = observation_
#    agent.learn() # Learn after one episode
    scores.append(score)
    eps_history.append(agent.epsilon)
    
    avg_score = np.mean(scores[-100:])
    
    print('episode ', i, 'score %.2f' % score,
         'average score %.2f' % avg_score,
         'epsilon %.2f ' % agent.epsilon,
         'profit_iteration %.2f ' % info['profit_iteration'],
         'iterations %.2f ' % info['iterations'],
         'long_return %.2f ' % info['long_return']
         )
    
    if (i !=0) and(i % 10 == 0):
        agent.save_models()
        print("saved check point")
# Out:
# episode  0 score -83.69 average score -83.69 epsilon 1.00  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  1 score -89.46 average score -86.58 epsilon 1.00  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  2 score -93.96 average score -89.04 epsilon 1.00  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  3 score -92.33 average score -89.86 epsilon 0.99  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  4 score -88.53 average score -89.59 epsilon 0.97  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  5 score -57.68 average score -84.27 epsilon 0.95  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  6 score -79.97 average score -83.66 epsilon 0.93  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  7 score -82.11 average score -83.47 epsilon 0.90  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  8 score -90.57 average score -84.26 epsilon 0.88  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  9 score -85.33 average score -84.36 epsilon 0.86  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  10 score -74.49 average score -83.47 epsilon 0.84  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  11 score -84.42 average score -83.54 epsilon 0.81  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  12 score -85.87 average score -83.72 epsilon 0.79  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  13 score -87.68 average score -84.01 epsilon 0.77  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  14 score -74.20 average score -83.35 epsilon 0.75  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  15 score -62.97 average score -82.08 epsilon 0.72  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  16 score -85.28 average score -82.27 epsilon 0.70  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  17 score -76.92 average score -81.97 epsilon 0.68  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  18 score -66.53 average score -81.16 epsilon 0.66  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  19 score -47.49 average score -79.47 epsilon 0.63  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  20 score -29.28 average score -77.08 epsilon 0.61  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  21 score -26.62 average score -74.79 epsilon 0.59  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  22 score -65.15 average score -74.37 epsilon 0.57  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  23 score -8.91 average score -71.64 epsilon 0.54  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  24 score -64.76 average score -71.37 epsilon 0.52  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  25 score -28.05 average score -69.70 epsilon 0.50  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  26 score -74.50 average score -69.88 epsilon 0.48  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  27 score -43.51 average score -68.94 epsilon 0.46  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  28 score 23.98 average score -65.73 epsilon 0.43  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  29 score 42.16 average score -62.14 epsilon 0.41  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  30 score 5.55 average score -59.95 epsilon 0.39  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  31 score 37.80 average score -56.90 epsilon 0.37  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  32 score 28.01 average score -54.33 epsilon 0.34  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  33 score 131.14 average score -48.87 epsilon 0.32  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  34 score 254.04 average score -40.22 epsilon 0.30  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  35 score 122.39 average score -35.70 epsilon 0.28  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  36 score 302.04 average score -26.57 epsilon 0.25  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  37 score 56.26 average score -24.39 epsilon 0.23  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  38 score 43.04 average score -22.66 epsilon 0.21  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  39 score 305.37 average score -14.46 epsilon 0.19  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  40 score 335.04 average score -5.94 epsilon 0.16  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  41 score 220.04 average score -0.56 epsilon 0.14  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  42 score 379.29 average score 8.28 epsilon 0.12  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  43 score 311.98 average score 15.18 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  44 score 587.22 average score 27.89 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  45 score 614.97 average score 40.65 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  46 score 785.25 average score 56.50 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  47 score 414.98 average score 63.96 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  48 score 633.05 average score 75.58 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  49 score 654.66 average score 87.16 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  50 score 1032.63 average score 105.70 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  51 score 759.19 average score 118.27 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  52 score 550.94 average score 126.43 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  53 score 461.75 average score 132.64 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  54 score 858.77 average score 145.84 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  55 score 748.59 average score 156.60 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  56 score 749.35 average score 167.00 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  57 score 585.39 average score 174.22 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  58 score 1350.68 average score 194.16 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  59 score 919.60 average score 206.25 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  60 score 1667.43 average score 230.20 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  61 score 860.86 average score 240.37 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  62 score 458.16 average score 243.83 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  63 score 896.37 average score 254.03 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  64 score 830.92 average score 262.90 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  65 score 1545.12 average score 282.33 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  66 score 828.30 average score 290.48 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  67 score 1348.02 average score 306.03 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  68 score 588.03 average score 310.12 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  69 score 604.66 average score 314.32 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  70 score 688.50 average score 319.59 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  71 score 479.17 average score 321.81 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  72 score 750.98 average score 327.69 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  73 score 614.13 average score 331.56 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  74 score 805.25 average score 337.88 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  75 score 513.34 average score 340.19 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  76 score 334.18 average score 340.11 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  77 score 726.69 average score 345.06 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  78 score 554.51 average score 347.72 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
# episode  79 score 466.61 average score 349.20 epsilon 0.10  profit_iteration 0.00  iterations 2238.00  long_return 1.42
