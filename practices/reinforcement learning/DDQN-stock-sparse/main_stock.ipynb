# %%
import gym
import numpy as np
from ddqn_agent import DDQNAgent
from utils import plot_learning_curve

from env6 import TradingSPYEnv
#from env6_noshort import TradingSPYEnv
import numpy as np
import os

# %%
#env = TradingSPYEnv(init_invest=100.0, sma_len=[5,10,15,20,25],train_test_split=0.6)
env = TradingSPYEnv(init_invest=100.0, sma_len=[5,25,50],train_test_split=0.6)
first_test_step = env.current_step

num_states = env.reset(first_test_step).shape[0]
print("Size of State Space ->  {}".format(num_states))
num_actions = env.action_space.n
print("Size of Action Space ->  {}".format(num_actions))


agent = DDQNAgent(gamma=0.99, epsilon=1.0, lr=0.0001,
                 input_dims=[num_states],
                 n_actions=num_actions, mem_size=100000, eps_min=0.1,
                 batch_size=1024, replace=10000, eps_dec=5e-6,
                 chkpt_dir='models/', algo='DDQNAgent',
                 env_name='stock',
                 fc1_dims=128, fc2_dims=128, p = 0.2, weight_decay=1e-5)


#agent = Agent(gamma=0.99, epsilon=0.5, batch_size=8192, n_actions=num_actions, eps_dec=1e-5, eps_end=0.1, 
#              input_dims = [num_states], lr=0.00005, p=0.5,
#              weight_decay=1e-5)
# Out:
# C:\Users\golde\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# Size of State Space ->  51
# Size of Action Space ->  3

# %%
scores, eps_history = [], []
n_games = 1000
max_score = 0.0
#learn_frequency = 4
#learn_count = 0


for i in range(n_games):
    score = 0.0
    done = False
    observation = env.reset(first_test_step)
    while not done:
        action = agent.choose_action(observation)
        observation_, reward, done, info = env.step(action)
        if (observation_ is not None): 
            score += reward
            agent.store_transition(observation, action, reward, observation_, done)
        agent.learn()
#        if learn_count == learn_frequency:
#            agent.learn()
#            learn_count = 0
#        else:
#            learn_count += 1
        observation = observation_
#    agent.learn() # Learn after one episode
    scores.append(score)
    eps_history.append(agent.epsilon)
    
    avg_score = np.mean(scores[-100:])
    
    print('episode ', i, 'score %.2f' % score,
         'average score %.2f' % avg_score,
         'epsilon %.2f ' % agent.epsilon,
         'profit_iteration %.2f ' % info['profit_iteration'],
         'iterations %.2f ' % info['iterations'],
         'long_return %.2f ' % info['long_return']
         )
    
    if (i !=0) and(i % 10 == 0):
        agent.save_models()
        print("saved check point")
# Out:
# episode  0 score -0.71 average score -0.71 epsilon 1.00  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  1 score -0.84 average score -0.77 epsilon 1.00  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  2 score -0.70 average score -0.75 epsilon 0.99  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  3 score -0.66 average score -0.73 epsilon 0.99  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  4 score -0.79 average score -0.74 epsilon 0.98  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  5 score -0.92 average score -0.77 epsilon 0.98  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  6 score -0.68 average score -0.76 epsilon 0.97  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  7 score -0.77 average score -0.76 epsilon 0.97  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  8 score -0.84 average score -0.77 epsilon 0.96  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  9 score -0.89 average score -0.78 epsilon 0.96  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  10 score -1.15 average score -0.81 epsilon 0.95  profit_iteration 0.00  iterations 927.00  long_return 1.55
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  11 score -0.66 average score -0.80 epsilon 0.95  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  12 score -0.96 average score -0.81 epsilon 0.94  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  13 score -0.97 average score -0.82 epsilon 0.94  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  14 score -0.80 average score -0.82 epsilon 0.94  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  15 score -0.65 average score -0.81 epsilon 0.93  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  16 score -0.86 average score -0.81 epsilon 0.93  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  17 score -0.84 average score -0.82 epsilon 0.92  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  18 score -0.74 average score -0.81 epsilon 0.92  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  19 score -0.86 average score -0.81 epsilon 0.91  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  20 score -0.54 average score -0.80 epsilon 0.91  profit_iteration 0.00  iterations 927.00  long_return 1.55
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  21 score -1.10 average score -0.81 epsilon 0.90  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  22 score -0.78 average score -0.81 epsilon 0.90  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  23 score -0.96 average score -0.82 epsilon 0.89  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  24 score -0.65 average score -0.81 epsilon 0.89  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  25 score -0.80 average score -0.81 epsilon 0.88  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  26 score -1.02 average score -0.82 epsilon 0.88  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  27 score -1.09 average score -0.83 epsilon 0.88  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  28 score -0.67 average score -0.82 epsilon 0.87  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  29 score -0.94 average score -0.83 epsilon 0.87  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  30 score -1.27 average score -0.84 epsilon 0.86  profit_iteration 0.00  iterations 927.00  long_return 1.55
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  31 score -0.77 average score -0.84 epsilon 0.86  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  32 score -0.94 average score -0.84 epsilon 0.85  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  33 score -0.35 average score -0.83 epsilon 0.85  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  34 score -0.64 average score -0.82 epsilon 0.84  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  35 score -0.76 average score -0.82 epsilon 0.84  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  36 score -0.82 average score -0.82 epsilon 0.83  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  37 score -0.87 average score -0.82 epsilon 0.83  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  38 score -0.64 average score -0.82 epsilon 0.82  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  39 score -1.01 average score -0.82 epsilon 0.82  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  40 score -0.67 average score -0.82 epsilon 0.81  profit_iteration 0.00  iterations 927.00  long_return 1.55
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  41 score -0.37 average score -0.81 epsilon 0.81  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  42 score -1.31 average score -0.82 epsilon 0.81  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  43 score -0.98 average score -0.82 epsilon 0.80  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  44 score -0.63 average score -0.82 epsilon 0.80  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  45 score -0.75 average score -0.82 epsilon 0.79  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  46 score -0.74 average score -0.82 epsilon 0.79  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  47 score -0.67 average score -0.81 epsilon 0.78  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  48 score -0.78 average score -0.81 epsilon 0.78  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  49 score -0.76 average score -0.81 epsilon 0.77  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  50 score -0.95 average score -0.81 epsilon 0.77  profit_iteration 0.00  iterations 927.00  long_return 1.55
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  51 score -0.68 average score -0.81 epsilon 0.76  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  52 score -0.82 average score -0.81 epsilon 0.76  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  53 score -0.94 average score -0.81 epsilon 0.75  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  54 score -1.09 average score -0.82 epsilon 0.75  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  55 score -0.79 average score -0.82 epsilon 0.75  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  56 score -0.69 average score -0.82 epsilon 0.74  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  57 score -0.39 average score -0.81 epsilon 0.74  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  58 score -0.36 average score -0.80 epsilon 0.73  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  59 score -0.86 average score -0.80 epsilon 0.73  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  60 score -0.94 average score -0.80 epsilon 0.72  profit_iteration 0.00  iterations 927.00  long_return 1.55
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  61 score -0.73 average score -0.80 epsilon 0.72  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  62 score -0.51 average score -0.80 epsilon 0.71  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  63 score -0.54 average score -0.79 epsilon 0.71  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  64 score -0.56 average score -0.79 epsilon 0.70  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  65 score -0.75 average score -0.79 epsilon 0.70  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  66 score -0.66 average score -0.79 epsilon 0.69  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  67 score -0.21 average score -0.78 epsilon 0.69  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  68 score -0.65 average score -0.78 epsilon 0.68  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  69 score -0.53 average score -0.77 epsilon 0.68  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  70 score -0.68 average score -0.77 epsilon 0.68  profit_iteration 0.00  iterations 927.00  long_return 1.55
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  71 score -0.72 average score -0.77 epsilon 0.67  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  72 score -0.87 average score -0.77 epsilon 0.67  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  73 score -1.02 average score -0.78 epsilon 0.66  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  74 score -0.70 average score -0.78 epsilon 0.66  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  75 score -0.48 average score -0.77 epsilon 0.65  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  76 score -0.49 average score -0.77 epsilon 0.65  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  77 score -0.44 average score -0.76 epsilon 0.64  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  78 score -0.68 average score -0.76 epsilon 0.64  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  79 score -0.51 average score -0.76 epsilon 0.63  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  80 score -0.57 average score -0.76 epsilon 0.63  profit_iteration 0.00  iterations 927.00  long_return 1.55
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  81 score -0.65 average score -0.76 epsilon 0.62  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  82 score -0.31 average score -0.75 epsilon 0.62  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  83 score -0.92 average score -0.75 epsilon 0.62  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  84 score -0.54 average score -0.75 epsilon 0.61  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  85 score -0.52 average score -0.75 epsilon 0.61  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  86 score -1.11 average score -0.75 epsilon 0.60  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  87 score -0.73 average score -0.75 epsilon 0.60  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  88 score -0.23 average score -0.75 epsilon 0.59  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  89 score -0.65 average score -0.74 epsilon 0.59  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  90 score -0.61 average score -0.74 epsilon 0.58  profit_iteration 0.00  iterations 927.00  long_return 1.55
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  91 score -0.79 average score -0.74 epsilon 0.58  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  92 score -0.84 average score -0.75 epsilon 0.57  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  93 score -0.54 average score -0.74 epsilon 0.57  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  94 score -0.36 average score -0.74 epsilon 0.56  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  95 score -0.16 average score -0.73 epsilon 0.56  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  96 score -0.35 average score -0.73 epsilon 0.56  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  97 score -0.88 average score -0.73 epsilon 0.55  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  98 score -0.62 average score -0.73 epsilon 0.55  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  99 score -0.74 average score -0.73 epsilon 0.54  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  100 score -0.54 average score -0.73 epsilon 0.54  profit_iteration 0.00  iterations 927.00  long_return 1.55
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  101 score -0.65 average score -0.73 epsilon 0.53  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  102 score -0.73 average score -0.73 epsilon 0.53  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  103 score -0.70 average score -0.73 epsilon 0.52  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  104 score -0.55 average score -0.72 epsilon 0.52  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  105 score -0.57 average score -0.72 epsilon 0.51  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  106 score -0.43 average score -0.72 epsilon 0.51  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  107 score -0.29 average score -0.71 epsilon 0.50  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  108 score -0.68 average score -0.71 epsilon 0.50  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  109 score -0.19 average score -0.70 epsilon 0.49  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  110 score -0.54 average score -0.70 epsilon 0.49  profit_iteration 0.00  iterations 927.00  long_return 1.55
# ... saving checkpoint ...
# ... saving checkpoint ...
# saved check point
# episode  111 score -0.42 average score -0.70 epsilon 0.49  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  112 score -0.21 average score -0.69 epsilon 0.48  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  113 score -0.83 average score -0.69 epsilon 0.48  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  114 score -0.49 average score -0.68 epsilon 0.47  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  115 score -0.38 average score -0.68 epsilon 0.47  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  116 score -0.29 average score -0.68 epsilon 0.46  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  117 score -0.49 average score -0.67 epsilon 0.46  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  118 score -0.55 average score -0.67 epsilon 0.45  profit_iteration 0.00  iterations 927.00  long_return 1.55
# episode  119 score -0.45 average score -0.67 epsilon 0.45  profit_iteration 0.00  iterations 927.00  long_return 1.55
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-a4fbccf4249a> in <module>
#      16             score += reward
#      17             agent.store_transition(observation, action, reward, observation_, done)
# ---> 18         agent.learn()
#      19 #        if learn_count == learn_frequency:
#      20 #            agent.learn()
#
# ~\Documents\GitHub\projects\practices\reinforcement learning\DDQN-stock\ddqn_agent.py in learn(self)
#      92         q_target = rewards + self.gamma*q_next[indices, max_actions]
#      93         loss = self.q_eval.loss(q_target, q_pred).to(self.q_eval.device)
# ---> 94         loss.backward()
#      95         T.nn.utils.clip_grad_norm_(self.q_eval.parameters(), 1.0) # gradient clip
#      96
#
# ~\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     183                 products. Defaults to ``False``.
#     184         """
# --> 185         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     186
#     187     def register_hook(self, hook):
#
# ~\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     125     Variable._execution_engine.run_backward(
#     126         tensors, grad_tensors, retain_graph, create_graph,
# --> 127         allow_unreachable=True)  # allow_unreachable flag
#     128
#     129
#
# KeyboardInterrupt:
